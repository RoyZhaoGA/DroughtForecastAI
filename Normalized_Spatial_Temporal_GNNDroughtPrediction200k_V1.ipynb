# %% [markdown]
# <a href="https://colab.research.google.com/github/RoyZhaoGA/DroughtForecastAI/blob/main/Normalized_Spatial_Temporal_GNNDroughtPrediction200k_V1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
processed_dataset_org = pd.read_csv("/content/drive/MyDrive/DroughtCastAI/Dataset/Processed_Datasets/CMIP6_processed_dataset_200km_version2_1_month_lag.csv")

# %%
processed_dataset_org
# Out:
#        Unnamed: 0   Month     Lat     Lon  temperature_2m  temperature_2m_min  \
# 0             287  201505  15.271 -17.068         297.249             291.684
# 1             287  201506  15.271 -17.068         298.479             292.966
# 2             287  201507  15.271 -17.068         300.038             296.358
# 3             287  201508  15.271 -17.068         300.277             297.167
# 4             287  201509  15.271 -17.068         300.453             296.962
# ...           ...     ...     ...     ...             ...                 ...
# 83575         387  202304  11.678  51.204         299.834             294.269
# 83576         387  202305  11.678  51.204         301.408             294.354
# 83577         387  202306  11.678  51.204         302.933             296.843
# 83578         387  202307  11.678  51.204         304.032             299.200
# 83579         387  202308  11.678  51.204         303.200             298.097
#
#        temperature_2m_max  dewpoint_temperature_2m  total_precipitation_sum  \
# 0                 304.108                  292.141                 0.000248
# 1                 307.924                  293.551                 0.000030
# 2                 304.813                  295.583                 0.039828
# 3                 304.959                  297.178                 0.201599
# 4                 304.370                  297.498                 0.118411
# ...                   ...                      ...                      ...
# 83575             306.253                  293.895                 0.005088
# 83576             307.231                  295.266                 0.019854
# 83577             309.328                  292.453                 0.000158
# 83578             309.950                  290.167                 0.000038
# 83579             310.122                  290.921                 0.000185
#
#        total_precipitation_min  ...      EVI  next_month_tempreature  \
# 0                 0.000000e+00  ...  1132.95                 303.650
# 1                 0.000000e+00  ...  1116.97                 302.250
# 2                 0.000000e+00  ...  1368.95                 302.435
# 3                 8.638150e-08  ...  2475.59                 303.790
# 4                 8.523460e-07  ...  2849.36                 304.714
# ...                        ...  ...      ...                     ...
# 83575             1.009060e-07  ...  1300.87                 303.895
# 83576             3.091570e-07  ...  1210.34                 305.717
# 83577             0.000000e+00  ...  1144.27                 305.315
# 83578             0.000000e+00  ...  1043.21                 303.643
# 83579             0.000000e+00  ...  1060.97                 304.022
#
#        next_month_precipitation    spei01    spei03    datetime  year  month2  \
# 0                  3.938450e-06 -1.030740 -0.937773  2015-05-01  2015       5
# 1                  3.481040e-06 -1.983540 -1.747770  2015-06-01  2015       6
# 2                  1.429650e-05 -0.773948 -1.519480  2015-07-01  2015       7
# 3                  6.708030e-05  1.125420  0.176900  2015-08-01  2015       8
# 4                  1.539020e-06  0.593335  0.588032  2015-09-01  2015       9
# ...                         ...       ...       ...         ...   ...     ...
# 83575              1.717400e-06  1.432950  0.334410  2023-04-01  2023       4
# 83576              4.468630e-07  0.317675  0.610513  2023-05-01  2023       5
# 83577              3.380950e-08  0.585810  0.947582  2023-06-01  2023       6
# 83578              4.085260e-06  1.418990  0.833237  2023-07-01  2023       7
# 83579              8.440640e-07  0.518092  0.864057  2023-08-01  2023       8
#
#        next_month_soil_moisture_am  next_month_spei01
# 0                         0.148753          -1.983540
# 1                         0.169415          -0.773948
# 2                         0.229645           1.125420
# 3                         0.226260           0.593335
# 4                         0.155879           0.325884
# ...                            ...                ...
# 83575                     0.147807           0.317675
# 83576                     0.147549           0.585810
# 83577                     0.146490           1.418990
# 83578                     0.148758           0.518092
# 83579                     0.151262          -0.447870
#
# [83580 rows x 28 columns]

# %%
processed_dataset_org.describe()
# Out:
#          Unnamed: 0          Month           Lat           Lon  \
# count  83580.000000   83580.000000  83580.000000  83580.000000
# mean     418.813735  201906.427614      6.426204     18.674333
# std      242.096341     242.792918     17.759911     15.790527
# min        0.000000  201505.000000    -33.238000    -17.068000
# 25%      208.000000  201705.000000     -6.288000      8.085000
# 50%      419.000000  201906.000000      9.881000     20.661000
# 75%      628.000000  202107.000000     20.661000     29.644000
# max      837.000000  202308.000000     36.831000     51.204000
#
#        temperature_2m  temperature_2m_min  temperature_2m_max  \
# count    83580.000000        83580.000000        83580.000000
# mean       297.649914          288.751947          307.368306
# std          5.733555            6.671234            5.693900
# min        272.097000          258.898000          281.999000
# 25%        294.404000          284.604000          303.519750
# 50%        298.138000          290.355000          307.035500
# 75%        301.243000          293.962000          311.563000
# max        313.569000          302.760000          322.431000
#
#        dewpoint_temperature_2m  total_precipitation_sum  \
# count             83580.000000             83580.000000
# mean                283.618993                 0.053403
# std                   8.848290                 0.088575
# min                 259.118000                 0.000016
# 25%                 276.173000                 0.000221
# 50%                 284.262000                 0.006267
# 75%                 291.767250                 0.076323
# max                 298.408000                 1.148110
#
#        total_precipitation_min  ...          NDVI           EVI  \
# count             83580.000000  ...  83580.000000  83580.000000
# mean                  0.000054  ...   3420.290769   2134.155208
# std                   0.000232  ...   2345.066013   1406.945576
# min                   0.000000  ...    489.180000    326.296000
# 25%                   0.000000  ...   1138.105000    857.004500
# 50%                   0.000000  ...   2827.910000   1692.095000
# 75%                   0.000001  ...   5490.260000   3268.610000
# max                   0.006530  ...   8742.230000   6458.600000
#
#        next_month_tempreature  next_month_precipitation        spei01  \
# count            83580.000000              8.358000e+04  83580.000000
# mean               298.576399              2.584283e-05     -0.646818
# std                  5.686335              4.198437e-05      1.343397
# min                277.836000              0.000000e+00     -5.000000
# 25%                295.590000              5.410485e-08     -1.500755
# 50%                299.064000              3.700365e-06     -0.672251
# 75%                302.221000              3.568545e-05      0.246571
# max                313.910000              3.350020e-04      5.000000
#
#              spei03          year        month2  next_month_soil_moisture_am  \
# count  83580.000000  83580.000000  83580.000000                 83580.000000
# mean      -0.761360   2018.999282      6.499402                     0.151643
# std        1.285446      2.432968      3.389895                     0.126393
# min       -5.000000   2015.000000      1.000000                     0.020000
# 25%       -1.608122   2017.000000      4.000000                     0.050233
# 50%       -0.850191   2019.000000      6.000000                     0.107151
# 75%        0.077590   2021.000000      9.000000                     0.219935
# max        5.000000   2023.000000     12.000000                     0.668410
#
#        next_month_spei01
# count       83580.000000
# mean           -0.646973
# std             1.344868
# min            -5.000000
# 25%            -1.499347
# 50%            -0.671430
# 75%             0.247549
# max             5.000000
#
# [8 rows x 27 columns]

# %%
from sklearn import preprocessing

processed_dataset_normal = processed_dataset_org.copy()
processed_dataset_normal2=processed_dataset_normal[[ 'Lat', 'Lon', 'temperature_2m',
       'temperature_2m_min', 'temperature_2m_max', 'dewpoint_temperature_2m',
       'total_precipitation_sum', 'total_precipitation_min',
       'total_precipitation_max', 'u_component_of_wind_10m',
       'v_component_of_wind_10m', 'surface_net_solar_radiation_sum',
       'total_evaporation_sum', 'soil_moisture_am', 'soil_moisture_pm', 'NDVI',
       'EVI', 'next_month_tempreature', 'next_month_precipitation', 'spei01',
       'spei03', 'year', 'month2', 'next_month_soil_moisture_am',
       'next_month_spei01']]
x = processed_dataset_normal2.values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
normalized_df= pd.DataFrame(x_scaled)

normalized_df.columns = ['Lat_nom', 'Lon_nom','temperature_2m',
       'temperature_2m_min', 'temperature_2m_max', 'dewpoint_temperature_2m',
       'total_precipitation_sum', 'total_precipitation_min',
       'total_precipitation_max', 'u_component_of_wind_10m',
       'v_component_of_wind_10m', 'surface_net_solar_radiation_sum',
       'total_evaporation_sum', 'soil_moisture_am', 'soil_moisture_pm', 'NDVI',
       'EVI', 'next_month_tempreature', 'next_month_precipitation', 'spei01',
       'spei03', 'year', 'month2', 'next_month_soil_moisture_am',
       'next_month_spei01']

horizontal_concat = pd.concat([processed_dataset_normal[['Month','Lat', 'Lon']],normalized_df, processed_dataset_normal[['datetime']]], axis=1)
#horizontal_concat2 = pd.concat([ processed_dataset_normal[['monrh']],horizontal_concat, axis=1)
# view normalized data
display(horizontal_concat)
# Out:
#         Month     Lat     Lon   Lat_nom  Lon_nom  temperature_2m  \
# 0      201505  15.271 -17.068  0.692303      0.0        0.606481
# 1      201506  15.271 -17.068  0.692303      0.0        0.636140
# 2      201507  15.271 -17.068  0.692303      0.0        0.673732
# 3      201508  15.271 -17.068  0.692303      0.0        0.679495
# 4      201509  15.271 -17.068  0.692303      0.0        0.683738
# ...       ...     ...     ...       ...      ...             ...
# 83575  202304  11.678  51.204  0.641025      1.0        0.668813
# 83576  202305  11.678  51.204  0.641025      1.0        0.706766
# 83577  202306  11.678  51.204  0.641025      1.0        0.743538
# 83578  202307  11.678  51.204  0.641025      1.0        0.770038
# 83579  202308  11.678  51.204  0.641025      1.0        0.749976
#
#        temperature_2m_min  temperature_2m_max  dewpoint_temperature_2m  \
# 0                0.747481            0.546819                 0.840494
# 1                0.776709            0.641200                 0.876381
# 2                0.854042            0.564256                 0.928099
# 3                0.872486            0.567867                 0.968694
# 4                0.867813            0.553299                 0.976839
# ...                   ...                 ...                      ...
# 83575            0.806416            0.599871                 0.885136
# 83576            0.808353            0.624060                 0.920031
# 83577            0.865100            0.675925                 0.848435
# 83578            0.918836            0.691309                 0.790252
# 83579            0.893689            0.695563                 0.809443
#
#        total_precipitation_sum  ...       EVI  next_month_tempreature  \
# 0                     0.000202  ...  0.131542                0.715585
# 1                     0.000012  ...  0.128936                0.676776
# 2                     0.034677  ...  0.170026                0.681904
# 3                     0.175580  ...  0.350487                0.719466
# 4                     0.103123  ...  0.411438                0.745080
# ...                        ...  ...       ...                     ...
# 83575                 0.004417  ...  0.158925                0.722376
# 83576                 0.017279  ...  0.144162                0.772884
# 83577                 0.000123  ...  0.133388                0.761740
# 83578                 0.000019  ...  0.116908                0.715391
# 83579                 0.000147  ...  0.119804                0.725897
#
#        next_month_precipitation    spei01    spei03  year    month2  \
# 0                      0.011756  0.396926  0.406223   0.0  0.363636
# 1                      0.010391  0.301646  0.325223   0.0  0.454545
# 2                      0.042676  0.422605  0.348052   0.0  0.545455
# 3                      0.200239  0.612542  0.517690   0.0  0.636364
# 4                      0.004594  0.559334  0.558803   0.0  0.727273
# ...                         ...       ...       ...   ...       ...
# 83575                  0.005127  0.643295  0.533441   1.0  0.272727
# 83576                  0.001334  0.531767  0.561051   1.0  0.363636
# 83577                  0.000101  0.558581  0.594758   1.0  0.454545
# 83578                  0.012195  0.641899  0.583324   1.0  0.545455
# 83579                  0.002520  0.551809  0.586406   1.0  0.636364
#
#        next_month_soil_moisture_am  next_month_spei01    datetime
# 0                         0.198567           0.301646  2015-05-01
# 1                         0.230433           0.422605  2015-06-01
# 2                         0.323322           0.612542  2015-07-01
# 3                         0.318101           0.559334  2015-08-01
# 4                         0.209557           0.532588  2015-09-01
# ...                            ...                ...         ...
# 83575                     0.197108           0.531767  2023-04-01
# 83576                     0.196710           0.558581  2023-05-01
# 83577                     0.195077           0.641899  2023-06-01
# 83578                     0.198575           0.551809  2023-07-01
# 83579                     0.202437           0.455213  2023-08-01
#
# [83580 rows x 29 columns]

# %%
processed_dataset=horizontal_concat

processed_dataset.describe()
# Out:
#                Month           Lat           Lon       Lat_nom       Lon_nom  \
# count   83580.000000  83580.000000  83580.000000  83580.000000  83580.000000
# mean   201906.427614      6.426204     18.674333      0.566073      0.523528
# std       242.792918     17.759911     15.790527      0.253463      0.231288
# min    201505.000000    -33.238000    -17.068000      0.000000      0.000000
# 25%    201705.000000     -6.288000      8.085000      0.384621      0.368423
# 50%    201906.000000      9.881000     20.661000      0.615379      0.552628
# 75%    202107.000000     20.661000     29.644000      0.769227      0.684204
# max    202308.000000     36.831000     51.204000      1.000000      1.000000
#
#        temperature_2m  temperature_2m_min  temperature_2m_max  \
# count    83580.000000        83580.000000        83580.000000
# mean         0.616149            0.680634            0.627456
# std          0.138251            0.152096            0.140827
# min          0.000000            0.000000            0.000000
# 25%          0.537881            0.586065            0.532270
# 50%          0.627918            0.717181            0.619225
# 75%          0.702787            0.799416            0.731203
# max          1.000000            1.000000            1.000000
#
#        dewpoint_temperature_2m  total_precipitation_sum  ...          NDVI  \
# count             83580.000000             83580.000000  ...  83580.000000
# mean                  0.623594                 0.046500  ...      0.355155
# std                   0.225205                 0.077150  ...      0.284145
# min                   0.000000                 0.000000  ...      0.000000
# 25%                   0.434080                 0.000178  ...      0.078629
# 50%                   0.639959                 0.005444  ...      0.283378
# 75%                   0.830981                 0.066464  ...      0.605967
# max                   1.000000                 1.000000  ...      1.000000
#
#                 EVI  next_month_tempreature  next_month_precipitation  \
# count  83580.000000            83580.000000              83580.000000
# mean       0.294809                0.574940                  0.077142
# std        0.229432                0.157630                  0.125326
# min        0.000000                0.000000                  0.000000
# 25%        0.086543                0.492155                  0.000162
# 50%        0.222722                0.588457                  0.011046
# 75%        0.479806                0.675972                  0.106523
# max        1.000000                1.000000                  1.000000
#
#              spei01        spei03          year        month2  \
# count  83580.000000  83580.000000  83580.000000  83580.000000
# mean       0.435318      0.423864      0.499910      0.499946
# std        0.134340      0.128545      0.304121      0.308172
# min        0.000000      0.000000      0.000000      0.000000
# 25%        0.349924      0.339188      0.250000      0.272727
# 50%        0.432775      0.414981      0.500000      0.454545
# 75%        0.524657      0.507759      0.750000      0.727273
# max        1.000000      1.000000      1.000000      1.000000
#
#        next_month_soil_moisture_am  next_month_spei01
# count                 83580.000000       83580.000000
# mean                      0.203024           0.435303
# std                       0.194927           0.134487
# min                       0.000000           0.000000
# 25%                       0.046626           0.350065
# 50%                       0.134407           0.432857
# 75%                       0.308346           0.524755
# max                       1.000000           1.000000
#
# [8 rows x 28 columns]

# %%
display(processed_dataset)
# Out:
#         Month     Lat     Lon   Lat_nom  Lon_nom  temperature_2m  \
# 0      201505  15.271 -17.068  0.692303      0.0        0.606481
# 1      201506  15.271 -17.068  0.692303      0.0        0.636140
# 2      201507  15.271 -17.068  0.692303      0.0        0.673732
# 3      201508  15.271 -17.068  0.692303      0.0        0.679495
# 4      201509  15.271 -17.068  0.692303      0.0        0.683738
# ...       ...     ...     ...       ...      ...             ...
# 83575  202304  11.678  51.204  0.641025      1.0        0.668813
# 83576  202305  11.678  51.204  0.641025      1.0        0.706766
# 83577  202306  11.678  51.204  0.641025      1.0        0.743538
# 83578  202307  11.678  51.204  0.641025      1.0        0.770038
# 83579  202308  11.678  51.204  0.641025      1.0        0.749976
#
#        temperature_2m_min  temperature_2m_max  dewpoint_temperature_2m  \
# 0                0.747481            0.546819                 0.840494
# 1                0.776709            0.641200                 0.876381
# 2                0.854042            0.564256                 0.928099
# 3                0.872486            0.567867                 0.968694
# 4                0.867813            0.553299                 0.976839
# ...                   ...                 ...                      ...
# 83575            0.806416            0.599871                 0.885136
# 83576            0.808353            0.624060                 0.920031
# 83577            0.865100            0.675925                 0.848435
# 83578            0.918836            0.691309                 0.790252
# 83579            0.893689            0.695563                 0.809443
#
#        total_precipitation_sum  ...       EVI  next_month_tempreature  \
# 0                     0.000202  ...  0.131542                0.715585
# 1                     0.000012  ...  0.128936                0.676776
# 2                     0.034677  ...  0.170026                0.681904
# 3                     0.175580  ...  0.350487                0.719466
# 4                     0.103123  ...  0.411438                0.745080
# ...                        ...  ...       ...                     ...
# 83575                 0.004417  ...  0.158925                0.722376
# 83576                 0.017279  ...  0.144162                0.772884
# 83577                 0.000123  ...  0.133388                0.761740
# 83578                 0.000019  ...  0.116908                0.715391
# 83579                 0.000147  ...  0.119804                0.725897
#
#        next_month_precipitation    spei01    spei03  year    month2  \
# 0                      0.011756  0.396926  0.406223   0.0  0.363636
# 1                      0.010391  0.301646  0.325223   0.0  0.454545
# 2                      0.042676  0.422605  0.348052   0.0  0.545455
# 3                      0.200239  0.612542  0.517690   0.0  0.636364
# 4                      0.004594  0.559334  0.558803   0.0  0.727273
# ...                         ...       ...       ...   ...       ...
# 83575                  0.005127  0.643295  0.533441   1.0  0.272727
# 83576                  0.001334  0.531767  0.561051   1.0  0.363636
# 83577                  0.000101  0.558581  0.594758   1.0  0.454545
# 83578                  0.012195  0.641899  0.583324   1.0  0.545455
# 83579                  0.002520  0.551809  0.586406   1.0  0.636364
#
#        next_month_soil_moisture_am  next_month_spei01    datetime
# 0                         0.198567           0.301646  2015-05-01
# 1                         0.230433           0.422605  2015-06-01
# 2                         0.323322           0.612542  2015-07-01
# 3                         0.318101           0.559334  2015-08-01
# 4                         0.209557           0.532588  2015-09-01
# ...                            ...                ...         ...
# 83575                     0.197108           0.531767  2023-04-01
# 83576                     0.196710           0.558581  2023-05-01
# 83577                     0.195077           0.641899  2023-06-01
# 83578                     0.198575           0.551809  2023-07-01
# 83579                     0.202437           0.455213  2023-08-01
#
# [83580 rows x 29 columns]

# %%
processed_dataset.to_csv('/content/drive/MyDrive/DroughtCastAI/Dataset/Processed_Datasets/CMIP6_processed_dataset_200km_version2_1_month_lag_normalized.csv', sep=',', encoding='utf-8', header='true')

# %%
processed_dataset=pd.read_csv("/content/drive/MyDrive/DroughtCastAI/Dataset/Processed_Datasets/CMIP6_processed_dataset_200km_version2_1_month_lag_normalized.csv")
processed_dataset.describe()
# Out:
#          Unnamed: 0          Month           Lat           Lon       Lat_nom  \
# count  83580.000000   83580.000000  83580.000000  83580.000000  83580.000000
# mean   41789.500000  201906.427614      6.426204     18.674333      0.566073
# std    24127.612087     242.792918     17.759911     15.790527      0.253463
# min        0.000000  201505.000000    -33.238000    -17.068000      0.000000
# 25%    20894.750000  201705.000000     -6.288000      8.085000      0.384621
# 50%    41789.500000  201906.000000      9.881000     20.661000      0.615379
# 75%    62684.250000  202107.000000     20.661000     29.644000      0.769227
# max    83579.000000  202308.000000     36.831000     51.204000      1.000000
#
#             Lon_nom  temperature_2m  temperature_2m_min  temperature_2m_max  \
# count  83580.000000    83580.000000        83580.000000        83580.000000
# mean       0.523528        0.616149            0.680634            0.627456
# std        0.231288        0.138251            0.152096            0.140827
# min        0.000000        0.000000            0.000000            0.000000
# 25%        0.368423        0.537881            0.586065            0.532270
# 50%        0.552628        0.627918            0.717181            0.619225
# 75%        0.684204        0.702787            0.799416            0.731203
# max        1.000000        1.000000            1.000000            1.000000
#
#        dewpoint_temperature_2m  ...          NDVI           EVI  \
# count             83580.000000  ...  83580.000000  83580.000000
# mean                  0.623594  ...      0.355155      0.294809
# std                   0.225205  ...      0.284145      0.229432
# min                   0.000000  ...      0.000000      0.000000
# 25%                   0.434080  ...      0.078629      0.086543
# 50%                   0.639959  ...      0.283378      0.222722
# 75%                   0.830981  ...      0.605967      0.479806
# max                   1.000000  ...      1.000000      1.000000
#
#        next_month_tempreature  next_month_precipitation        spei01  \
# count            83580.000000              83580.000000  83580.000000
# mean                 0.574940                  0.077142      0.435318
# std                  0.157630                  0.125326      0.134340
# min                  0.000000                  0.000000      0.000000
# 25%                  0.492155                  0.000162      0.349924
# 50%                  0.588457                  0.011046      0.432775
# 75%                  0.675972                  0.106523      0.524657
# max                  1.000000                  1.000000      1.000000
#
#              spei03          year        month2  next_month_soil_moisture_am  \
# count  83580.000000  83580.000000  83580.000000                 83580.000000
# mean       0.423864      0.499910      0.499946                     0.203024
# std        0.128545      0.304121      0.308172                     0.194927
# min        0.000000      0.000000      0.000000                     0.000000
# 25%        0.339188      0.250000      0.272727                     0.046626
# 50%        0.414981      0.500000      0.454545                     0.134407
# 75%        0.507759      0.750000      0.727273                     0.308346
# max        1.000000      1.000000      1.000000                     1.000000
#
#        next_month_spei01
# count       83580.000000
# mean            0.435303
# std             0.134487
# min             0.000000
# 25%             0.350065
# 50%             0.432857
# 75%             0.524755
# max             1.000000
#
# [8 rows x 29 columns]

# %%
import networkx as nx
from geopy.distance import geodesic

# %%
sort_processed_dataset = processed_dataset.sort_values(by=["Month",'Lat','Lon'])
sort_processed_dataset
# Out:
#        Unnamed: 0   Month     Lat     Lon  Lat_nom   Lon_nom  temperature_2m  \
# 36896       36896  201505 -33.238  18.865      0.0  0.526321        0.398172
# 40496       40496  201505 -33.238  20.661      0.0  0.552628        0.349754
# 44196       44196  201505 -33.238  22.458      0.0  0.578949        0.375193
# 47996       47996  201505 -33.238  24.255      0.0  0.605270        0.389299
# 51696       51696  201505 -33.238  26.051      0.0  0.631577        0.398992
# ...           ...     ...     ...     ...      ...       ...             ...
# 16798       16798  202308  36.831   2.695      1.0  0.289474        0.667945
# 18598       18598  202308  36.831   4.492      1.0  0.315796        0.647545
# 20498       20498  202308  36.831   6.288      1.0  0.342102        0.653019
# 22398       22398  202308  36.831   8.085      1.0  0.368423        0.668234
# 24697       24697  202308  36.831   9.881      1.0  0.394730        0.682846
#
#        temperature_2m_min  temperature_2m_max  dewpoint_temperature_2m  ...  \
# 36896            0.485135            0.527923                 0.593484  ...
# 40496            0.418038            0.437228                 0.444897  ...
# 44196            0.422256            0.457385                 0.470960  ...
# 47996            0.458894            0.511773                 0.493153  ...
# 51696            0.463682            0.522853                 0.573683  ...
# ...                   ...                 ...                      ...  ...
# 16798            0.756691            0.643748                 0.852634  ...
# 18598            0.728672            0.660986                 0.788369  ...
# 20498            0.717706            0.701103                 0.789488  ...
# 22398            0.745839            0.794890                 0.796946  ...
# 24697            0.730222            0.857984                 0.785874  ...
#
#             EVI  next_month_tempreature  next_month_precipitation    spei01  \
# 36896  0.204301                0.197233                  0.106377  0.435383
# 40496  0.120505                0.167129                  0.051331  0.493988
# 44196  0.133445                0.172479                  0.068831  0.460426
# 47996  0.184492                0.188169                  0.071556  0.496584
# 51696  0.407857                0.258191                  0.101502  0.422760
# ...         ...                     ...                       ...       ...
# 16798  0.171166                0.621888                  0.130777  0.199253
# 18598  0.183406                0.610772                  0.091340  0.238931
# 20498  0.221102                0.603232                  0.081882  0.234256
# 22398  0.192887                0.609275                  0.068997  0.350369
# 24697  0.177926                0.612242                  0.046001  0.394491
#
#          spei03  year    month2  next_month_soil_moisture_am  \
# 36896  0.357744   0.0  0.363636                     0.356693
# 40496  0.428312   0.0  0.363636                     0.289999
# 44196  0.480249   0.0  0.363636                     0.334359
# 47996  0.604930   0.0  0.363636                     0.280466
# 51696  0.559692   0.0  0.363636                     0.332310
# ...         ...   ...       ...                          ...
# 16798  0.271646   1.0  0.636364                     0.124452
# 18598  0.303782   1.0  0.636364                     0.224663
# 20498  0.384567   1.0  0.636364                     0.213737
# 22398  0.368890   1.0  0.636364                     0.220538
# 24697  0.308478   1.0  0.636364                     0.074301
#
#        next_month_spei01    datetime
# 36896           0.564221  2015-05-01
# 40496           0.746059  2015-05-01
# 44196           0.689636  2015-05-01
# 47996           0.643318  2015-05-01
# 51696           0.627903  2015-05-01
# ...                  ...         ...
# 16798           0.390657  2023-08-01
# 18598           0.322575  2023-08-01
# 20498           0.305495  2023-08-01
# 22398           0.282792  2023-08-01
# 24697           0.237530  2023-08-01
#
# [83580 rows x 30 columns]

# %%
sort_processed_dataset["row_index"] = sort_processed_dataset.index

# %%
sort_processed_dataset.columns
# Out:
# Index(['Unnamed: 0', 'Month', 'Lat', 'Lon', 'Lat_nom', 'Lon_nom',
#        'temperature_2m', 'temperature_2m_min', 'temperature_2m_max',
#        'dewpoint_temperature_2m', 'total_precipitation_sum',
#        'total_precipitation_min', 'total_precipitation_max',
#        'u_component_of_wind_10m', 'v_component_of_wind_10m',
#        'surface_net_solar_radiation_sum', 'total_evaporation_sum',
#        'soil_moisture_am', 'soil_moisture_pm', 'NDVI', 'EVI',
#        'next_month_tempreature', 'next_month_precipitation', 'spei01',
#        'spei03', 'year', 'month2', 'next_month_soil_moisture_am',
#        'next_month_spei01', 'datetime', 'row_index'],
#       dtype='object')

# %% [markdown]
# **Spatial-Temporal Graph**

# %%
Spatial_temporal_graph = nx.Graph()

# %%
# Add nodes with features
for index, row in sort_processed_dataset.iterrows():
    Spatial_temporal_graph.add_node(index, **row[["row_index","Month",'Lat', 'Lon',  'Lat_nom', 'Lon_nom','temperature_2m', 'temperature_2m_min',
                             'temperature_2m_max', 'dewpoint_temperature_2m', 'total_precipitation_sum',
                             'total_precipitation_min', 'total_precipitation_max', 'u_component_of_wind_10m',
                             'v_component_of_wind_10m', 'surface_net_solar_radiation_sum',
                             'total_evaporation_sum', 'soil_moisture_am', 'soil_moisture_pm', 'NDVI',
                             'EVI', 'next_month_tempreature', 'next_month_precipitation', 'year', 'month2', 'spei01', "next_month_soil_moisture_am", "next_month_spei01"]].to_dict())

print("finished creating node features")
# Out:
# finished creating node features

# %%
unique_list_of_months = list(set(sort_processed_dataset["Month"]))
unique_list_of_months.sort()
unique_list_of_months
# Out:
# [201505,
#  201506,
#  201507,
#  201508,
#  201509,
#  201510,
#  201511,
#  201512,
#  201601,
#  201602,
#  201603,
#  201604,
#  201605,
#  201606,
#  201607,
#  201608,
#  201609,
#  201610,
#  201611,
#  201612,
#  201701,
#  201702,
#  201703,
#  201704,
#  201705,
#  201706,
#  201707,
#  201708,
#  201709,
#  201710,
#  201711,
#  201712,
#  201801,
#  201802,
#  201803,
#  201804,
#  201805,
#  201806,
#  201807,
#  201808,
#  201809,
#  201810,
#  201811,
#  201812,
#  201901,
#  201902,
#  201903,
#  201904,
#  201905,
#  201906,
#  201907,
#  201908,
#  201909,
#  201910,
#  201911,
#  201912,
#  202001,
#  202002,
#  202003,
#  202004,
#  202005,
#  202006,
#  202007,
#  202008,
#  202009,
#  202010,
#  202011,
#  202012,
#  202101,
#  202102,
#  202103,
#  202104,
#  202105,
#  202106,
#  202107,
#  202108,
#  202109,
#  202110,
#  202111,
#  202112,
#  202201,
#  202202,
#  202203,
#  202204,
#  202205,
#  202206,
#  202207,
#  202208,
#  202209,
#  202210,
#  202211,
#  202212,
#  202301,
#  202302,
#  202303,
#  202304,
#  202305,
#  202306,
#  202307,
#  202308]

# %% [markdown]
# **Distance-Based Spatial Graph**

# %%
from scipy.spatial import KDTree
total_index=0
diff=0.05

for month in unique_list_of_months:
    dataset_subset = sort_processed_dataset[sort_processed_dataset["Month"] == month]
    print("\n!!!!!!!!!!CURRENT MONTH!",month)
    # Create a KDTree for efficient spatial queries
    tree = KDTree(dataset_subset[['Lat', 'Lon']])

    # Iterate through each row in the dataset
    for i, row in dataset_subset.iterrows():
        # Query the tree for points within 3 units
        indices = tree.query_ball_point([row['Lat'], row['Lon']], 3)
        i_Spei=row['spei01']
     #   print("Current row I ",i," Lat and Lon ",row['Lat'],row['Lon']," with SPEI ", i_Spei)
        # Add edges to the graph
        for j in indices:
            j_row_index = sort_processed_dataset.iloc[total_index + j]["row_index"]
            j_month=sort_processed_dataset.iloc[total_index + j]["Month"]
            j_Lat=sort_processed_dataset.iloc[total_index + j]["Lat"]
            j_Lon=sort_processed_dataset.iloc[total_index + j]["Lon"]
            j_Spei=sort_processed_dataset.iloc[total_index + j]["spei01"]
            speiDiff=abs(i_Spei - j_Spei)
           # print("Adjacent row J ", j_row_index, "of Month" , j_month, " Lat and Lon", j_Lat,j_Lon, " with SPEI ", j_Spei)
            if i != j_row_index:  # Avoid adding self-loops
                if  speiDiff < diff:
                  Spatial_temporal_graph.add_edge(i, j_row_index)
                  print("Edge Added: "+str(i)+", "+str(j_row_index))

    total_index += len(dataset_subset)

    print("nodes processed: " + str(total_index))
# Out:
# Streaming output truncated to the last 5000 lines.
# Edge Added: 61294, 57694
# Edge Added: 61294, 61394
# Edge Added: 61294, 64694
# Edge Added: 61294, 64794
# Edge Added: 64794, 61294
# Edge Added: 64794, 61394
# Edge Added: 64794, 64694
# Edge Added: 64794, 68093
# Edge Added: 64794, 67993
# Edge Added: 68093, 64694
# Edge Added: 68093, 64794
# Edge Added: 68093, 64894
# Edge Added: 68093, 67993
# Edge Added: 68093, 71191
# Edge Added: 71291, 68193
# Edge Added: 71291, 73987
# Edge Added: 71291, 71191
# Edge Added: 71291, 74087
# Edge Added: 74087, 73987
# Edge Added: 74087, 71191
# Edge Added: 74087, 76383
# Edge Added: 74087, 71291
# Edge Added: 76383, 73987
# Edge Added: 76383, 74087
# Edge Added: 77983, 77883
# Edge Added: 77983, 76283
# Edge Added: 78981, 78881
# Edge Added: 80279, 80179
# Edge Added: 80279, 81179
# Edge Added: 80279, 81379
# Edge Added: 80279, 81279
# Edge Added: 81279, 80179
# Edge Added: 81279, 80279
# Edge Added: 81279, 81179
# Edge Added: 81279, 81379
# Edge Added: 81279, 82279
# Edge Added: 82379, 83078
# Edge Added: 82379, 82479
# Edge Added: 82379, 83178
# Edge Added: 83078, 82479
# Edge Added: 83078, 82379
# Edge Added: 2098, 3398
# Edge Added: 2098, 2198
# Edge Added: 2098, 1098
# Edge Added: 2098, 3498
# Edge Added: 3398, 2098
# Edge Added: 3398, 3298
# Edge Added: 3398, 4998
# Edge Added: 3398, 3498
# Edge Added: 4998, 3398
# Edge Added: 4998, 3298
# Edge Added: 4998, 6698
# Edge Added: 4998, 3498
# Edge Added: 6698, 4998
# Edge Added: 6698, 4898
# Edge Added: 6698, 6598
# Edge Added: 8398, 6598
# Edge Added: 8398, 8298
# Edge Added: 10097, 8298
# Edge Added: 10097, 11797
# Edge Added: 10097, 11697
# Edge Added: 11797, 10097
# Edge Added: 11797, 13397
# Edge Added: 13497, 15097
# Edge Added: 13497, 15197
# Edge Added: 13497, 11897
# Edge Added: 13497, 13597
# Edge Added: 13497, 15297
# Edge Added: 15197, 13497
# Edge Added: 15197, 15097
# Edge Added: 15197, 16897
# Edge Added: 15197, 13597
# Edge Added: 15197, 15297
# Edge Added: 16997, 18897
# Edge Added: 16997, 15297
# Edge Added: 16997, 18997
# Edge Added: 18897, 16997
# Edge Added: 18897, 20797
# Edge Added: 18897, 17097
# Edge Added: 18897, 18997
# Edge Added: 20797, 18897
# Edge Added: 20797, 18997
# Edge Added: 23096, 20697
# Edge Added: 25595, 25495
# Edge Added: 25595, 28494
# Edge Added: 25595, 28594
# Edge Added: 25595, 25695
# Edge Added: 25595, 28694
# Edge Added: 28594, 28494
# Edge Added: 28594, 25595
# Edge Added: 28594, 32194
# Edge Added: 28594, 28694
# Edge Added: 32094, 32194
# Edge Added: 35594, 39294
# Edge Added: 35594, 32194
# Edge Added: 35594, 35694
# Edge Added: 39294, 35594
# Edge Added: 39294, 42894
# Edge Added: 39294, 39394
# Edge Added: 39294, 35694
# Edge Added: 39294, 42994
# Edge Added: 42894, 39294
# Edge Added: 42894, 46594
# Edge Added: 42894, 39394
# Edge Added: 42894, 42994
# Edge Added: 42894, 46694
# Edge Added: 46594, 50394
# Edge Added: 46594, 42894
# Edge Added: 46594, 46694
# Edge Added: 46594, 50494
# Edge Added: 50394, 46594
# Edge Added: 50394, 46694
# Edge Added: 50394, 54194
# Edge Added: 50394, 50494
# Edge Added: 54094, 53994
# Edge Added: 54094, 54194
# Edge Added: 54094, 57894
# Edge Added: 57794, 53994
# Edge Added: 57794, 57694
# Edge Added: 61394, 57694
# Edge Added: 61394, 61294
# Edge Added: 61394, 64794
# Edge Added: 64894, 68093
# Edge Added: 64894, 61494
# Edge Added: 68193, 71291
# Edge Added: 68193, 68293
# Edge Added: 68193, 64994
# Edge Added: 71391, 74187
# Edge Added: 71391, 68293
# Edge Added: 71391, 71491
# Edge Added: 74187, 71391
# Edge Added: 74187, 76483
# Edge Added: 74187, 71491
# Edge Added: 74187, 76583
# Edge Added: 76483, 74187
# Edge Added: 76483, 78082
# Edge Added: 76483, 76583
# Edge Added: 76483, 78181
# Edge Added: 78082, 76483
# Edge Added: 78082, 76583
# Edge Added: 78082, 78181
# Edge Added: 81379, 80279
# Edge Added: 81379, 81279
# Edge Added: 81379, 81479
# Edge Added: 82479, 83078
# Edge Added: 82479, 83178
# Edge Added: 82479, 82379
# Edge Added: 83178, 82479
# Edge Added: 83178, 82379
# Edge Added: 1098, 2098
# Edge Added: 1098, 2198
# Edge Added: 1098, 2298
# Edge Added: 2198, 2098
# Edge Added: 2198, 2298
# Edge Added: 2198, 1098
# Edge Added: 2198, 3598
# Edge Added: 3498, 3398
# Edge Added: 3498, 2098
# Edge Added: 3498, 4998
# Edge Added: 3498, 2298
# Edge Added: 3498, 3598
# Edge Added: 5098, 6798
# Edge Added: 6798, 5198
# Edge Added: 6798, 5098
# Edge Added: 6798, 8498
# Edge Added: 6798, 8598
# Edge Added: 8498, 6798
# Edge Added: 8498, 10297
# Edge Added: 10197, 11997
# Edge Added: 11897, 13497
# Edge Added: 11897, 13597
# Edge Added: 13597, 13497
# Edge Added: 13597, 15197
# Edge Added: 13597, 11897
# Edge Added: 13597, 15297
# Edge Added: 15297, 13497
# Edge Added: 15297, 16997
# Edge Added: 15297, 15197
# Edge Added: 15297, 13597
# Edge Added: 17097, 18897
# Edge Added: 18997, 16997
# Edge Added: 18997, 18897
# Edge Added: 18997, 20797
# Edge Added: 18997, 19097
# Edge Added: 20897, 23296
# Edge Added: 25695, 25595
# Edge Added: 25695, 23296
# Edge Added: 28694, 25595
# Edge Added: 28694, 28594
# Edge Added: 28694, 25795
# Edge Added: 28694, 32194
# Edge Added: 28694, 32294
# Edge Added: 28694, 28794
# Edge Added: 32194, 28594
# Edge Added: 32194, 35594
# Edge Added: 32194, 32094
# Edge Added: 32194, 32294
# Edge Added: 32194, 28794
# Edge Added: 32194, 28694
# Edge Added: 32194, 35794
# Edge Added: 32194, 35694
# Edge Added: 35694, 39294
# Edge Added: 35694, 35594
# Edge Added: 35694, 32194
# Edge Added: 35694, 39494
# Edge Added: 35694, 35794
# Edge Added: 35694, 39394
# Edge Added: 39394, 39294
# Edge Added: 39394, 42894
# Edge Added: 39394, 35694
# Edge Added: 39394, 42994
# Edge Added: 42994, 39294
# Edge Added: 42994, 42894
# Edge Added: 42994, 39494
# Edge Added: 42994, 39394
# Edge Added: 42994, 46794
# Edge Added: 42994, 43094
# Edge Added: 42994, 46694
# Edge Added: 46694, 50394
# Edge Added: 46694, 46594
# Edge Added: 46694, 42894
# Edge Added: 46694, 42994
# Edge Added: 46694, 46794
# Edge Added: 46694, 43094
# Edge Added: 46694, 50494
# Edge Added: 46694, 50594
# Edge Added: 50494, 50394
# Edge Added: 50494, 46594
# Edge Added: 50494, 46694
# Edge Added: 50494, 54194
# Edge Added: 50494, 50594
# Edge Added: 54194, 50394
# Edge Added: 54194, 54094
# Edge Added: 54194, 50494
# Edge Added: 54194, 50594
# Edge Added: 54194, 54294
# Edge Added: 54194, 57994
# Edge Added: 54194, 57894
# Edge Added: 57894, 54094
# Edge Added: 57894, 54194
# Edge Added: 57894, 54294
# Edge Added: 57894, 57994
# Edge Added: 57894, 61494
# Edge Added: 61494, 64894
# Edge Added: 61494, 57894
# Edge Added: 61494, 64994
# Edge Added: 64994, 68193
# Edge Added: 64994, 61494
# Edge Added: 68293, 68193
# Edge Added: 68293, 71391
# Edge Added: 68293, 68393
# Edge Added: 68293, 65094
# Edge Added: 68293, 71591
# Edge Added: 71491, 71391
# Edge Added: 71491, 74187
# Edge Added: 71491, 74387
# Edge Added: 76583, 74187
# Edge Added: 76583, 78082
# Edge Added: 76583, 76483
# Edge Added: 78181, 78082
# Edge Added: 78181, 76483
# Edge Added: 78181, 76683
# Edge Added: 80479, 79280
# Edge Added: 81479, 81379
# Edge Added: 82579, 83278
# Edge Added: 83278, 82579
# Edge Added: 83478, 83578
# Edge Added: 198, 1198
# Edge Added: 198, 298
# Edge Added: 1198, 2398
# Edge Added: 1198, 2298
# Edge Added: 1198, 198
# Edge Added: 1198, 298
# Edge Added: 2298, 2198
# Edge Added: 2298, 2398
# Edge Added: 2298, 1198
# Edge Added: 2298, 1098
# Edge Added: 2298, 1298
# Edge Added: 2298, 3498
# Edge Added: 2298, 3698
# Edge Added: 2298, 3598
# Edge Added: 3598, 2198
# Edge Added: 3598, 2398
# Edge Added: 3598, 2298
# Edge Added: 3598, 3498
# Edge Added: 3598, 3698
# Edge Added: 5198, 5298
# Edge Added: 5198, 6798
# Edge Added: 5198, 6998
# Edge Added: 5198, 6898
# Edge Added: 6898, 5198
# Edge Added: 6898, 5298
# Edge Added: 6898, 6998
# Edge Added: 6898, 8698
# Edge Added: 6898, 8598
# Edge Added: 8598, 6798
# Edge Added: 8598, 6998
# Edge Added: 8598, 6898
# Edge Added: 8598, 8698
# Edge Added: 10297, 8698
# Edge Added: 10297, 8498
# Edge Added: 11997, 13697
# Edge Added: 11997, 13797
# Edge Added: 11997, 12097
# Edge Added: 11997, 10197
# Edge Added: 13697, 13797
# Edge Added: 13697, 11997
# Edge Added: 13697, 15497
# Edge Added: 17197, 15497
# Edge Added: 19097, 18997
# Edge Added: 19097, 19197
# Edge Added: 19097, 21097
# Edge Added: 23296, 20897
# Edge Added: 23296, 25695
# Edge Added: 25795, 28894
# Edge Added: 25795, 28694
# Edge Added: 28794, 28894
# Edge Added: 28794, 32194
# Edge Added: 28794, 32294
# Edge Added: 28794, 28694
# Edge Added: 32294, 28894
# Edge Added: 32294, 32194
# Edge Added: 32294, 28794
# Edge Added: 32294, 28694
# Edge Added: 32294, 35794
# Edge Added: 35794, 32194
# Edge Added: 35794, 32294
# Edge Added: 35794, 39494
# Edge Added: 35794, 35694
# Edge Added: 35794, 39594
# Edge Added: 39494, 35794
# Edge Added: 39494, 35694
# Edge Added: 39494, 39594
# Edge Added: 39494, 43194
# Edge Added: 39494, 42994
# Edge Added: 39494, 43094
# Edge Added: 43094, 39494
# Edge Added: 43094, 39594
# Edge Added: 43094, 43194
# Edge Added: 43094, 42994
# Edge Added: 43094, 46794
# Edge Added: 43094, 46894
# Edge Added: 43094, 46694
# Edge Added: 46794, 43194
# Edge Added: 46794, 42994
# Edge Added: 46794, 43094
# Edge Added: 46794, 46894
# Edge Added: 46794, 46694
# Edge Added: 46794, 50694
# Edge Added: 46794, 50594
# Edge Added: 50594, 46794
# Edge Added: 50594, 46894
# Edge Added: 50594, 46694
# Edge Added: 50594, 54394
# Edge Added: 50594, 50694
# Edge Added: 50594, 54194
# Edge Added: 50594, 50494
# Edge Added: 50594, 54294
# Edge Added: 54294, 54394
# Edge Added: 54294, 50694
# Edge Added: 54294, 54194
# Edge Added: 54294, 50594
# Edge Added: 54294, 57994
# Edge Added: 54294, 58094
# Edge Added: 54294, 57894
# Edge Added: 57994, 54394
# Edge Added: 57994, 54194
# Edge Added: 57994, 54294
# Edge Added: 57994, 58094
# Edge Added: 57994, 57894
# Edge Added: 57994, 61694
# Edge Added: 61594, 65094
# Edge Added: 61594, 65194
# Edge Added: 65094, 61594
# Edge Added: 65094, 68393
# Edge Added: 65094, 68293
# Edge Added: 65094, 65194
# Edge Added: 68393, 68293
# Edge Added: 68393, 65094
# Edge Added: 68393, 65194
# Edge Added: 68393, 71591
# Edge Added: 71591, 68393
# Edge Added: 71591, 68293
# Edge Added: 71591, 74387
# Edge Added: 74387, 71491
# Edge Added: 74387, 71591
# Edge Added: 74387, 76683
# Edge Added: 76683, 74387
# Edge Added: 76683, 78181
# Edge Added: 79280, 78381
# Edge Added: 79280, 79379
# Edge Added: 79280, 80479
# Edge Added: 83578, 83478
# Edge Added: 298, 198
# Edge Added: 298, 1198
# Edge Added: 298, 398
# Edge Added: 298, 98
# Edge Added: 1298, 2398
# Edge Added: 1298, 2298
# Edge Added: 1298, 398
# Edge Added: 1298, 2498
# Edge Added: 2398, 2298
# Edge Added: 2398, 1198
# Edge Added: 2398, 1298
# Edge Added: 2398, 2498
# Edge Added: 2398, 3698
# Edge Added: 2398, 3598
# Edge Added: 2398, 3798
# Edge Added: 3698, 2398
# Edge Added: 3698, 2298
# Edge Added: 3698, 2498
# Edge Added: 3698, 3598
# Edge Added: 3698, 3798
# Edge Added: 5298, 5198
# Edge Added: 5298, 6998
# Edge Added: 5298, 6898
# Edge Added: 5298, 7098
# Edge Added: 5298, 5398
# Edge Added: 6998, 5198
# Edge Added: 6998, 5298
# Edge Added: 6998, 6898
# Edge Added: 6998, 8698
# Edge Added: 6998, 8598
# Edge Added: 6998, 8798
# Edge Added: 6998, 7098
# Edge Added: 8698, 6998
# Edge Added: 8698, 6898
# Edge Added: 8698, 8598
# Edge Added: 8698, 8798
# Edge Added: 8698, 7098
# Edge Added: 8698, 10297
# Edge Added: 10397, 10497
# Edge Added: 12097, 13797
# Edge Added: 12097, 11997
# Edge Added: 12097, 13897
# Edge Added: 12097, 12197
# Edge Added: 13797, 13697
# Edge Added: 13797, 11997
# Edge Added: 13797, 12097
# Edge Added: 13797, 15497
# Edge Added: 15497, 13697
# Edge Added: 15497, 13797
# Edge Added: 15497, 17197
# Edge Added: 17297, 15597
# Edge Added: 19197, 19097
# Edge Added: 19197, 21097
# Edge Added: 19197, 19297
# Edge Added: 19197, 17397
# Edge Added: 21097, 19197
# Edge Added: 21097, 19097
# Edge Added: 21097, 19297
# Edge Added: 21097, 21197
# Edge Added: 21097, 23396
# Edge Added: 21097, 23496
# Edge Added: 23396, 21097
# Edge Added: 23396, 23496
# Edge Added: 25895, 25995
# Edge Added: 28894, 25795
# Edge Added: 28894, 32294
# Edge Added: 28894, 28794
# Edge Added: 28894, 28994
# Edge Added: 32394, 32494
# Edge Added: 32394, 35894
# Edge Added: 32394, 35994
# Edge Added: 35894, 32394
# Edge Added: 35894, 32494
# Edge Added: 35894, 39594
# Edge Added: 35894, 35994
# Edge Added: 35894, 39694
# Edge Added: 39594, 39494
# Edge Added: 39594, 35794
# Edge Added: 39594, 35894
# Edge Added: 39594, 43194
# Edge Added: 39594, 43094
# Edge Added: 39594, 39694
# Edge Added: 39594, 43294
# Edge Added: 43194, 39494
# Edge Added: 43194, 39594
# Edge Added: 43194, 46794
# Edge Added: 43194, 43094
# Edge Added: 43194, 46894
# Edge Added: 43194, 39694
# Edge Added: 43194, 43294
# Edge Added: 43194, 46994
# Edge Added: 46894, 43194
# Edge Added: 46894, 46794
# Edge Added: 46894, 43094
# Edge Added: 46894, 43294
# Edge Added: 46894, 46994
# Edge Added: 46894, 50694
# Edge Added: 46894, 50594
# Edge Added: 46894, 50794
# Edge Added: 50694, 46794
# Edge Added: 50694, 46894
# Edge Added: 50694, 46994
# Edge Added: 50694, 54394
# Edge Added: 50694, 50594
# Edge Added: 50694, 54294
# Edge Added: 50694, 50794
# Edge Added: 50694, 54494
# Edge Added: 54394, 50694
# Edge Added: 54394, 50594
# Edge Added: 54394, 54294
# Edge Added: 54394, 57994
# Edge Added: 54394, 58094
# Edge Added: 54394, 50794
# Edge Added: 54394, 54494
# Edge Added: 58094, 54394
# Edge Added: 58094, 54294
# Edge Added: 58094, 57994
# Edge Added: 58094, 54494
# Edge Added: 61694, 57994
# Edge Added: 61694, 61794
# Edge Added: 61694, 58194
# Edge Added: 61694, 65194
# Edge Added: 61694, 65294
# Edge Added: 65194, 61594
# Edge Added: 65194, 61694
# Edge Added: 65194, 61794
# Edge Added: 65194, 68393
# Edge Added: 65194, 65094
# Edge Added: 65194, 68593
# Edge Added: 65194, 65294
# Edge Added: 71691, 71791
# Edge Added: 71691, 74587
# Edge Added: 74487, 71791
# Edge Added: 74487, 76883
# Edge Added: 78381, 79280
# Edge Added: 78381, 79379
# Edge Added: 79379, 78381
# Edge Added: 79379, 79280
# Edge Added: 98, 298
# Edge Added: 398, 1298
# Edge Added: 398, 298
# Edge Added: 398, 1498
# Edge Added: 2498, 2398
# Edge Added: 2498, 1298
# Edge Added: 2498, 1498
# Edge Added: 2498, 2598
# Edge Added: 2498, 3698
# Edge Added: 2498, 3798
# Edge Added: 2498, 3898
# Edge Added: 3798, 2398
# Edge Added: 3798, 2498
# Edge Added: 3798, 2598
# Edge Added: 3798, 3698
# Edge Added: 3798, 3898
# Edge Added: 5398, 5298
# Edge Added: 5398, 7098
# Edge Added: 5398, 5498
# Edge Added: 5398, 7198
# Edge Added: 7098, 5298
# Edge Added: 7098, 6998
# Edge Added: 7098, 8698
# Edge Added: 7098, 8898
# Edge Added: 7098, 8798
# Edge Added: 7098, 5398
# Edge Added: 7098, 7198
# Edge Added: 8798, 6998
# Edge Added: 8798, 8698
# Edge Added: 8798, 8898
# Edge Added: 8798, 7098
# Edge Added: 8798, 7198
# Edge Added: 10497, 10397
# Edge Added: 12197, 12097
# Edge Added: 12197, 12297
# Edge Added: 12197, 13897
# Edge Added: 13897, 12097
# Edge Added: 13897, 12297
# Edge Added: 13897, 12197
# Edge Added: 13897, 15597
# Edge Added: 15597, 17297
# Edge Added: 15597, 13897
# Edge Added: 15597, 17497
# Edge Added: 15597, 17397
# Edge Added: 17397, 19197
# Edge Added: 17397, 15697
# Edge Added: 17397, 15597
# Edge Added: 17397, 19297
# Edge Added: 17397, 17497
# Edge Added: 17397, 19397
# Edge Added: 19297, 19197
# Edge Added: 19297, 21097
# Edge Added: 19297, 17497
# Edge Added: 19297, 17397
# Edge Added: 19297, 21297
# Edge Added: 19297, 19397
# Edge Added: 21197, 21097
# Edge Added: 21197, 19397
# Edge Added: 21197, 23496
# Edge Added: 23496, 21097
# Edge Added: 23496, 21197
# Edge Added: 23496, 21297
# Edge Added: 23496, 23396
# Edge Added: 25995, 25895
# Edge Added: 25995, 23596
# Edge Added: 25995, 26095
# Edge Added: 28994, 28894
# Edge Added: 28994, 29094
# Edge Added: 32494, 32394
# Edge Added: 32494, 32594
# Edge Added: 32494, 35894
# Edge Added: 32494, 35994
# Edge Added: 32494, 36094
# Edge Added: 35994, 32394
# Edge Added: 35994, 32494
# Edge Added: 35994, 32594
# Edge Added: 35994, 35894
# Edge Added: 35994, 36094
# Edge Added: 35994, 39694
# Edge Added: 39694, 35894
# Edge Added: 39694, 39594
# Edge Added: 39694, 43194
# Edge Added: 39694, 39794
# Edge Added: 39694, 35994
# Edge Added: 39694, 36094
# Edge Added: 39694, 43394
# Edge Added: 39694, 43294
# Edge Added: 43294, 39594
# Edge Added: 43294, 43194
# Edge Added: 43294, 46894
# Edge Added: 43294, 39794
# Edge Added: 43294, 39694
# Edge Added: 43294, 43394
# Edge Added: 43294, 47094
# Edge Added: 43294, 46994
# Edge Added: 46994, 43194
# Edge Added: 46994, 46894
# Edge Added: 46994, 43394
# Edge Added: 46994, 43294
# Edge Added: 46994, 47094
# Edge Added: 46994, 50694
# Edge Added: 46994, 50794
# Edge Added: 46994, 50894
# Edge Added: 50794, 46894
# Edge Added: 50794, 47094
# Edge Added: 50794, 46994
# Edge Added: 50794, 54394
# Edge Added: 50794, 50694
# Edge Added: 50794, 50894
# Edge Added: 50794, 54494
# Edge Added: 54494, 54394
# Edge Added: 54494, 50694
# Edge Added: 54494, 58094
# Edge Added: 54494, 50794
# Edge Added: 54494, 50894
# Edge Added: 58194, 61694
# Edge Added: 58194, 54594
# Edge Added: 58194, 58294
# Edge Added: 58194, 61894
# Edge Added: 58194, 61794
# Edge Added: 61794, 61694
# Edge Added: 61794, 58294
# Edge Added: 61794, 61894
# Edge Added: 61794, 58194
# Edge Added: 61794, 65194
# Edge Added: 61794, 65394
# Edge Added: 61794, 65294
# Edge Added: 65294, 61694
# Edge Added: 65294, 61894
# Edge Added: 65294, 61794
# Edge Added: 65294, 65194
# Edge Added: 65294, 68593
# Edge Added: 65294, 65394
# Edge Added: 65294, 68693
# Edge Added: 68593, 65194
# Edge Added: 68593, 65294
# Edge Added: 71791, 71691
# Edge Added: 71791, 74487
# Edge Added: 71791, 71891
# Edge Added: 74587, 71691
# Edge Added: 74587, 74687
# Edge Added: 76883, 74487
# Edge Added: 76883, 76983
# Edge Added: 1498, 398
# Edge Added: 1498, 2498
# Edge Added: 1498, 2598
# Edge Added: 1498, 2698
# Edge Added: 2598, 2498
# Edge Added: 2598, 1498
# Edge Added: 2598, 2698
# Edge Added: 2598, 3798
# Edge Added: 2598, 3898
# Edge Added: 3898, 2498
# Edge Added: 3898, 2598
# Edge Added: 3898, 2698
# Edge Added: 3898, 3798
# Edge Added: 3898, 5598
# Edge Added: 3898, 3998
# Edge Added: 5498, 5398
# Edge Added: 5498, 7298
# Edge Added: 7198, 8898
# Edge Added: 7198, 8798
# Edge Added: 7198, 7098
# Edge Added: 7198, 5398
# Edge Added: 7198, 8998
# Edge Added: 8898, 8798
# Edge Added: 8898, 7098
# Edge Added: 8898, 7198
# Edge Added: 8898, 7298
# Edge Added: 8898, 8998
# Edge Added: 10597, 10697
# Edge Added: 12297, 13897
# Edge Added: 12297, 12197
# Edge Added: 12297, 13997
# Edge Added: 13997, 12297
# Edge Added: 13997, 12397
# Edge Added: 13997, 15697
# Edge Added: 13997, 15797
# Edge Added: 15697, 13997
# Edge Added: 15697, 17497
# Edge Added: 15697, 17397
# Edge Added: 15697, 15797
# Edge Added: 15697, 17597
# Edge Added: 17497, 15697
# Edge Added: 17497, 15597
# Edge Added: 17497, 19297
# Edge Added: 17497, 17397
# Edge Added: 17497, 19397
# Edge Added: 17497, 17597
# Edge Added: 19397, 19297
# Edge Added: 19397, 17497
# Edge Added: 19397, 17397
# Edge Added: 19397, 21197
# Edge Added: 19397, 21297
# Edge Added: 19397, 19497
# Edge Added: 19397, 17597
# Edge Added: 21297, 19297
# Edge Added: 21297, 19397
# Edge Added: 21297, 19497
# Edge Added: 21297, 23496
# Edge Added: 21297, 23596
# Edge Added: 23596, 21297
# Edge Added: 23596, 25995
# Edge Added: 26095, 25995
# Edge Added: 29094, 28994
# Edge Added: 32594, 29194
# Edge Added: 32594, 32494
# Edge Added: 32594, 32694
# Edge Added: 32594, 35994
# Edge Added: 32594, 36094
# Edge Added: 36094, 32494
# Edge Added: 36094, 32594
# Edge Added: 36094, 32694
# Edge Added: 36094, 39794
# Edge Added: 36094, 35994
# Edge Added: 36094, 36194
# Edge Added: 36094, 39694
# Edge Added: 39794, 36194
# Edge Added: 39794, 36094
# Edge Added: 39794, 39894
# Edge Added: 39794, 39694
# Edge Added: 39794, 43394
# Edge Added: 39794, 43294
# Edge Added: 39794, 43494
# Edge Added: 43394, 39794
# Edge Added: 43394, 39894
# Edge Added: 43394, 39694
# Edge Added: 43394, 43294
# Edge Added: 43394, 43494
# Edge Added: 43394, 47094
# Edge Added: 43394, 46994
# Edge Added: 47094, 43394
# Edge Added: 47094, 43294
# Edge Added: 47094, 43494
# Edge Added: 47094, 46994
# Edge Added: 47094, 50794
# Edge Added: 47094, 50894
# Edge Added: 50894, 47194
# Edge Added: 50894, 47094
# Edge Added: 50894, 46994
# Edge Added: 50894, 50794
# Edge Added: 50894, 54494
# Edge Added: 50894, 54694
# Edge Added: 54594, 58394
# Edge Added: 54594, 58294
# Edge Added: 54594, 58194
# Edge Added: 58294, 54594
# Edge Added: 58294, 58394
# Edge Added: 58294, 61894
# Edge Added: 58294, 61794
# Edge Added: 58294, 61994
# Edge Added: 58294, 58194
# Edge Added: 61894, 58394
# Edge Added: 61894, 58294
# Edge Added: 61894, 61794
# Edge Added: 61894, 61994
# Edge Added: 61894, 58194
# Edge Added: 61894, 65394
# Edge Added: 61894, 65494
# Edge Added: 61894, 65294
# Edge Added: 65394, 61894
# Edge Added: 65394, 61794
# Edge Added: 65394, 61994
# Edge Added: 65394, 68793
# Edge Added: 65394, 65494
# Edge Added: 65394, 65294
# Edge Added: 65394, 68693
# Edge Added: 68693, 68793
# Edge Added: 68693, 65394
# Edge Added: 68693, 65494
# Edge Added: 68693, 65294
# Edge Added: 71891, 71991
# Edge Added: 71891, 71791
# Edge Added: 74687, 74587
# Edge Added: 76983, 76883
# Edge Added: 2698, 1498
# Edge Added: 2698, 2598
# Edge Added: 2698, 3898
# Edge Added: 3998, 3898
# Edge Added: 3998, 5598
# Edge Added: 3998, 4098
# Edge Added: 3998, 5698
# Edge Added: 5598, 3898
# Edge Added: 5598, 3998
# Edge Added: 5598, 4098
# Edge Added: 5598, 5698
# Edge Added: 7298, 8898
# Edge Added: 7298, 5498
# Edge Added: 7298, 8998
# Edge Added: 7298, 7398
# Edge Added: 7298, 9098
# Edge Added: 8998, 8898
# Edge Added: 8998, 7198
# Edge Added: 8998, 7298
# Edge Added: 8998, 9098
# Edge Added: 8998, 10697
# Edge Added: 10697, 8998
# Edge Added: 10697, 9098
# Edge Added: 10697, 10597
# Edge Added: 10697, 10797
# Edge Added: 12397, 13997
# Edge Added: 12397, 12497
# Edge Added: 14097, 14197
# Edge Added: 14097, 15797
# Edge Added: 15797, 13997
# Edge Added: 15797, 14097
# Edge Added: 15797, 15697
# Edge Added: 15797, 17597
# Edge Added: 15797, 15897
# Edge Added: 17597, 15697
# Edge Added: 17597, 17497
# Edge Added: 17597, 19397
# Edge Added: 17597, 15797
# Edge Added: 17597, 19497
# Edge Added: 17597, 15897
# Edge Added: 19497, 21297
# Edge Added: 19497, 19397
# Edge Added: 19497, 17597
# Edge Added: 23696, 26195
# Edge Added: 26195, 23696
# Edge Added: 26195, 29194
# Edge Added: 26195, 26295
# Edge Added: 26195, 29294
# Edge Added: 29194, 26195
# Edge Added: 29194, 32594
# Edge Added: 29194, 32694
# Edge Added: 29194, 26295
# Edge Added: 29194, 29294
# Edge Added: 29194, 32794
# Edge Added: 32694, 29194
# Edge Added: 32694, 32594
# Edge Added: 32694, 36094
# Edge Added: 32694, 29294
# Edge Added: 32694, 32794
# Edge Added: 36194, 39794
# Edge Added: 36194, 36094
# Edge Added: 36194, 39894
# Edge Added: 36194, 36294
# Edge Added: 36194, 39994
# Edge Added: 39894, 39794
# Edge Added: 39894, 36194
# Edge Added: 39894, 43394
# Edge Added: 39894, 36294
# Edge Added: 39894, 39994
# Edge Added: 43494, 39794
# Edge Added: 43494, 43394
# Edge Added: 43494, 47194
# Edge Added: 43494, 47094
# Edge Added: 43494, 39994
# Edge Added: 43494, 43594
# Edge Added: 47194, 43494
# Edge Added: 47194, 43594
# Edge Added: 47194, 47294
# Edge Added: 47194, 50994
# Edge Added: 47194, 50894
# Edge Added: 47194, 51094
# Edge Added: 50994, 47194
# Edge Added: 50994, 47294
# Edge Added: 50994, 54794
# Edge Added: 50994, 51094
# Edge Added: 54694, 50894
# Edge Added: 58394, 54594
# Edge Added: 58394, 58294
# Edge Added: 58394, 61894
# Edge Added: 58394, 61994
# Edge Added: 58394, 58494
# Edge Added: 58394, 62094
# Edge Added: 61994, 58394
# Edge Added: 61994, 58294
# Edge Added: 61994, 61894
# Edge Added: 61994, 58494
# Edge Added: 61994, 62094
# Edge Added: 61994, 65394
# Edge Added: 61994, 65494
# Edge Added: 61994, 65594
# Edge Added: 65494, 61894
# Edge Added: 65494, 61994
# Edge Added: 65494, 62094
# Edge Added: 65494, 68793
# Edge Added: 65494, 65394
# Edge Added: 65494, 68693
# Edge Added: 65494, 65594
# Edge Added: 68793, 65394
# Edge Added: 68793, 65494
# Edge Added: 68793, 68693
# Edge Added: 68793, 65594
# Edge Added: 71991, 71891
# Edge Added: 71991, 72091
# Edge Added: 71991, 74887
# Edge Added: 698, 1698
# Edge Added: 698, 1798
# Edge Added: 1698, 698
# Edge Added: 1698, 2798
# Edge Added: 2798, 1698
# Edge Added: 2798, 1798
# Edge Added: 2798, 4198
# Edge Added: 4098, 5598
# Edge Added: 4098, 3998
# Edge Added: 4098, 5698
# Edge Added: 5698, 5598
# Edge Added: 5698, 3998
# Edge Added: 5698, 4098
# Edge Added: 5698, 5798
# Edge Added: 7398, 7298
# Edge Added: 7398, 7498
# Edge Added: 7398, 9198
# Edge Added: 9098, 7298
# Edge Added: 9098, 8998
# Edge Added: 9098, 10697
# Edge Added: 9098, 9198
# Edge Added: 10797, 10697
# Edge Added: 10797, 9198
# Edge Added: 12497, 12397
# Edge Added: 14197, 14097
# Edge Added: 14197, 14297
# Edge Added: 14197, 12597
# Edge Added: 15897, 15797
# Edge Added: 15897, 17597
# Edge Added: 19597, 21497
# Edge Added: 21497, 19597
# Edge Added: 21497, 23896
# Edge Added: 21497, 23796
# Edge Added: 23796, 21497
# Edge Added: 23796, 23896
# Edge Added: 23796, 26395
# Edge Added: 23796, 26295
# Edge Added: 26295, 26195
# Edge Added: 26295, 29194
# Edge Added: 26295, 23896
# Edge Added: 26295, 23796
# Edge Added: 26295, 26395
# Edge Added: 26295, 29294
# Edge Added: 26295, 29394
# Edge Added: 29294, 26195
# Edge Added: 29294, 29194
# Edge Added: 29294, 32694
# Edge Added: 29294, 26395
# Edge Added: 29294, 26295
# Edge Added: 29294, 29394
# Edge Added: 29294, 32794
# Edge Added: 29294, 32894
# Edge Added: 32794, 29194
# Edge Added: 32794, 32694
# Edge Added: 32794, 29294
# Edge Added: 32794, 29394
# Edge Added: 32794, 32894
# Edge Added: 32794, 36394
# Edge Added: 36294, 36194
# Edge Added: 36294, 39894
# Edge Added: 36294, 39994
# Edge Added: 39994, 36194
# Edge Added: 39994, 39894
# Edge Added: 39994, 43494
# Edge Added: 39994, 36294
# Edge Added: 39994, 36394
# Edge Added: 43594, 43494
# Edge Added: 43594, 47194
# Edge Added: 43594, 40094
# Edge Added: 47294, 47194
# Edge Added: 47294, 47394
# Edge Added: 47294, 43694
# Edge Added: 47294, 50994
# Edge Added: 47294, 51094
# Edge Added: 47294, 51194
# Edge Added: 51094, 47194
# Edge Added: 51094, 47394
# Edge Added: 51094, 47294
# Edge Added: 51094, 50994
# Edge Added: 51094, 54894
# Edge Added: 51094, 51194
# Edge Added: 54794, 50994
# Edge Added: 54794, 54894
# Edge Added: 58494, 58394
# Edge Added: 58494, 61994
# Edge Added: 58494, 58594
# Edge Added: 58494, 62194
# Edge Added: 58494, 62094
# Edge Added: 62094, 58394
# Edge Added: 62094, 61994
# Edge Added: 62094, 58594
# Edge Added: 62094, 58494
# Edge Added: 62094, 62194
# Edge Added: 62094, 65494
# Edge Added: 62094, 65594
# Edge Added: 65594, 61994
# Edge Added: 65594, 62194
# Edge Added: 65594, 62094
# Edge Added: 65594, 68793
# Edge Added: 65594, 65494
# Edge Added: 65594, 68893
# Edge Added: 68893, 65594
# Edge Added: 72091, 71991
# Edge Added: 72091, 68993
# Edge Added: 72091, 74987
# Edge Added: 72091, 72191
# Edge Added: 74887, 71991
# Edge Added: 74887, 74987
# Edge Added: 74887, 72191
# Edge Added: 798, 898
# Edge Added: 1798, 698
# Edge Added: 1798, 2798
# Edge Added: 1798, 1898
# Edge Added: 4198, 2798
# Edge Added: 4198, 2998
# Edge Added: 5798, 5698
# Edge Added: 5798, 4298
# Edge Added: 5798, 7598
# Edge Added: 5798, 5898
# Edge Added: 5798, 7498
# Edge Added: 7498, 7398
# Edge Added: 7498, 5898
# Edge Added: 7498, 5798
# Edge Added: 7498, 9298
# Edge Added: 9198, 7398
# Edge Added: 9198, 9098
# Edge Added: 9198, 10797
# Edge Added: 9198, 9298
# Edge Added: 10897, 9298
# Edge Added: 12597, 14197
# Edge Added: 12597, 14297
# Edge Added: 14297, 14197
# Edge Added: 14297, 12597
# Edge Added: 17797, 19697
# Edge Added: 17797, 19797
# Edge Added: 19697, 17797
# Edge Added: 19697, 21597
# Edge Added: 19697, 19797
# Edge Added: 19697, 21697
# Edge Added: 21597, 19697
# Edge Added: 21597, 19797
# Edge Added: 21597, 21697
# Edge Added: 21597, 23896
# Edge Added: 21597, 23996
# Edge Added: 23896, 21497
# Edge Added: 23896, 21597
# Edge Added: 23896, 26495
# Edge Added: 23896, 23796
# Edge Added: 23896, 26395
# Edge Added: 23896, 26295
# Edge Added: 26395, 23896
# Edge Added: 26395, 23796
# Edge Added: 26395, 26295
# Edge Added: 26395, 29294
# Edge Added: 26395, 29394
# Edge Added: 26395, 29494
# Edge Added: 29394, 26395
# Edge Added: 29394, 26295
# Edge Added: 29394, 29294
# Edge Added: 29394, 29494
# Edge Added: 29394, 32994
# Edge Added: 29394, 32794
# Edge Added: 29394, 32894
# Edge Added: 32894, 29294
# Edge Added: 32894, 29394
# Edge Added: 32894, 29494
# Edge Added: 32894, 32994
# Edge Added: 32894, 32794
# Edge Added: 32894, 36394
# Edge Added: 32894, 36494
# Edge Added: 36394, 32994
# Edge Added: 36394, 32794
# Edge Added: 36394, 32894
# Edge Added: 36394, 36494
# Edge Added: 36394, 39994
# Edge Added: 40094, 40194
# Edge Added: 40094, 43594
# Edge Added: 40094, 43794
# Edge Added: 40094, 43694
# Edge Added: 43694, 40194
# Edge Added: 43694, 40094
# Edge Added: 43694, 43794
# Edge Added: 43694, 47494
# Edge Added: 43694, 47394
# Edge Added: 43694, 47294
# Edge Added: 47394, 43794
# Edge Added: 47394, 47494
# Edge Added: 47394, 47294
# Edge Added: 47394, 43694
# Edge Added: 47394, 51294
# Edge Added: 47394, 51094
# Edge Added: 47394, 51194
# Edge Added: 51194, 47494
# Edge Added: 51194, 47394
# Edge Added: 51194, 47294
# Edge Added: 51194, 54894
# Edge Added: 51194, 51294
# Edge Added: 51194, 51094
# Edge Added: 51194, 54994
# Edge Added: 54894, 54794
# Edge Added: 54894, 51294
# Edge Added: 54894, 51094
# Edge Added: 54894, 51194
# Edge Added: 54894, 54994
# Edge Added: 54894, 58694
# Edge Added: 58594, 58494
# Edge Added: 58594, 62194
# Edge Added: 58594, 62094
# Edge Added: 62194, 58594
# Edge Added: 62194, 58494
# Edge Added: 62194, 62094
# Edge Added: 62194, 65694
# Edge Added: 62194, 65594
# Edge Added: 65694, 62194
# Edge Added: 65694, 68993
# Edge Added: 68993, 65694
# Edge Added: 68993, 65794
# Edge Added: 68993, 72091
# Edge Added: 72191, 69093
# Edge Added: 72191, 74987
# Edge Added: 72191, 72091
# Edge Added: 72191, 72291
# Edge Added: 72191, 74887
# Edge Added: 74987, 72191
# Edge Added: 74987, 72091
# Edge Added: 74987, 72291
# Edge Added: 74987, 74887
# Edge Added: 898, 798
# Edge Added: 1898, 1798
# Edge Added: 1898, 2998
# Edge Added: 2998, 1998
# Edge Added: 2998, 1898
# Edge Added: 2998, 4198
# Edge Added: 4298, 3098
# Edge Added: 4298, 4398
# Edge Added: 4298, 5898
# Edge Added: 4298, 5798
# Edge Added: 4298, 5998
# Edge Added: 5898, 4398
# Edge Added: 5898, 4298
# Edge Added: 5898, 7598
# Edge Added: 5898, 7698
# Edge Added: 5898, 5798
# Edge Added: 5898, 5998
# Edge Added: 5898, 7498
# Edge Added: 7598, 5898
# Edge Added: 7598, 7698
# Edge Added: 7598, 5798
# Edge Added: 7598, 5998
# Edge Added: 9298, 7498
# Edge Added: 9298, 9398
# Edge Added: 9298, 9198
# Edge Added: 9298, 10897
# Edge Added: 10997, 11097
# Edge Added: 10997, 12697
# Edge Added: 10997, 12797
# Edge Added: 12697, 11097
# Edge Added: 12697, 10997
# Edge Added: 12697, 14497
# Edge Added: 12697, 12797
# Edge Added: 14397, 16197
# Edge Added: 14397, 14497
# Edge Added: 16097, 16197
# Edge Added: 16097, 14497
# Edge Added: 17897, 16197
# Edge Added: 17897, 19797
# Edge Added: 17897, 17997
# Edge Added: 19797, 17797
# Edge Added: 19797, 21597
# Edge Added: 19797, 19697
# Edge Added: 19797, 17897
# Edge Added: 19797, 21697
# Edge Added: 19797, 17997
# Edge Added: 19797, 21797
# Edge Added: 21697, 21597
# Edge Added: 21697, 19697
# Edge Added: 21697, 19797
# Edge Added: 21697, 21797
# Edge Added: 21697, 23996
# Edge Added: 21697, 24096
# Edge Added: 23996, 21597
# Edge Added: 23996, 21697
# Edge Added: 23996, 21797
# Edge Added: 23996, 26495
# Edge Added: 23996, 24096
# Edge Added: 26495, 23896
# Edge Added: 26495, 23996
# Edge Added: 26495, 24096
# Edge Added: 26495, 26595
# Edge Added: 29494, 26395
# Edge Added: 29494, 29394
# Edge Added: 29494, 32994
# Edge Added: 29494, 32894
# Edge Added: 29494, 29594
# Edge Added: 29494, 33094
# Edge Added: 32994, 29394
# Edge Added: 32994, 29494
# Edge Added: 32994, 32894
# Edge Added: 32994, 36394
# Edge Added: 32994, 36494
# Edge Added: 32994, 29594
# Edge Added: 32994, 33094
# Edge Added: 32994, 36594
# Edge Added: 36494, 32994
# Edge Added: 36494, 32894
# Edge Added: 36494, 36394
# Edge Added: 36494, 33094
# Edge Added: 36494, 36594
# Edge Added: 40194, 40094
# Edge Added: 40194, 43794
# Edge Added: 40194, 43694
# Edge Added: 40194, 40294
# Edge Added: 40194, 43894
# Edge Added: 43794, 40194
# Edge Added: 43794, 40094
# Edge Added: 43794, 47494
# Edge Added: 43794, 47394
# Edge Added: 43794, 43694
# Edge Added: 43794, 40294
# Edge Added: 43794, 47594
# Edge Added: 43794, 43894
# Edge Added: 47494, 43794
# Edge Added: 47494, 47394
# Edge Added: 47494, 43694
# Edge Added: 47494, 47594
# Edge Added: 47494, 43894
# Edge Added: 47494, 51294
# Edge Added: 47494, 51194
# Edge Added: 47494, 51394
# Edge Added: 51294, 47494
# Edge Added: 51294, 47394
# Edge Added: 51294, 47594
# Edge Added: 51294, 54894
# Edge Added: 51294, 51194
# Edge Added: 51294, 54994
# Edge Added: 51294, 55094
# Edge Added: 51294, 51394
# Edge Added: 54994, 54894
# Edge Added: 54994, 51294
# Edge Added: 54994, 51194
# Edge Added: 54994, 58794
# Edge Added: 54994, 55094
# Edge Added: 54994, 51394
# Edge Added: 58694, 54894
# Edge Added: 58694, 62294
# Edge Added: 58694, 62394
# Edge Added: 62294, 58694
# Edge Added: 62294, 62394
# Edge Added: 62294, 65794
# Edge Added: 62294, 65894
# Edge Added: 65794, 62294
# Edge Added: 65794, 62394
# Edge Added: 65794, 68993
# Edge Added: 65794, 69093
# Edge Added: 65794, 65894
# Edge Added: 69093, 65794
# Edge Added: 69093, 72191
# Edge Added: 69093, 69193
# Edge Added: 69093, 65894
# Edge Added: 72291, 74987
# Edge Added: 72291, 72191
# Edge Added: 72291, 69193
# Edge Added: 72291, 72391
# Edge Added: 1998, 2998
# Edge Added: 3098, 4398
# Edge Added: 3098, 4298
# Edge Added: 3098, 4498
# Edge Added: 4398, 3098
# Edge Added: 4398, 4298
# Edge Added: 4398, 5898
# Edge Added: 4398, 5998
# Edge Added: 4398, 4498
# Edge Added: 4398, 6098
# Edge Added: 5998, 4398
# Edge Added: 5998, 4298
# Edge Added: 5998, 7598
# Edge Added: 5998, 5898
# Edge Added: 5998, 7698
# Edge Added: 5998, 4498
# Edge Added: 5998, 6098
# Edge Added: 5998, 7798
# Edge Added: 7698, 7598
# Edge Added: 7698, 5898
# Edge Added: 7698, 5998
# Edge Added: 7698, 6098
# Edge Added: 7698, 7798
# Edge Added: 9398, 9298
# Edge Added: 9398, 7798
# Edge Added: 9398, 9498
# Edge Added: 11097, 10997
# Edge Added: 11097, 11197
# Edge Added: 11097, 12697
# Edge Added: 11097, 12797
# Edge Added: 11097, 12897
# Edge Added: 12797, 11097
# Edge Added: 12797, 10997
# Edge Added: 12797, 12697
# Edge Added: 12797, 14497
# Edge Added: 12797, 14597
# Edge Added: 14497, 14397
# Edge Added: 14497, 12697
# Edge Added: 14497, 16097
# Edge Added: 14497, 16197
# Edge Added: 14497, 12797
# Edge Added: 14497, 14597
# Edge Added: 14497, 12897
# Edge Added: 14497, 16297
# Edge Added: 16197, 14397
# Edge Added: 16197, 16097
# Edge Added: 16197, 14497
# Edge Added: 16197, 14597
# Edge Added: 16197, 16297
# Edge Added: 16197, 17897
# Edge Added: 16197, 17997
# Edge Added: 16197, 18097
# Edge Added: 17997, 16197
# Edge Added: 17997, 16297
# Edge Added: 17997, 17897
# Edge Added: 17997, 19797
# Edge Added: 17997, 18097
# Edge Added: 19897, 21897
# Edge Added: 21797, 19797
# Edge Added: 21797, 21697
# Edge Added: 21797, 21897
# Edge Added: 21797, 23996
# Edge Added: 21797, 24196
# Edge Added: 21797, 24096
# Edge Added: 24096, 21697
# Edge Added: 24096, 21897
# Edge Added: 24096, 21797
# Edge Added: 24096, 26495
# Edge Added: 24096, 23996
# Edge Added: 24096, 24196
# Edge Added: 26595, 26495
# Edge Added: 26595, 24196
# Edge Added: 26595, 26695
# Edge Added: 29594, 29494
# Edge Added: 29594, 32994
# Edge Added: 29594, 29694
# Edge Added: 29594, 26695
# Edge Added: 29594, 33094
# Edge Added: 29594, 33194
# Edge Added: 33094, 29494
# Edge Added: 33094, 32994
# Edge Added: 33094, 36494
# Edge Added: 33094, 29694
# Edge Added: 33094, 29594
# Edge Added: 33094, 36594
# Edge Added: 33094, 33194
# Edge Added: 33094, 36694
# Edge Added: 36594, 32994
# Edge Added: 36594, 36494
# Edge Added: 36594, 33094
# Edge Added: 36594, 33194
# Edge Added: 36594, 36694
# Edge Added: 40294, 40194
# Edge Added: 40294, 43794
# Edge Added: 40294, 40394
# Edge Added: 40294, 43894
# Edge Added: 43894, 40194
# Edge Added: 43894, 43794
# Edge Added: 43894, 47494
# Edge Added: 43894, 40394
# Edge Added: 43894, 40294
# Edge Added: 43894, 47594
# Edge Added: 43894, 47694
# Edge Added: 43894, 43994
# Edge Added: 47594, 43794
# Edge Added: 47594, 47494
# Edge Added: 47594, 43894
# Edge Added: 47594, 47694
# Edge Added: 47594, 43994
# Edge Added: 47594, 51294
# Edge Added: 47594, 51394
# Edge Added: 47594, 51494
# Edge Added: 51394, 47494
# Edge Added: 51394, 47594
# Edge Added: 51394, 47694
# Edge Added: 51394, 51294
# Edge Added: 51394, 54994
# Edge Added: 51394, 55094
# Edge Added: 51394, 51494
# Edge Added: 51394, 55194
# Edge Added: 55094, 51294
# Edge Added: 55094, 54994
# Edge Added: 55094, 58794
# Edge Added: 55094, 51394
# Edge Added: 55094, 51494
# Edge Added: 55094, 58894
# Edge Added: 55094, 55194
# Edge Added: 58794, 54994
# Edge Added: 58794, 62494
# Edge Added: 58794, 62394
# Edge Added: 58794, 55094
# Edge Added: 58794, 58894
# Edge Added: 58794, 55194
# Edge Added: 62394, 58694
# Edge Added: 62394, 62294
# Edge Added: 62394, 62494
# Edge Added: 62394, 58794
# Edge Added: 62394, 58894
# Edge Added: 62394, 65794
# Edge Added: 62394, 65894
# Edge Added: 62394, 65994
# Edge Added: 65894, 62294
# Edge Added: 65894, 62494
# Edge Added: 65894, 62394
# Edge Added: 65894, 65794
# Edge Added: 65894, 69093
# Edge Added: 65894, 69193
# Edge Added: 65894, 65994
# Edge Added: 65894, 69293
# Edge Added: 69193, 69093
# Edge Added: 69193, 72291
# Edge Added: 69193, 65894
# Edge Added: 69193, 72391
# Edge Added: 69193, 65994
# Edge Added: 69193, 69293
# Edge Added: 69193, 72491
# Edge Added: 72391, 72291
# Edge Added: 72391, 69193
# Edge Added: 72391, 69293
# Edge Added: 72391, 72491
# Edge Added: 4498, 3098
# Edge Added: 4498, 4398
# Edge Added: 4498, 5998
# Edge Added: 4498, 4598
# Edge Added: 4498, 6098
# Edge Added: 6098, 4398
# Edge Added: 6098, 7698
# Edge Added: 6098, 5998
# Edge Added: 6098, 4598
# Edge Added: 6098, 4498
# Edge Added: 6098, 7798
# Edge Added: 7798, 7698
# Edge Added: 7798, 5998
# Edge Added: 7798, 9398
# Edge Added: 7798, 6198
# Edge Added: 7798, 6098
# Edge Added: 9498, 9398
# Edge Added: 9498, 7898
# Edge Added: 11197, 11097
# Edge Added: 11197, 9598
# Edge Added: 11197, 11297
# Edge Added: 11197, 12897
# Edge Added: 11197, 12997
# Edge Added: 12897, 11097
# Edge Added: 12897, 11197
# Edge Added: 12897, 11297
# Edge Added: 12897, 14497
# Edge Added: 12897, 14597
# Edge Added: 12897, 12997
# Edge Added: 12897, 14697
# Edge Added: 14597, 16197
# Edge Added: 14597, 14497
# Edge Added: 14597, 12797
# Edge Added: 14597, 12897
# Edge Added: 14597, 16297
# Edge Added: 14597, 12997
# Edge Added: 14597, 16397
# Edge Added: 14597, 14697
# Edge Added: 16297, 16197
# Edge Added: 16297, 14497
# Edge Added: 16297, 14597
# Edge Added: 16297, 17997
# Edge Added: 16297, 18097
# Edge Added: 16297, 16397
# Edge Added: 16297, 14697
# Edge Added: 16297, 18197
# Edge Added: 18097, 16197
# Edge Added: 18097, 16297
# Edge Added: 18097, 17997
# Edge Added: 18097, 16397
# Edge Added: 18097, 20097
# Edge Added: 18097, 18197
# Edge Added: 21897, 21797
# Edge Added: 21897, 19897
# Edge Added: 21897, 21997
# Edge Added: 21897, 20097
# Edge Added: 21897, 24196
# Edge Added: 21897, 24096
# Edge Added: 21897, 24296
# Edge Added: 24196, 21897
# Edge Added: 24196, 21797
# Edge Added: 24196, 21997
# Edge Added: 24196, 24096
# Edge Added: 24196, 26595
# Edge Added: 24196, 24296
# Edge Added: 24196, 26795
# Edge Added: 26695, 29694
# Edge Added: 26695, 29594
# Edge Added: 26695, 26595
# Edge Added: 26695, 29794
# Edge Added: 29694, 29594
# Edge Added: 29694, 26695
# Edge Added: 29694, 33094
# Edge Added: 29694, 33194
# Edge Added: 29694, 33294
# Edge Added: 33194, 29694
# Edge Added: 33194, 29594
# Edge Added: 33194, 33094
# Edge Added: 33194, 36594
# Edge Added: 33194, 36694
# Edge Added: 33194, 36794
# Edge Added: 33194, 33294
# Edge Added: 36694, 33094
# Edge Added: 36694, 36594
# Edge Added: 36694, 33194
# Edge Added: 36694, 36794
# Edge Added: 36694, 33294
# Edge Added: 40394, 40294
# Edge Added: 40394, 43894
# Edge Added: 40394, 43994
# Edge Added: 40394, 40494
# Edge Added: 40394, 44094
# Edge Added: 43994, 40394
# Edge Added: 43994, 47594
# Edge Added: 43994, 43894
# Edge Added: 43994, 47694
# Edge Added: 43994, 40494
# Edge Added: 43994, 44094
# Edge Added: 43994, 47794
# Edge Added: 47694, 47594
# Edge Added: 47694, 43894
# Edge Added: 47694, 43994
# Edge Added: 47694, 44094
# Edge Added: 47694, 47794
# Edge Added: 47694, 51394
# Edge Added: 47694, 51494
# Edge Added: 47694, 51594
# Edge Added: 51494, 47594
# Edge Added: 51494, 47694
# Edge Added: 51494, 47794
# Edge Added: 51494, 55094
# Edge Added: 51494, 51394
# Edge Added: 51494, 55194
# Edge Added: 51494, 51594
# Edge Added: 51494, 55294
# Edge Added: 55194, 58794
# Edge Added: 55194, 55094
# Edge Added: 55194, 51394
# Edge Added: 55194, 51494
# Edge Added: 55194, 58894
# Edge Added: 55194, 51594
# Edge Added: 55194, 55294
# Edge Added: 55194, 58994
# Edge Added: 58894, 62494
# Edge Added: 58894, 62394
# Edge Added: 58894, 58794
# Edge Added: 58894, 55094
# Edge Added: 58894, 55194
# Edge Added: 58894, 62594
# Edge Added: 58894, 55294
# Edge Added: 58894, 58994
# Edge Added: 62494, 62394
# Edge Added: 62494, 58794
# Edge Added: 62494, 58894
# Edge Added: 62494, 62594
# Edge Added: 62494, 58994
# Edge Added: 62494, 65894
# Edge Added: 62494, 65994
# Edge Added: 62494, 66094
# Edge Added: 65994, 62494
# Edge Added: 65994, 62394
# Edge Added: 65994, 62594
# Edge Added: 65994, 69193
# Edge Added: 65994, 65894
# Edge Added: 65994, 69293
# Edge Added: 65994, 69393
# Edge Added: 65994, 66094
# Edge Added: 69293, 69193
# Edge Added: 69293, 65894
# Edge Added: 69293, 72391
# Edge Added: 69293, 65994
# Edge Added: 69293, 72491
# Edge Added: 69293, 72591
# Edge Added: 69293, 69393
# Edge Added: 69293, 66094
# Edge Added: 72491, 69193
# Edge Added: 72491, 72391
# Edge Added: 72491, 69293
# Edge Added: 72491, 72591
# Edge Added: 72491, 69393
# Edge Added: 4598, 6198
# Edge Added: 4598, 4498
# Edge Added: 4598, 6098
# Edge Added: 6198, 4598
# Edge Added: 6198, 4698
# Edge Added: 6198, 7898
# Edge Added: 6198, 7798
# Edge Added: 7898, 6198
# Edge Added: 7898, 6298
# Edge Added: 7898, 9498
# Edge Added: 9598, 11197
# Edge Added: 9598, 11297
# Edge Added: 9598, 11397
# Edge Added: 9598, 7998
# Edge Added: 11297, 9598
# Edge Added: 11297, 11197
# Edge Added: 11297, 11397
# Edge Added: 11297, 9698
# Edge Added: 11297, 12897
# Edge Added: 11297, 13097
# Edge Added: 11297, 12997
# Edge Added: 12997, 11197
# Edge Added: 12997, 11297
# Edge Added: 12997, 11397
# Edge Added: 12997, 14597
# Edge Added: 12997, 12897
# Edge Added: 12997, 13097
# Edge Added: 12997, 14797
# Edge Added: 12997, 14697
# Edge Added: 14697, 14597
# Edge Added: 14697, 12897
# Edge Added: 14697, 16297
# Edge Added: 14697, 13097
# Edge Added: 14697, 12997
# Edge Added: 14697, 16397
# Edge Added: 14697, 14797
# Edge Added: 14697, 16497
# Edge Added: 16397, 14597
# Edge Added: 16397, 16297
# Edge Added: 16397, 18097
# Edge Added: 16397, 14797
# Edge Added: 16397, 14697
# Edge Added: 16397, 16497
# Edge Added: 16397, 18197
# Edge Added: 16397, 18297
# Edge Added: 18197, 16297
# Edge Added: 18197, 18097
# Edge Added: 18197, 16397
# Edge Added: 18197, 16497
# Edge Added: 18197, 20097
# Edge Added: 20097, 21897
# Edge Added: 20097, 18097
# Edge Added: 20097, 21997
# Edge Added: 20097, 20197
# Edge Added: 20097, 18197
# Edge Added: 20097, 18297
# Edge Added: 20097, 22097
# Edge Added: 21997, 21897
# Edge Added: 21997, 20197
# Edge Added: 21997, 20097
# Edge Added: 21997, 22097
# Edge Added: 21997, 24196
# Edge Added: 21997, 24296
# Edge Added: 21997, 24396
# Edge Added: 24296, 21897
# Edge Added: 24296, 21997
# Edge Added: 24296, 22097
# Edge Added: 24296, 24196
# Edge Added: 24296, 26795
# Edge Added: 24296, 24396
# Edge Added: 24296, 26895
# Edge Added: 26795, 24196
# Edge Added: 26795, 24296
# Edge Added: 26795, 24396
# Edge Added: 26795, 26895
# Edge Added: 26795, 29894
# Edge Added: 29794, 26695
# Edge Added: 33294, 29694
# Edge Added: 33294, 33194
# Edge Added: 33294, 36694
# Edge Added: 33294, 36794
# Edge Added: 36794, 33194
# Edge Added: 36794, 36694
# Edge Added: 36794, 33294
# Edge Added: 40494, 40394
# Edge Added: 40494, 43994
# Edge Added: 40494, 44094
# Edge Added: 40494, 36894
# Edge Added: 40494, 44194
# Edge Added: 44094, 40394
# Edge Added: 44094, 47694
# Edge Added: 44094, 43994
# Edge Added: 44094, 40494
# Edge Added: 44094, 47794
# Edge Added: 44094, 47894
# Edge Added: 44094, 44194
# Edge Added: 47794, 47694
# Edge Added: 47794, 43994
# Edge Added: 47794, 44094
# Edge Added: 47794, 47894
# Edge Added: 47794, 44194
# Edge Added: 47794, 51494
# Edge Added: 47794, 51594
# Edge Added: 47794, 51694
# Edge Added: 51594, 47694
# Edge Added: 51594, 47794
# Edge Added: 51594, 47894
# Edge Added: 51594, 51494
# Edge Added: 51594, 55194
# Edge Added: 51594, 55294
# Edge Added: 51594, 51694
# Edge Added: 51594, 55394
# Edge Added: 55294, 51494
# Edge Added: 55294, 58894
# Edge Added: 55294, 55194
# Edge Added: 55294, 51594
# Edge Added: 55294, 51694
# Edge Added: 55294, 59094
# Edge Added: 55294, 55394
# Edge Added: 55294, 58994
# Edge Added: 58994, 62494
# Edge Added: 58994, 58894
# Edge Added: 58994, 55194
# Edge Added: 58994, 62594
# Edge Added: 58994, 55294
# Edge Added: 58994, 59094
# Edge Added: 58994, 62694
# Edge Added: 58994, 55394
# Edge Added: 62594, 62494
# Edge Added: 62594, 58894
# Edge Added: 62594, 59094
# Edge Added: 62594, 62694
# Edge Added: 62594, 58994
# Edge Added: 62594, 65994
# Edge Added: 62594, 66094
# Edge Added: 62594, 66194
# Edge Added: 66094, 62494
# Edge Added: 66094, 62594
# Edge Added: 66094, 62694
# Edge Added: 66094, 65994
# Edge Added: 66094, 69293
# Edge Added: 66094, 69393
# Edge Added: 66094, 69493
# Edge Added: 66094, 66194
# Edge Added: 69393, 65994
# Edge Added: 69393, 69293
# Edge Added: 69393, 72491
# Edge Added: 69393, 72591
# Edge Added: 69393, 66094
# Edge Added: 69393, 69493
# Edge Added: 69393, 66194
# Edge Added: 72591, 69293
# Edge Added: 72591, 72491
# Edge Added: 72591, 69393
# Edge Added: 72591, 69493
# Edge Added: 4698, 6198
# Edge Added: 4698, 6298
# Edge Added: 6298, 4698
# Edge Added: 6298, 6398
# Edge Added: 6298, 7898
# Edge Added: 6298, 7998
# Edge Added: 6298, 8098
# Edge Added: 7998, 6298
# Edge Added: 7998, 6398
# Edge Added: 7998, 9598
# Edge Added: 7998, 8098
# Edge Added: 9698, 11297
# Edge Added: 9698, 11397
# Edge Added: 9698, 9798
# Edge Added: 9698, 11497
# Edge Added: 11397, 9598
# Edge Added: 11397, 11297
# Edge Added: 11397, 9698
# Edge Added: 11397, 9798
# Edge Added: 11397, 11497
# Edge Added: 11397, 13097
# Edge Added: 11397, 12997
# Edge Added: 13097, 11297
# Edge Added: 13097, 11397
# Edge Added: 13097, 11497
# Edge Added: 13097, 12997
# Edge Added: 13097, 14797
# Edge Added: 13097, 14697
# Edge Added: 14797, 13097
# Edge Added: 14797, 12997
# Edge Added: 14797, 16397
# Edge Added: 14797, 14697
# Edge Added: 14797, 16497
# Edge Added: 14797, 16597
# Edge Added: 16497, 16397
# Edge Added: 16497, 14797
# Edge Added: 16497, 14697
# Edge Added: 16497, 16597
# Edge Added: 16497, 18197
# Edge Added: 16497, 18297
# Edge Added: 16497, 18397
# Edge Added: 18297, 16397
# Edge Added: 18297, 16497
# Edge Added: 18297, 20197
# Edge Added: 18297, 20097
# Edge Added: 18297, 20297
# Edge Added: 18297, 18397
# Edge Added: 20197, 21997
# Edge Added: 20197, 20097
# Edge Added: 20197, 18297
# Edge Added: 20197, 22097
# Edge Added: 20197, 22197
# Edge Added: 20197, 20297
# Edge Added: 20197, 18397
# Edge Added: 22097, 21997
# Edge Added: 22097, 20197
# Edge Added: 22097, 20097
# Edge Added: 22097, 22197
# Edge Added: 22097, 20297
# Edge Added: 22097, 24296
# Edge Added: 22097, 24396
# Edge Added: 22097, 24496
# Edge Added: 24396, 21997
# Edge Added: 24396, 22097
# Edge Added: 24396, 24296
# Edge Added: 24396, 26795
# Edge Added: 24396, 26895
# Edge Added: 24396, 26995
# Edge Added: 24396, 24496
# Edge Added: 26895, 24296
# Edge Added: 26895, 26795
# Edge Added: 26895, 24396
# Edge Added: 26895, 29894
# Edge Added: 26895, 26995
# Edge Added: 26895, 24496
# Edge Added: 26895, 29994
# Edge Added: 29894, 26795
# Edge Added: 29894, 26895
# Edge Added: 29894, 26995
# Edge Added: 29894, 29994
# Edge Added: 29894, 33394
# Edge Added: 33394, 29894
# Edge Added: 33394, 29994
# Edge Added: 33394, 36894
# Edge Added: 36894, 40494
# Edge Added: 36894, 33394
# Edge Added: 44194, 40494
# Edge Added: 44194, 44094
# Edge Added: 44194, 47794
# Edge Added: 44194, 47994
# Edge Added: 44194, 47894
# Edge Added: 47894, 44094
# Edge Added: 47894, 47794
# Edge Added: 47894, 47994
# Edge Added: 47894, 44194
# Edge Added: 47894, 51594
# Edge Added: 47894, 51694
# Edge Added: 51694, 47794
# Edge Added: 51694, 47994
# Edge Added: 51694, 47894
# Edge Added: 51694, 51594
# Edge Added: 51694, 55294
# Edge Added: 51694, 55394
# Edge Added: 55394, 51594
# Edge Added: 55394, 55294
# Edge Added: 55394, 51694
# Edge Added: 55394, 59094
# Edge Added: 55394, 58994
# Edge Added: 59094, 62594
# Edge Added: 59094, 55294
# Edge Added: 59094, 62694
# Edge Added: 59094, 55394
# Edge Added: 59094, 58994
# Edge Added: 62694, 62594
# Edge Added: 62694, 59094
# Edge Added: 62694, 58994
# Edge Added: 62694, 66094
# Edge Added: 62694, 66194
# Edge Added: 66194, 62594
# Edge Added: 66194, 62694
# Edge Added: 66194, 69393
# Edge Added: 66194, 66094
# Edge Added: 66194, 69493
# Edge Added: 69493, 72591
# Edge Added: 69493, 69393
# Edge Added: 69493, 66094
# Edge Added: 69493, 66194
# Edge Added: 6398, 6298
# Edge Added: 6398, 7998
# Edge Added: 6398, 8098
# Edge Added: 6398, 8198
# Edge Added: 8098, 6298
# Edge Added: 8098, 6398
# Edge Added: 8098, 7998
# Edge Added: 8098, 9798
# Edge Added: 8098, 8198
# Edge Added: 9798, 11397
# Edge Added: 9798, 9698
# Edge Added: 9798, 9898
# Edge Added: 9798, 8098
# Edge Added: 9798, 11497
# Edge Added: 9798, 11597
# Edge Added: 9798, 8198
# Edge Added: 11497, 11397
# Edge Added: 11497, 9698
# Edge Added: 11497, 9898
# Edge Added: 11497, 9798
# Edge Added: 11497, 11597
# Edge Added: 11497, 13097
# Edge Added: 13197, 14897
# Edge Added: 13197, 13297
# Edge Added: 14897, 13197
# Edge Added: 16597, 14797
# Edge Added: 16597, 16497
# Edge Added: 16597, 18497
# Edge Added: 18397, 16497
# Edge Added: 18397, 20197
# Edge Added: 18397, 18297
# Edge Added: 18397, 20297
# Edge Added: 18397, 18497
# Edge Added: 20297, 20197
# Edge Added: 20297, 18297
# Edge Added: 20297, 22097
# Edge Added: 20297, 22197
# Edge Added: 20297, 18397
# Edge Added: 20297, 18497
# Edge Added: 22197, 20197
# Edge Added: 22197, 22097
# Edge Added: 22197, 20297
# Edge Added: 24496, 22097
# Edge Added: 24496, 22297
# Edge Added: 24496, 24396
# Edge Added: 24496, 26895
# Edge Added: 24496, 26995
# Edge Added: 24496, 24596
# Edge Added: 26995, 24396
# Edge Added: 26995, 26895
# Edge Added: 26995, 29894
# Edge Added: 26995, 24496
# Edge Added: 26995, 29994
# Edge Added: 26995, 24596
# Edge Added: 29994, 26895
# Edge Added: 29994, 29894
# Edge Added: 29994, 26995
# Edge Added: 29994, 33394
# Edge Added: 47994, 47894
# Edge Added: 47994, 44194
# Edge Added: 47994, 51694
# ...
# Edge Added: 19798, 19898
# Edge Added: 21698, 19698
# Edge Added: 21698, 19798
# Edge Added: 21698, 21798
# Edge Added: 21698, 19898
# Edge Added: 21698, 23997
# Edge Added: 21698, 24097
# Edge Added: 23997, 21598
# Edge Added: 23997, 21698
# Edge Added: 23997, 24097
# Edge Added: 26496, 23897
# Edge Added: 26496, 26396
# Edge Added: 26496, 26596
# Edge Added: 29495, 29395
# Edge Added: 29495, 32995
# Edge Added: 29495, 29595
# Edge Added: 29495, 33095
# Edge Added: 32995, 29395
# Edge Added: 32995, 29495
# Edge Added: 32995, 32895
# Edge Added: 32995, 36495
# Edge Added: 32995, 29595
# Edge Added: 32995, 33095
# Edge Added: 32995, 36595
# Edge Added: 36495, 32995
# Edge Added: 36495, 40195
# Edge Added: 36495, 40295
# Edge Added: 36495, 33095
# Edge Added: 36495, 36595
# Edge Added: 40195, 36495
# Edge Added: 40195, 43795
# Edge Added: 40195, 40295
# Edge Added: 40195, 43895
# Edge Added: 40195, 36595
# Edge Added: 43795, 40195
# Edge Added: 43795, 47495
# Edge Added: 43795, 47395
# Edge Added: 43795, 40295
# Edge Added: 43795, 47595
# Edge Added: 43795, 43895
# Edge Added: 47495, 43795
# Edge Added: 47495, 47395
# Edge Added: 47495, 47595
# Edge Added: 47495, 43895
# Edge Added: 47495, 51295
# Edge Added: 47495, 51195
# Edge Added: 47495, 51395
# Edge Added: 51295, 47495
# Edge Added: 51295, 47395
# Edge Added: 51295, 47595
# Edge Added: 51295, 51195
# Edge Added: 51295, 54995
# Edge Added: 51295, 55095
# Edge Added: 51295, 51395
# Edge Added: 54995, 51295
# Edge Added: 54995, 51195
# Edge Added: 54995, 58695
# Edge Added: 54995, 58795
# Edge Added: 54995, 55095
# Edge Added: 54995, 51395
# Edge Added: 58695, 54895
# Edge Added: 58695, 54995
# Edge Added: 58695, 62295
# Edge Added: 58695, 62195
# Edge Added: 58695, 62395
# Edge Added: 58695, 58795
# Edge Added: 58695, 55095
# Edge Added: 62295, 58695
# Edge Added: 62295, 62195
# Edge Added: 62295, 62395
# Edge Added: 62295, 58795
# Edge Added: 62295, 65695
# Edge Added: 62295, 65795
# Edge Added: 62295, 65895
# Edge Added: 65795, 62295
# Edge Added: 65795, 62195
# Edge Added: 65795, 62395
# Edge Added: 65795, 65695
# Edge Added: 65795, 68994
# Edge Added: 65795, 69094
# Edge Added: 65795, 69194
# Edge Added: 65795, 65895
# Edge Added: 69094, 65695
# Edge Added: 69094, 65795
# Edge Added: 69094, 68994
# Edge Added: 69094, 72192
# Edge Added: 69094, 72292
# Edge Added: 69094, 69194
# Edge Added: 69094, 65895
# Edge Added: 69094, 72392
# Edge Added: 72292, 68994
# Edge Added: 72292, 69094
# Edge Added: 72292, 74988
# Edge Added: 72292, 72192
# Edge Added: 72292, 69194
# Edge Added: 72292, 72392
# Edge Added: 1999, 1899
# Edge Added: 1999, 2999
# Edge Added: 1999, 3199
# Edge Added: 1999, 999
# Edge Added: 3099, 4399
# Edge Added: 3099, 4299
# Edge Added: 3099, 3199
# Edge Added: 3099, 4499
# Edge Added: 4399, 3099
# Edge Added: 4399, 4299
# Edge Added: 4399, 5899
# Edge Added: 4399, 5999
# Edge Added: 4399, 4499
# Edge Added: 4399, 6099
# Edge Added: 5999, 4399
# Edge Added: 5999, 7599
# Edge Added: 5999, 5899
# Edge Added: 5999, 6099
# Edge Added: 5999, 7799
# Edge Added: 7699, 7599
# Edge Added: 9399, 9299
# Edge Added: 9399, 9499
# Edge Added: 11098, 11198
# Edge Added: 11098, 12698
# Edge Added: 11098, 12798
# Edge Added: 11098, 12898
# Edge Added: 12798, 11098
# Edge Added: 12798, 11198
# Edge Added: 12798, 14398
# Edge Added: 12798, 12698
# Edge Added: 12798, 14498
# Edge Added: 12798, 14598
# Edge Added: 12798, 12898
# Edge Added: 14498, 14398
# Edge Added: 14498, 16198
# Edge Added: 14498, 12798
# Edge Added: 14498, 14598
# Edge Added: 14498, 12898
# Edge Added: 14498, 16298
# Edge Added: 16198, 14398
# Edge Added: 16198, 14498
# Edge Added: 16198, 14598
# Edge Added: 16198, 16298
# Edge Added: 17998, 17898
# Edge Added: 17998, 19798
# Edge Added: 17998, 19898
# Edge Added: 19898, 17898
# Edge Added: 19898, 19798
# Edge Added: 19898, 21698
# Edge Added: 19898, 17998
# Edge Added: 19898, 21898
# Edge Added: 21798, 19798
# Edge Added: 21798, 21698
# Edge Added: 21798, 24097
# Edge Added: 24097, 21698
# Edge Added: 24097, 21898
# Edge Added: 24097, 21798
# Edge Added: 24097, 23997
# Edge Added: 24097, 24197
# Edge Added: 26596, 26496
# Edge Added: 26596, 26696
# Edge Added: 29595, 29495
# Edge Added: 29595, 32995
# Edge Added: 29595, 29695
# Edge Added: 29595, 33095
# Edge Added: 29595, 33195
# Edge Added: 33095, 29495
# Edge Added: 33095, 32995
# Edge Added: 33095, 36495
# Edge Added: 33095, 29695
# Edge Added: 33095, 29595
# Edge Added: 33095, 36595
# Edge Added: 33095, 33195
# Edge Added: 33095, 36695
# Edge Added: 36595, 32995
# Edge Added: 36595, 40195
# Edge Added: 36595, 36495
# Edge Added: 36595, 40395
# Edge Added: 36595, 40295
# Edge Added: 36595, 33095
# Edge Added: 36595, 33195
# Edge Added: 36595, 36695
# Edge Added: 40295, 40195
# Edge Added: 40295, 36495
# Edge Added: 40295, 43795
# Edge Added: 40295, 40395
# Edge Added: 40295, 43895
# Edge Added: 40295, 36595
# Edge Added: 40295, 43995
# Edge Added: 40295, 36695
# Edge Added: 43895, 40195
# Edge Added: 43895, 43795
# Edge Added: 43895, 47495
# Edge Added: 43895, 40395
# Edge Added: 43895, 40295
# Edge Added: 43895, 47595
# Edge Added: 43895, 47695
# Edge Added: 43895, 43995
# Edge Added: 47595, 43795
# Edge Added: 47595, 47495
# Edge Added: 47595, 43895
# Edge Added: 47595, 47695
# Edge Added: 47595, 43995
# Edge Added: 47595, 51295
# Edge Added: 47595, 51395
# Edge Added: 47595, 51495
# Edge Added: 51395, 47495
# Edge Added: 51395, 47595
# Edge Added: 51395, 47695
# Edge Added: 51395, 51295
# Edge Added: 51395, 54995
# Edge Added: 51395, 55095
# Edge Added: 51395, 51495
# Edge Added: 51395, 55195
# Edge Added: 55095, 51295
# Edge Added: 55095, 54995
# Edge Added: 55095, 58695
# Edge Added: 55095, 58795
# Edge Added: 55095, 51395
# Edge Added: 55095, 51495
# Edge Added: 55095, 58895
# Edge Added: 55095, 55195
# Edge Added: 58795, 54995
# Edge Added: 58795, 58695
# Edge Added: 58795, 62295
# Edge Added: 58795, 62495
# Edge Added: 58795, 62395
# Edge Added: 58795, 55095
# Edge Added: 58795, 58895
# Edge Added: 58795, 55195
# Edge Added: 62395, 58695
# Edge Added: 62395, 62295
# Edge Added: 62395, 62495
# Edge Added: 62395, 58795
# Edge Added: 62395, 58895
# Edge Added: 62395, 65795
# Edge Added: 62395, 65895
# Edge Added: 62395, 65995
# Edge Added: 65895, 62295
# Edge Added: 65895, 62495
# Edge Added: 65895, 62395
# Edge Added: 65895, 65795
# Edge Added: 65895, 69094
# Edge Added: 65895, 69194
# Edge Added: 65895, 65995
# Edge Added: 65895, 69294
# Edge Added: 69194, 65795
# Edge Added: 69194, 69094
# Edge Added: 69194, 72292
# Edge Added: 69194, 65895
# Edge Added: 69194, 72392
# Edge Added: 69194, 65995
# Edge Added: 69194, 69294
# Edge Added: 69194, 72492
# Edge Added: 72392, 69094
# Edge Added: 72392, 72292
# Edge Added: 72392, 69194
# Edge Added: 72392, 69294
# Edge Added: 72392, 72492
# Edge Added: 999, 1999
# Edge Added: 3199, 1999
# Edge Added: 3199, 3099
# Edge Added: 3199, 4599
# Edge Added: 3199, 4499
# Edge Added: 4499, 3099
# Edge Added: 4499, 4399
# Edge Added: 4499, 3199
# Edge Added: 4499, 4599
# Edge Added: 4499, 6099
# Edge Added: 6099, 4399
# Edge Added: 6099, 5999
# Edge Added: 6099, 4499
# Edge Added: 6099, 7799
# Edge Added: 7799, 5999
# Edge Added: 7799, 6099
# Edge Added: 9499, 9399
# Edge Added: 9499, 11298
# Edge Added: 11198, 11098
# Edge Added: 11198, 12798
# Edge Added: 11198, 12898
# Edge Added: 12898, 11098
# Edge Added: 12898, 11198
# Edge Added: 12898, 14498
# Edge Added: 12898, 12798
# Edge Added: 12898, 14598
# Edge Added: 14598, 16198
# Edge Added: 14598, 14498
# Edge Added: 14598, 12798
# Edge Added: 14598, 12898
# Edge Added: 14598, 16298
# Edge Added: 16298, 16198
# Edge Added: 16298, 14498
# Edge Added: 16298, 14598
# Edge Added: 18098, 16398
# Edge Added: 19998, 18198
# Edge Added: 21898, 19898
# Edge Added: 21898, 24197
# Edge Added: 21898, 24097
# Edge Added: 21898, 24297
# Edge Added: 24197, 21898
# Edge Added: 24197, 24097
# Edge Added: 24197, 24297
# Edge Added: 26696, 26596
# Edge Added: 29695, 29595
# Edge Added: 29695, 33095
# Edge Added: 29695, 33195
# Edge Added: 29695, 33295
# Edge Added: 33195, 29695
# Edge Added: 33195, 29595
# Edge Added: 33195, 33095
# Edge Added: 33195, 36595
# Edge Added: 33195, 36695
# Edge Added: 33195, 36795
# Edge Added: 33195, 33295
# Edge Added: 36695, 40395
# Edge Added: 36695, 40295
# Edge Added: 36695, 33095
# Edge Added: 36695, 36595
# Edge Added: 36695, 33195
# Edge Added: 36695, 40495
# Edge Added: 36695, 36795
# Edge Added: 36695, 33295
# Edge Added: 40395, 40295
# Edge Added: 40395, 43895
# Edge Added: 40395, 36595
# Edge Added: 40395, 43995
# Edge Added: 40395, 36695
# Edge Added: 40395, 40495
# Edge Added: 40395, 44095
# Edge Added: 40395, 36795
# Edge Added: 43995, 40395
# Edge Added: 43995, 40295
# Edge Added: 43995, 47595
# Edge Added: 43995, 43895
# Edge Added: 43995, 47695
# Edge Added: 43995, 40495
# Edge Added: 43995, 44095
# Edge Added: 43995, 47795
# Edge Added: 47695, 47595
# Edge Added: 47695, 43895
# Edge Added: 47695, 43995
# Edge Added: 47695, 44095
# Edge Added: 47695, 47795
# Edge Added: 47695, 51395
# Edge Added: 47695, 51495
# Edge Added: 47695, 51595
# Edge Added: 51495, 47595
# Edge Added: 51495, 47695
# Edge Added: 51495, 47795
# Edge Added: 51495, 55095
# Edge Added: 51495, 51395
# Edge Added: 51495, 55195
# Edge Added: 51495, 51595
# Edge Added: 51495, 55295
# Edge Added: 55195, 58795
# Edge Added: 55195, 55095
# Edge Added: 55195, 51395
# Edge Added: 55195, 51495
# Edge Added: 55195, 58895
# Edge Added: 55195, 51595
# Edge Added: 55195, 55295
# Edge Added: 55195, 58995
# Edge Added: 58895, 62495
# Edge Added: 58895, 62395
# Edge Added: 58895, 58795
# Edge Added: 58895, 55095
# Edge Added: 58895, 55195
# Edge Added: 58895, 62595
# Edge Added: 58895, 55295
# Edge Added: 58895, 58995
# Edge Added: 62495, 62395
# Edge Added: 62495, 58795
# Edge Added: 62495, 58895
# Edge Added: 62495, 62595
# Edge Added: 62495, 58995
# Edge Added: 62495, 65895
# Edge Added: 62495, 65995
# Edge Added: 62495, 66095
# Edge Added: 65995, 62495
# Edge Added: 65995, 62395
# Edge Added: 65995, 62595
# Edge Added: 65995, 69194
# Edge Added: 65995, 65895
# Edge Added: 65995, 69294
# Edge Added: 65995, 69394
# Edge Added: 65995, 66095
# Edge Added: 69294, 69194
# Edge Added: 69294, 65895
# Edge Added: 69294, 72392
# Edge Added: 69294, 65995
# Edge Added: 69294, 72492
# Edge Added: 69294, 72592
# Edge Added: 69294, 69394
# Edge Added: 69294, 66095
# Edge Added: 72492, 69194
# Edge Added: 72492, 72392
# Edge Added: 72492, 69294
# Edge Added: 72492, 72592
# Edge Added: 72492, 69394
# Edge Added: 4599, 6199
# Edge Added: 4599, 3199
# Edge Added: 4599, 4499
# Edge Added: 4599, 4699
# Edge Added: 6199, 4599
# Edge Added: 6199, 4699
# Edge Added: 6199, 7899
# Edge Added: 7899, 6199
# Edge Added: 7899, 9699
# Edge Added: 11298, 9499
# Edge Added: 12998, 14698
# Edge Added: 14698, 12998
# Edge Added: 16398, 18098
# Edge Added: 18198, 19998
# Edge Added: 18198, 16498
# Edge Added: 20098, 20198
# Edge Added: 21998, 22098
# Edge Added: 24297, 21898
# Edge Added: 24297, 24197
# Edge Added: 26796, 29795
# Edge Added: 26796, 26896
# Edge Added: 29795, 26796
# Edge Added: 29795, 26896
# Edge Added: 33295, 29695
# Edge Added: 33295, 33195
# Edge Added: 33295, 36695
# Edge Added: 36795, 40395
# Edge Added: 36795, 33195
# Edge Added: 36795, 36695
# Edge Added: 36795, 40495
# Edge Added: 40495, 40395
# Edge Added: 40495, 43995
# Edge Added: 40495, 36695
# Edge Added: 40495, 44095
# Edge Added: 40495, 36795
# Edge Added: 40495, 44195
# Edge Added: 44095, 40395
# Edge Added: 44095, 47695
# Edge Added: 44095, 43995
# Edge Added: 44095, 40495
# Edge Added: 44095, 47795
# Edge Added: 44095, 47895
# Edge Added: 44095, 44195
# Edge Added: 47795, 47695
# Edge Added: 47795, 43995
# Edge Added: 47795, 44095
# Edge Added: 47795, 47895
# Edge Added: 47795, 44195
# Edge Added: 47795, 51495
# Edge Added: 47795, 51595
# Edge Added: 47795, 51695
# Edge Added: 51595, 47695
# Edge Added: 51595, 47795
# Edge Added: 51595, 47895
# Edge Added: 51595, 51495
# Edge Added: 51595, 55195
# Edge Added: 51595, 55295
# Edge Added: 51595, 51695
# Edge Added: 51595, 55395
# Edge Added: 55295, 51495
# Edge Added: 55295, 58895
# Edge Added: 55295, 55195
# Edge Added: 55295, 51595
# Edge Added: 55295, 51695
# Edge Added: 55295, 59095
# Edge Added: 55295, 55395
# Edge Added: 55295, 58995
# Edge Added: 58995, 62495
# Edge Added: 58995, 58895
# Edge Added: 58995, 55195
# Edge Added: 58995, 62595
# Edge Added: 58995, 55295
# Edge Added: 58995, 59095
# Edge Added: 58995, 62695
# Edge Added: 58995, 55395
# Edge Added: 62595, 62495
# Edge Added: 62595, 58895
# Edge Added: 62595, 59095
# Edge Added: 62595, 62695
# Edge Added: 62595, 58995
# Edge Added: 62595, 65995
# Edge Added: 62595, 66095
# Edge Added: 62595, 66195
# Edge Added: 66095, 62495
# Edge Added: 66095, 62595
# Edge Added: 66095, 62695
# Edge Added: 66095, 65995
# Edge Added: 66095, 69294
# Edge Added: 66095, 69394
# Edge Added: 66095, 69494
# Edge Added: 66095, 66195
# Edge Added: 69394, 65995
# Edge Added: 69394, 69294
# Edge Added: 69394, 72492
# Edge Added: 69394, 72592
# Edge Added: 69394, 66095
# Edge Added: 69394, 69494
# Edge Added: 69394, 66195
# Edge Added: 72592, 69294
# Edge Added: 72592, 72492
# Edge Added: 72592, 69394
# Edge Added: 72592, 69494
# Edge Added: 4699, 6199
# Edge Added: 4699, 4599
# Edge Added: 4699, 6299
# Edge Added: 4699, 6399
# Edge Added: 6299, 4699
# Edge Added: 6299, 6399
# Edge Added: 6299, 7999
# Edge Added: 6299, 8099
# Edge Added: 7999, 6299
# Edge Added: 7999, 6399
# Edge Added: 7999, 9799
# Edge Added: 7999, 8099
# Edge Added: 9699, 7899
# Edge Added: 9699, 11498
# Edge Added: 11398, 13098
# Edge Added: 13098, 11398
# Edge Added: 13098, 14798
# Edge Added: 14798, 13098
# Edge Added: 14798, 16498
# Edge Added: 16498, 14798
# Edge Added: 16498, 18198
# Edge Added: 20198, 20098
# Edge Added: 20198, 20298
# Edge Added: 20198, 18398
# Edge Added: 22098, 21998
# Edge Added: 22098, 22198
# Edge Added: 22098, 20298
# Edge Added: 24397, 24497
# Edge Added: 26896, 29795
# Edge Added: 26896, 26796
# Edge Added: 26896, 29995
# Edge Added: 44195, 40495
# Edge Added: 44195, 44095
# Edge Added: 44195, 47795
# Edge Added: 44195, 47995
# Edge Added: 44195, 47895
# Edge Added: 47895, 44095
# Edge Added: 47895, 47795
# Edge Added: 47895, 47995
# Edge Added: 47895, 44195
# Edge Added: 47895, 51595
# Edge Added: 47895, 51695
# Edge Added: 51695, 47795
# Edge Added: 51695, 47995
# Edge Added: 51695, 47895
# Edge Added: 51695, 51595
# Edge Added: 51695, 55295
# Edge Added: 51695, 55395
# Edge Added: 55395, 51595
# Edge Added: 55395, 55295
# Edge Added: 55395, 51695
# Edge Added: 55395, 59095
# Edge Added: 55395, 58995
# Edge Added: 59095, 62595
# Edge Added: 59095, 55295
# Edge Added: 59095, 62695
# Edge Added: 59095, 55395
# Edge Added: 59095, 58995
# Edge Added: 62695, 62595
# Edge Added: 62695, 59095
# Edge Added: 62695, 58995
# Edge Added: 62695, 66095
# Edge Added: 62695, 66195
# Edge Added: 66195, 62595
# Edge Added: 66195, 62695
# Edge Added: 66195, 69394
# Edge Added: 66195, 66095
# Edge Added: 66195, 69494
# Edge Added: 69494, 72592
# Edge Added: 69494, 69394
# Edge Added: 69494, 66095
# Edge Added: 69494, 66195
# Edge Added: 6399, 4699
# Edge Added: 6399, 6299
# Edge Added: 6399, 7999
# Edge Added: 6399, 8099
# Edge Added: 6399, 8199
# Edge Added: 8099, 6299
# Edge Added: 8099, 6399
# Edge Added: 8099, 7999
# Edge Added: 8099, 9799
# Edge Added: 8099, 8199
# Edge Added: 9799, 7999
# Edge Added: 9799, 8099
# Edge Added: 9799, 11598
# Edge Added: 9799, 8199
# Edge Added: 11498, 9699
# Edge Added: 11498, 11598
# Edge Added: 11498, 13198
# Edge Added: 13198, 11498
# Edge Added: 13198, 11598
# Edge Added: 13198, 14898
# Edge Added: 14898, 13198
# Edge Added: 14898, 16598
# Edge Added: 16598, 14898
# Edge Added: 16598, 18398
# Edge Added: 16598, 18498
# Edge Added: 18398, 16598
# Edge Added: 18398, 20198
# Edge Added: 18398, 20298
# Edge Added: 18398, 20398
# Edge Added: 18398, 18498
# Edge Added: 20298, 20198
# Edge Added: 20298, 22098
# Edge Added: 20298, 18398
# Edge Added: 20298, 20398
# Edge Added: 20298, 18498
# Edge Added: 20298, 22298
# Edge Added: 22198, 22098
# Edge Added: 22198, 22298
# Edge Added: 22198, 24597
# Edge Added: 24497, 24397
# Edge Added: 29995, 26896
# Edge Added: 47995, 47895
# Edge Added: 47995, 44195
# Edge Added: 47995, 51695
# Edge Added: 8199, 6399
# Edge Added: 8199, 9799
# Edge Added: 8199, 8099
# Edge Added: 11598, 9799
# Edge Added: 11598, 11498
# Edge Added: 11598, 13198
# Edge Added: 14998, 16698
# Edge Added: 16698, 14998
# Edge Added: 18498, 16598
# Edge Added: 18498, 20298
# Edge Added: 18498, 18398
# Edge Added: 18498, 20398
# Edge Added: 20398, 20298
# Edge Added: 20398, 18398
# Edge Added: 20398, 18498
# Edge Added: 20398, 22298
# Edge Added: 22298, 22198
# Edge Added: 22298, 20298
# Edge Added: 22298, 20398
# Edge Added: 22298, 22398
# Edge Added: 24597, 22198
# Edge Added: 24597, 22398
# Edge Added: 24597, 24697
# Edge Added: 16798, 18598
# Edge Added: 18598, 16798
# Edge Added: 18598, 20498
# Edge Added: 20498, 18598
# Edge Added: 22398, 22298
# Edge Added: 22398, 24697
# Edge Added: 22398, 24597
# Edge Added: 24697, 22398
# Edge Added: 24697, 24597
# nodes processed: 83580

# %% [markdown]
# Current row  78584  Lat and Lon  0.898 42.221
#
# *   Adjacent row of Month 201506  Lat and Lon -0.898 40.424
# *   Adjacent row of Month 201506  Lat and Lon 0.898 42.221
# *   Adjacent row of Month 201506  Lat and Lon 0.898 44.017
# *   Adjacent row of Month 201506  Lat and Lon -0.898 42.221
# *   Adjacent row of Month 201506  Lat and Lon 0.898 40.424
# *   Adjacent row of Month 201506  Lat and Lon 2.695 40.424
# *   Adjacent row of Month 201506  Lat and Lon 2.695 44.017
# *   Adjacent row of Month 201506  Lat and Lon 2.695 42.221

# %%
lat = [35.034 , 35.034 , 36.831 , 36.831, 36.831 , 35.034  ]
lon = [6.288, 8.085, 6.288, 8.085,9.881,9.881]
n=[1,2,3,4,5,6]

# dictionary of lists
dict = {'lat': lat, 'lon': lon}

df = pd.DataFrame(dict)

print(df)

import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.scatter(x=df['lon'], y=df['lat'])

for i, txt in enumerate(n):
    ax.annotate(txt, (lon[i], lat[i]))
plt.show()
# Out:
#       lat    lon
# 0  35.034  6.288
# 1  35.034  8.085
# 2  36.831  6.288
# 3  36.831  8.085
# 4  36.831  9.881
# 5  35.034  9.881

# %%
from shapely.geometry import Point
import geopandas as gpd
from geopandas import GeoDataFrame



geometry = [Point(xy) for xy in zip(df['lon'], df['lat'])]
gdf = GeoDataFrame(df, geometry=geometry)

#this is a simple map that goes with geopandas
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
gdf.plot(ax=world.plot(figsize=(10, 6)), marker='o', color='red', markersize=5);
# Out:
# <ipython-input-21-451ac055118e>:11: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
display_a_to_b_nodes(Spatial_temporal_graph, 20000, 20100, "Month")

# %% [markdown]
# **Create 2 month temporal edges**

# %%
def sameSeason(currentM, nextM):
  winter=[12,1,2]
  spring=[3,4,5]
  summer=[6,7,8]
  fall=[9,10,11]

  cM=int(currentM[4:])
  nM=int(nextM[4:])
  print(cM,nM)

  if cM in winter and nM in winter:
    return True
  else:
    if cM in spring and nM in spring:
      return True
    else:
      if cM in summer and nM in summer:
        return True
      else:
        if cM in fall and nM in fall:
          return True
        else:
          return False

# %%
print(sameSeason("201501", "201512"))
print(sameSeason("201506", "201509"))
# Out:
# 1 12
# True
# 6 9
# False

# %%
#More Efficient Version

total_index = 0

diffm=0.05



for i, month in enumerate(unique_list_of_months[:-1]):
    # Get the dataset for the current month and the next month
    dataset_subset_1 = sort_processed_dataset[sort_processed_dataset["Month"] == month]
    dataset_subset_2 = sort_processed_dataset[sort_processed_dataset["Month"] == unique_list_of_months[i+1]]
    print("current month ", unique_list_of_months[i], " next month ",unique_list_of_months[i+1])

    if sameSeason(str(unique_list_of_months[i]),str(unique_list_of_months[i+1])):

     # Create dictionaries for the coordinates
      coords_dict_1 = {(row["Lon"], row["Lat"]): idx for idx, row in dataset_subset_1.iterrows()}
      coords_dict_2 = {(row["Lon"], row["Lat"]): idx for idx, row in dataset_subset_2.iterrows()}

     # Iterate through the first dictionary and check if the coordinates exist in the second dictionary
      for coord, idx1 in coords_dict_1.items():
         idx1_Spei=dataset_subset_1[dataset_subset_1["row_index"] == idx1].iloc[0]['spei01']
      #    print("idx1", idx1, " SPEI01 ", idx1_Spei);
         idx2 = coords_dict_2.get(coord)
         if idx2 is not None:
             idx2_Spei=dataset_subset_2[dataset_subset_2["row_index"] == idx2].iloc[0]['spei01']
          #   print("idx2", idx2, " SPEI01 ", idx2_Spei);
             speiDiff= abs(idx1_Spei-idx2_Spei)
             if speiDiff<diffm :
               Spatial_temporal_graph.add_edge(idx1, idx2)
               print("add Temporal edges with node ", idx1 ," and next month Node ", idx2)
               print("")

    # Update and print the processed count
      total_index += len(dataset_subset_1)
      print("nodes processed: " + str(total_index))
# Out:
# Streaming output truncated to the last 5000 lines.
# add Temporal edges with node  1585  and next month Node  1586
#
# add Temporal edges with node  2685  and next month Node  2686
#
# add Temporal edges with node  5585  and next month Node  5586
#
# add Temporal edges with node  10684  and next month Node  10685
#
# add Temporal edges with node  12384  and next month Node  12385
#
# add Temporal edges with node  15784  and next month Node  15785
#
# add Temporal edges with node  17584  and next month Node  17585
#
# add Temporal edges with node  19484  and next month Node  19485
#
# add Temporal edges with node  21384  and next month Node  21385
#
# add Temporal edges with node  23683  and next month Node  23684
#
# add Temporal edges with node  26182  and next month Node  26183
#
# add Temporal edges with node  29181  and next month Node  29182
#
# add Temporal edges with node  36181  and next month Node  36182
#
# add Temporal edges with node  39881  and next month Node  39882
#
# add Temporal edges with node  58381  and next month Node  58382
#
# add Temporal edges with node  61981  and next month Node  61982
#
# add Temporal edges with node  65481  and next month Node  65482
#
# add Temporal edges with node  71978  and next month Node  71979
#
# add Temporal edges with node  74774  and next month Node  74775
#
# add Temporal edges with node  685  and next month Node  686
#
# add Temporal edges with node  2785  and next month Node  2786
#
# add Temporal edges with node  4085  and next month Node  4086
#
# add Temporal edges with node  5685  and next month Node  5686
#
# add Temporal edges with node  7385  and next month Node  7386
#
# add Temporal edges with node  9085  and next month Node  9086
#
# add Temporal edges with node  10784  and next month Node  10785
#
# add Temporal edges with node  14184  and next month Node  14185
#
# add Temporal edges with node  36281  and next month Node  36282
#
# add Temporal edges with node  54781  and next month Node  54782
#
# add Temporal edges with node  58481  and next month Node  58482
#
# add Temporal edges with node  62081  and next month Node  62082
#
# add Temporal edges with node  65581  and next month Node  65582
#
# add Temporal edges with node  68880  and next month Node  68881
#
# add Temporal edges with node  72078  and next month Node  72079
#
# add Temporal edges with node  2885  and next month Node  2886
#
# add Temporal edges with node  4185  and next month Node  4186
#
# add Temporal edges with node  5785  and next month Node  5786
#
# add Temporal edges with node  7485  and next month Node  7486
#
# add Temporal edges with node  9185  and next month Node  9186
#
# add Temporal edges with node  21584  and next month Node  21585
#
# add Temporal edges with node  23883  and next month Node  23884
#
# add Temporal edges with node  26382  and next month Node  26383
#
# add Temporal edges with node  36381  and next month Node  36382
#
# add Temporal edges with node  58581  and next month Node  58582
#
# add Temporal edges with node  62181  and next month Node  62182
#
# add Temporal edges with node  65681  and next month Node  65682
#
# add Temporal edges with node  68980  and next month Node  68981
#
# add Temporal edges with node  72178  and next month Node  72179
#
# add Temporal edges with node  885  and next month Node  886
#
# add Temporal edges with node  1885  and next month Node  1886
#
# add Temporal edges with node  2985  and next month Node  2986
#
# add Temporal edges with node  4285  and next month Node  4286
#
# add Temporal edges with node  5885  and next month Node  5886
#
# add Temporal edges with node  7585  and next month Node  7586
#
# add Temporal edges with node  9285  and next month Node  9286
#
# add Temporal edges with node  10984  and next month Node  10985
#
# add Temporal edges with node  12684  and next month Node  12685
#
# add Temporal edges with node  14384  and next month Node  14385
#
# add Temporal edges with node  16084  and next month Node  16085
#
# add Temporal edges with node  19784  and next month Node  19785
#
# add Temporal edges with node  21684  and next month Node  21685
#
# add Temporal edges with node  23983  and next month Node  23984
#
# add Temporal edges with node  26482  and next month Node  26483
#
# add Temporal edges with node  36481  and next month Node  36482
#
# add Temporal edges with node  43781  and next month Node  43782
#
# add Temporal edges with node  47481  and next month Node  47482
#
# add Temporal edges with node  58681  and next month Node  58682
#
# add Temporal edges with node  62281  and next month Node  62282
#
# add Temporal edges with node  65781  and next month Node  65782
#
# add Temporal edges with node  69080  and next month Node  69081
#
# add Temporal edges with node  1985  and next month Node  1986
#
# add Temporal edges with node  4385  and next month Node  4386
#
# add Temporal edges with node  5985  and next month Node  5986
#
# add Temporal edges with node  7685  and next month Node  7686
#
# add Temporal edges with node  9385  and next month Node  9386
#
# add Temporal edges with node  17984  and next month Node  17985
#
# add Temporal edges with node  19884  and next month Node  19885
#
# add Temporal edges with node  21784  and next month Node  21785
#
# add Temporal edges with node  24083  and next month Node  24084
#
# add Temporal edges with node  26582  and next month Node  26583
#
# add Temporal edges with node  33081  and next month Node  33082
#
# add Temporal edges with node  36581  and next month Node  36582
#
# add Temporal edges with node  40281  and next month Node  40282
#
# add Temporal edges with node  43881  and next month Node  43882
#
# add Temporal edges with node  47581  and next month Node  47582
#
# add Temporal edges with node  51381  and next month Node  51382
#
# add Temporal edges with node  55081  and next month Node  55082
#
# add Temporal edges with node  58781  and next month Node  58782
#
# add Temporal edges with node  62381  and next month Node  62382
#
# add Temporal edges with node  65881  and next month Node  65882
#
# add Temporal edges with node  69180  and next month Node  69181
#
# add Temporal edges with node  72378  and next month Node  72379
#
# add Temporal edges with node  6085  and next month Node  6086
#
# add Temporal edges with node  7785  and next month Node  7786
#
# add Temporal edges with node  19984  and next month Node  19985
#
# add Temporal edges with node  21884  and next month Node  21885
#
# add Temporal edges with node  24183  and next month Node  24184
#
# add Temporal edges with node  26682  and next month Node  26683
#
# add Temporal edges with node  29681  and next month Node  29682
#
# add Temporal edges with node  36681  and next month Node  36682
#
# add Temporal edges with node  40381  and next month Node  40382
#
# add Temporal edges with node  43981  and next month Node  43982
#
# add Temporal edges with node  47681  and next month Node  47682
#
# add Temporal edges with node  51481  and next month Node  51482
#
# add Temporal edges with node  55181  and next month Node  55182
#
# add Temporal edges with node  65981  and next month Node  65982
#
# add Temporal edges with node  69280  and next month Node  69281
#
# add Temporal edges with node  72478  and next month Node  72479
#
# add Temporal edges with node  7885  and next month Node  7886
#
# add Temporal edges with node  36781  and next month Node  36782
#
# add Temporal edges with node  40481  and next month Node  40482
#
# add Temporal edges with node  44081  and next month Node  44082
#
# add Temporal edges with node  47781  and next month Node  47782
#
# add Temporal edges with node  51581  and next month Node  51582
#
# add Temporal edges with node  55281  and next month Node  55282
#
# add Temporal edges with node  66081  and next month Node  66082
#
# add Temporal edges with node  69380  and next month Node  69381
#
# add Temporal edges with node  7985  and next month Node  7986
#
# add Temporal edges with node  44181  and next month Node  44182
#
# add Temporal edges with node  47881  and next month Node  47882
#
# add Temporal edges with node  51681  and next month Node  51682
#
# add Temporal edges with node  55381  and next month Node  55382
#
# add Temporal edges with node  59081  and next month Node  59082
#
# add Temporal edges with node  66181  and next month Node  66182
#
# add Temporal edges with node  69480  and next month Node  69481
#
# add Temporal edges with node  11484  and next month Node  11485
#
# add Temporal edges with node  20284  and next month Node  20285
#
# add Temporal edges with node  47981  and next month Node  47982
#
# add Temporal edges with node  11584  and next month Node  11585
#
# add Temporal edges with node  13284  and next month Node  13285
#
# add Temporal edges with node  14984  and next month Node  14985
#
# add Temporal edges with node  16684  and next month Node  16685
#
# add Temporal edges with node  18484  and next month Node  18485
#
# add Temporal edges with node  20384  and next month Node  20385
#
# add Temporal edges with node  16784  and next month Node  16785
#
# add Temporal edges with node  20484  and next month Node  20485
#
# add Temporal edges with node  22384  and next month Node  22385
#
# nodes processed: 47652
# current month  202207  next month  202208
# 7 8
# add Temporal edges with node  36982  and next month Node  36983
#
# add Temporal edges with node  44282  and next month Node  44283
#
# add Temporal edges with node  37082  and next month Node  37083
#
# add Temporal edges with node  44382  and next month Node  44383
#
# add Temporal edges with node  48182  and next month Node  48183
#
# add Temporal edges with node  51882  and next month Node  51883
#
# add Temporal edges with node  55582  and next month Node  55583
#
# add Temporal edges with node  59182  and next month Node  59183
#
# add Temporal edges with node  33482  and next month Node  33483
#
# add Temporal edges with node  51982  and next month Node  51983
#
# add Temporal edges with node  59282  and next month Node  59283
#
# add Temporal edges with node  30082  and next month Node  30083
#
# add Temporal edges with node  33582  and next month Node  33583
#
# add Temporal edges with node  55782  and next month Node  55783
#
# add Temporal edges with node  33682  and next month Node  33683
#
# add Temporal edges with node  30282  and next month Node  30283
#
# add Temporal edges with node  33782  and next month Node  33783
#
# add Temporal edges with node  59582  and next month Node  59583
#
# add Temporal edges with node  63082  and next month Node  63083
#
# add Temporal edges with node  33882  and next month Node  33883
#
# add Temporal edges with node  59682  and next month Node  59683
#
# add Temporal edges with node  56182  and next month Node  56183
#
# add Temporal edges with node  80767  and next month Node  80768
#
# add Temporal edges with node  81767  and next month Node  81768
#
# add Temporal edges with node  52582  and next month Node  52583
#
# add Temporal edges with node  56282  and next month Node  56283
#
# add Temporal edges with node  59882  and next month Node  59883
#
# add Temporal edges with node  63382  and next month Node  63383
#
# add Temporal edges with node  80867  and next month Node  80868
#
# add Temporal edges with node  81867  and next month Node  81868
#
# add Temporal edges with node  52682  and next month Node  52683
#
# add Temporal edges with node  63482  and next month Node  63483
#
# add Temporal edges with node  79867  and next month Node  79868
#
# add Temporal edges with node  81967  and next month Node  81968
#
# add Temporal edges with node  70079  and next month Node  70080
#
# add Temporal edges with node  77071  and next month Node  77072
#
# add Temporal edges with node  82067  and next month Node  82068
#
# add Temporal edges with node  56582  and next month Node  56583
#
# add Temporal edges with node  72979  and next month Node  72980
#
# add Temporal edges with node  75275  and next month Node  75276
#
# add Temporal edges with node  56682  and next month Node  56683
#
# add Temporal edges with node  56782  and next month Node  56783
#
# add Temporal edges with node  75475  and next month Node  75476
#
# add Temporal edges with node  77371  and next month Node  77372
#
# add Temporal edges with node  27683  and next month Node  27684
#
# add Temporal edges with node  34682  and next month Node  34683
#
# add Temporal edges with node  45682  and next month Node  45683
#
# add Temporal edges with node  49482  and next month Node  49483
#
# add Temporal edges with node  53182  and next month Node  53183
#
# add Temporal edges with node  56882  and next month Node  56883
#
# add Temporal edges with node  60482  and next month Node  60483
#
# add Temporal edges with node  73277  and next month Node  73278
#
# add Temporal edges with node  31282  and next month Node  31283
#
# add Temporal edges with node  34782  and next month Node  34783
#
# add Temporal edges with node  45782  and next month Node  45783
#
# add Temporal edges with node  49582  and next month Node  49583
#
# add Temporal edges with node  53282  and next month Node  53283
#
# add Temporal edges with node  56982  and next month Node  56983
#
# add Temporal edges with node  60582  and next month Node  60583
#
# add Temporal edges with node  64082  and next month Node  64083
#
# add Temporal edges with node  67381  and next month Node  67382
#
# add Temporal edges with node  70579  and next month Node  70580
#
# add Temporal edges with node  31382  and next month Node  31383
#
# add Temporal edges with node  34882  and next month Node  34883
#
# add Temporal edges with node  38582  and next month Node  38583
#
# add Temporal edges with node  45882  and next month Node  45883
#
# add Temporal edges with node  60682  and next month Node  60683
#
# add Temporal edges with node  67481  and next month Node  67482
#
# add Temporal edges with node  70679  and next month Node  70680
#
# add Temporal edges with node  73475  and next month Node  73476
#
# add Temporal edges with node  38682  and next month Node  38683
#
# add Temporal edges with node  60782  and next month Node  60783
#
# add Temporal edges with node  73575  and next month Node  73576
#
# add Temporal edges with node  75874  and next month Node  75875
#
# add Temporal edges with node  46082  and next month Node  46083
#
# add Temporal edges with node  49882  and next month Node  49883
#
# add Temporal edges with node  53582  and next month Node  53583
#
# add Temporal edges with node  49982  and next month Node  49983
#
# add Temporal edges with node  77671  and next month Node  77672
#
# add Temporal edges with node  78669  and next month Node  78670
#
# add Temporal edges with node  79967  and next month Node  79968
#
# add Temporal edges with node  76171  and next month Node  76172
#
# add Temporal edges with node  77771  and next month Node  77772
#
# add Temporal edges with node  78769  and next month Node  78770
#
# add Temporal edges with node  80067  and next month Node  80068
#
# add Temporal edges with node  81067  and next month Node  81068
#
# add Temporal edges with node  22884  and next month Node  22885
#
# add Temporal edges with node  25383  and next month Node  25384
#
# add Temporal edges with node  31882  and next month Node  31883
#
# add Temporal edges with node  53882  and next month Node  53883
#
# add Temporal edges with node  76271  and next month Node  76272
#
# add Temporal edges with node  77871  and next month Node  77872
#
# add Temporal edges with node  78869  and next month Node  78870
#
# add Temporal edges with node  80167  and next month Node  80168
#
# add Temporal edges with node  81167  and next month Node  81168
#
# add Temporal edges with node  82267  and next month Node  82268
#
# add Temporal edges with node  18785  and next month Node  18786
#
# add Temporal edges with node  22984  and next month Node  22985
#
# add Temporal edges with node  25483  and next month Node  25484
#
# add Temporal edges with node  71279  and next month Node  71280
#
# add Temporal edges with node  74075  and next month Node  74076
#
# add Temporal edges with node  76371  and next month Node  76372
#
# add Temporal edges with node  77971  and next month Node  77972
#
# add Temporal edges with node  78969  and next month Node  78970
#
# add Temporal edges with node  80267  and next month Node  80268
#
# add Temporal edges with node  83066  and next month Node  83067
#
# add Temporal edges with node  13485  and next month Node  13486
#
# add Temporal edges with node  16985  and next month Node  16986
#
# add Temporal edges with node  18885  and next month Node  18886
#
# add Temporal edges with node  20785  and next month Node  20786
#
# add Temporal edges with node  28582  and next month Node  28583
#
# add Temporal edges with node  32082  and next month Node  32083
#
# add Temporal edges with node  35582  and next month Node  35583
#
# add Temporal edges with node  42882  and next month Node  42883
#
# add Temporal edges with node  46582  and next month Node  46583
#
# add Temporal edges with node  50382  and next month Node  50383
#
# add Temporal edges with node  54082  and next month Node  54083
#
# add Temporal edges with node  57782  and next month Node  57783
#
# add Temporal edges with node  61382  and next month Node  61383
#
# add Temporal edges with node  71379  and next month Node  71380
#
# add Temporal edges with node  76471  and next month Node  76472
#
# add Temporal edges with node  78071  and next month Node  78072
#
# add Temporal edges with node  79069  and next month Node  79070
#
# add Temporal edges with node  80367  and next month Node  80368
#
# add Temporal edges with node  81367  and next month Node  81368
#
# add Temporal edges with node  82467  and next month Node  82468
#
# add Temporal edges with node  83166  and next month Node  83167
#
# add Temporal edges with node  3486  and next month Node  3487
#
# add Temporal edges with node  8486  and next month Node  8487
#
# add Temporal edges with node  10185  and next month Node  10186
#
# add Temporal edges with node  11885  and next month Node  11886
#
# add Temporal edges with node  13585  and next month Node  13586
#
# add Temporal edges with node  18985  and next month Node  18986
#
# add Temporal edges with node  20885  and next month Node  20886
#
# add Temporal edges with node  32182  and next month Node  32183
#
# add Temporal edges with node  35682  and next month Node  35683
#
# add Temporal edges with node  54182  and next month Node  54183
#
# add Temporal edges with node  57882  and next month Node  57883
#
# add Temporal edges with node  61482  and next month Node  61483
#
# add Temporal edges with node  64982  and next month Node  64983
#
# add Temporal edges with node  71479  and next month Node  71480
#
# add Temporal edges with node  80467  and next month Node  80468
#
# add Temporal edges with node  186  and next month Node  187
#
# add Temporal edges with node  5186  and next month Node  5187
#
# add Temporal edges with node  6886  and next month Node  6887
#
# add Temporal edges with node  8586  and next month Node  8587
#
# add Temporal edges with node  17185  and next month Node  17186
#
# add Temporal edges with node  19085  and next month Node  19086
#
# add Temporal edges with node  28782  and next month Node  28783
#
# add Temporal edges with node  32282  and next month Node  32283
#
# add Temporal edges with node  43082  and next month Node  43083
#
# add Temporal edges with node  46782  and next month Node  46783
#
# add Temporal edges with node  50582  and next month Node  50583
#
# add Temporal edges with node  54282  and next month Node  54283
#
# add Temporal edges with node  57982  and next month Node  57983
#
# add Temporal edges with node  61582  and next month Node  61583
#
# add Temporal edges with node  83366  and next month Node  83367
#
# add Temporal edges with node  286  and next month Node  287
#
# add Temporal edges with node  6986  and next month Node  6987
#
# add Temporal edges with node  8686  and next month Node  8687
#
# add Temporal edges with node  19185  and next month Node  19186
#
# add Temporal edges with node  21085  and next month Node  21086
#
# add Temporal edges with node  25883  and next month Node  25884
#
# add Temporal edges with node  28882  and next month Node  28883
#
# add Temporal edges with node  32382  and next month Node  32383
#
# add Temporal edges with node  43182  and next month Node  43183
#
# add Temporal edges with node  46882  and next month Node  46883
#
# add Temporal edges with node  50682  and next month Node  50683
#
# add Temporal edges with node  54382  and next month Node  54383
#
# add Temporal edges with node  61682  and next month Node  61683
#
# add Temporal edges with node  65182  and next month Node  65183
#
# add Temporal edges with node  68481  and next month Node  68482
#
# add Temporal edges with node  79368  and next month Node  79369
#
# add Temporal edges with node  386  and next month Node  387
#
# add Temporal edges with node  7086  and next month Node  7087
#
# add Temporal edges with node  12185  and next month Node  12186
#
# add Temporal edges with node  25983  and next month Node  25984
#
# add Temporal edges with node  28982  and next month Node  28983
#
# add Temporal edges with node  32482  and next month Node  32483
#
# add Temporal edges with node  61782  and next month Node  61783
#
# add Temporal edges with node  68581  and next month Node  68582
#
# add Temporal edges with node  486  and next month Node  487
#
# add Temporal edges with node  7186  and next month Node  7187
#
# add Temporal edges with node  12285  and next month Node  12286
#
# add Temporal edges with node  21285  and next month Node  21286
#
# add Temporal edges with node  29082  and next month Node  29083
#
# add Temporal edges with node  32582  and next month Node  32583
#
# add Temporal edges with node  36082  and next month Node  36083
#
# add Temporal edges with node  39782  and next month Node  39783
#
# add Temporal edges with node  74675  and next month Node  74676
#
# add Temporal edges with node  586  and next month Node  587
#
# add Temporal edges with node  1586  and next month Node  1587
#
# add Temporal edges with node  7286  and next month Node  7287
#
# add Temporal edges with node  12385  and next month Node  12386
#
# add Temporal edges with node  14085  and next month Node  14086
#
# add Temporal edges with node  15785  and next month Node  15786
#
# add Temporal edges with node  39882  and next month Node  39883
#
# add Temporal edges with node  2786  and next month Node  2787
#
# add Temporal edges with node  7386  and next month Node  7387
#
# add Temporal edges with node  9086  and next month Node  9087
#
# add Temporal edges with node  10785  and next month Node  10786
#
# add Temporal edges with node  14185  and next month Node  14186
#
# add Temporal edges with node  15885  and next month Node  15886
#
# add Temporal edges with node  17685  and next month Node  17686
#
# add Temporal edges with node  19585  and next month Node  19586
#
# add Temporal edges with node  21485  and next month Node  21486
#
# add Temporal edges with node  23784  and next month Node  23785
#
# add Temporal edges with node  26283  and next month Node  26284
#
# add Temporal edges with node  36282  and next month Node  36283
#
# add Temporal edges with node  74875  and next month Node  74876
#
# add Temporal edges with node  786  and next month Node  787
#
# add Temporal edges with node  2886  and next month Node  2887
#
# add Temporal edges with node  4186  and next month Node  4187
#
# add Temporal edges with node  5786  and next month Node  5787
#
# add Temporal edges with node  7486  and next month Node  7487
#
# add Temporal edges with node  9186  and next month Node  9187
#
# add Temporal edges with node  29382  and next month Node  29383
#
# add Temporal edges with node  36382  and next month Node  36383
#
# add Temporal edges with node  74975  and next month Node  74976
#
# add Temporal edges with node  1886  and next month Node  1887
#
# add Temporal edges with node  4286  and next month Node  4287
#
# add Temporal edges with node  5886  and next month Node  5887
#
# add Temporal edges with node  7586  and next month Node  7587
#
# add Temporal edges with node  9286  and next month Node  9287
#
# add Temporal edges with node  4386  and next month Node  4387
#
# add Temporal edges with node  5986  and next month Node  5987
#
# add Temporal edges with node  7686  and next month Node  7687
#
# add Temporal edges with node  9386  and next month Node  9387
#
# add Temporal edges with node  6086  and next month Node  6087
#
# add Temporal edges with node  7786  and next month Node  7787
#
# add Temporal edges with node  19985  and next month Node  19986
#
# add Temporal edges with node  33182  and next month Node  33183
#
# add Temporal edges with node  36682  and next month Node  36683
#
# add Temporal edges with node  40382  and next month Node  40383
#
# add Temporal edges with node  43982  and next month Node  43983
#
# add Temporal edges with node  47682  and next month Node  47683
#
# add Temporal edges with node  7886  and next month Node  7887
#
# add Temporal edges with node  26783  and next month Node  26784
#
# add Temporal edges with node  29782  and next month Node  29783
#
# add Temporal edges with node  36782  and next month Node  36783
#
# add Temporal edges with node  40482  and next month Node  40483
#
# add Temporal edges with node  44082  and next month Node  44083
#
# add Temporal edges with node  47782  and next month Node  47783
#
# add Temporal edges with node  51582  and next month Node  51583
#
# add Temporal edges with node  58982  and next month Node  58983
#
# add Temporal edges with node  62582  and next month Node  62583
#
# add Temporal edges with node  66082  and next month Node  66083
#
# add Temporal edges with node  7986  and next month Node  7987
#
# add Temporal edges with node  20185  and next month Node  20186
#
# add Temporal edges with node  22085  and next month Node  22086
#
# add Temporal edges with node  24384  and next month Node  24385
#
# add Temporal edges with node  26883  and next month Node  26884
#
# add Temporal edges with node  36882  and next month Node  36883
#
# add Temporal edges with node  44182  and next month Node  44183
#
# add Temporal edges with node  47882  and next month Node  47883
#
# add Temporal edges with node  51682  and next month Node  51683
#
# add Temporal edges with node  55382  and next month Node  55383
#
# add Temporal edges with node  59082  and next month Node  59083
#
# add Temporal edges with node  62682  and next month Node  62683
#
# add Temporal edges with node  66182  and next month Node  66183
#
# add Temporal edges with node  9786  and next month Node  9787
#
# add Temporal edges with node  11485  and next month Node  11486
#
# add Temporal edges with node  18385  and next month Node  18386
#
# add Temporal edges with node  20285  and next month Node  20286
#
# add Temporal edges with node  22185  and next month Node  22186
#
# add Temporal edges with node  24484  and next month Node  24485
#
# add Temporal edges with node  26983  and next month Node  26984
#
# add Temporal edges with node  11585  and next month Node  11586
#
# add Temporal edges with node  14985  and next month Node  14986
#
# add Temporal edges with node  18485  and next month Node  18486
#
# add Temporal edges with node  24584  and next month Node  24585
#
# add Temporal edges with node  16785  and next month Node  16786
#
# add Temporal edges with node  18585  and next month Node  18586
#
# nodes processed: 48488
# current month  202208  next month  202209
# 8 9
# current month  202209  next month  202210
# 9 10
# add Temporal edges with node  55684  and next month Node  55685
#
# add Temporal edges with node  59284  and next month Node  59285
#
# add Temporal edges with node  62784  and next month Node  62785
#
# add Temporal edges with node  48384  and next month Node  48385
#
# add Temporal edges with node  52084  and next month Node  52085
#
# add Temporal edges with node  59384  and next month Node  59385
#
# add Temporal edges with node  62884  and next month Node  62885
#
# add Temporal edges with node  48484  and next month Node  48485
#
# add Temporal edges with node  59484  and next month Node  59485
#
# add Temporal edges with node  30284  and next month Node  30285
#
# add Temporal edges with node  52284  and next month Node  52285
#
# add Temporal edges with node  63084  and next month Node  63085
#
# add Temporal edges with node  66383  and next month Node  66384
#
# add Temporal edges with node  69583  and next month Node  69584
#
# add Temporal edges with node  41184  and next month Node  41185
#
# add Temporal edges with node  56084  and next month Node  56085
#
# add Temporal edges with node  69683  and next month Node  69684
#
# add Temporal edges with node  44984  and next month Node  44985
#
# add Temporal edges with node  81769  and next month Node  81770
#
# add Temporal edges with node  69981  and next month Node  69982
#
# add Temporal edges with node  72781  and next month Node  72782
#
# add Temporal edges with node  75077  and next month Node  75078
#
# add Temporal edges with node  81969  and next month Node  81970
#
# add Temporal edges with node  82768  and next month Node  82769
#
# add Temporal edges with node  49084  and next month Node  49085
#
# add Temporal edges with node  63584  and next month Node  63585
#
# add Temporal edges with node  66883  and next month Node  66884
#
# add Temporal edges with node  72881  and next month Node  72882
#
# add Temporal edges with node  82069  and next month Node  82070
#
# add Temporal edges with node  52884  and next month Node  52885
#
# add Temporal edges with node  56584  and next month Node  56585
#
# add Temporal edges with node  60184  and next month Node  60185
#
# add Temporal edges with node  63684  and next month Node  63685
#
# add Temporal edges with node  66983  and next month Node  66984
#
# add Temporal edges with node  70181  and next month Node  70182
#
# add Temporal edges with node  72981  and next month Node  72982
#
# add Temporal edges with node  45484  and next month Node  45485
#
# add Temporal edges with node  49284  and next month Node  49285
#
# add Temporal edges with node  52984  and next month Node  52985
#
# add Temporal edges with node  56684  and next month Node  56685
#
# add Temporal edges with node  63784  and next month Node  63785
#
# add Temporal edges with node  67083  and next month Node  67084
#
# add Temporal edges with node  70281  and next month Node  70282
#
# add Temporal edges with node  45584  and next month Node  45585
#
# add Temporal edges with node  49384  and next month Node  49385
#
# add Temporal edges with node  53084  and next month Node  53085
#
# add Temporal edges with node  56784  and next month Node  56785
#
# add Temporal edges with node  60384  and next month Node  60385
#
# add Temporal edges with node  63884  and next month Node  63885
#
# add Temporal edges with node  67183  and next month Node  67184
#
# add Temporal edges with node  70381  and next month Node  70382
#
# add Temporal edges with node  63984  and next month Node  63985
#
# add Temporal edges with node  49684  and next month Node  49685
#
# add Temporal edges with node  24985  and next month Node  24986
#
# add Temporal edges with node  27984  and next month Node  27985
#
# add Temporal edges with node  34984  and next month Node  34985
#
# add Temporal edges with node  38684  and next month Node  38685
#
# add Temporal edges with node  42284  and next month Node  42285
#
# add Temporal edges with node  45984  and next month Node  45985
#
# add Temporal edges with node  49784  and next month Node  49785
#
# add Temporal edges with node  77473  and next month Node  77474
#
# add Temporal edges with node  25085  and next month Node  25086
#
# add Temporal edges with node  28084  and next month Node  28085
#
# add Temporal edges with node  31584  and next month Node  31585
#
# add Temporal edges with node  35084  and next month Node  35085
#
# add Temporal edges with node  77573  and next month Node  77574
#
# add Temporal edges with node  78571  and next month Node  78572
#
# add Temporal edges with node  53684  and next month Node  53685
#
# add Temporal edges with node  57384  and next month Node  57385
#
# add Temporal edges with node  77673  and next month Node  77674
#
# add Temporal edges with node  78671  and next month Node  78672
#
# add Temporal edges with node  79969  and next month Node  79970
#
# add Temporal edges with node  25285  and next month Node  25286
#
# add Temporal edges with node  31784  and next month Node  31785
#
# add Temporal edges with node  50084  and next month Node  50085
#
# add Temporal edges with node  53784  and next month Node  53785
#
# add Temporal edges with node  57484  and next month Node  57485
#
# add Temporal edges with node  78771  and next month Node  78772
#
# add Temporal edges with node  80069  and next month Node  80070
#
# add Temporal edges with node  81069  and next month Node  81070
#
# add Temporal edges with node  4788  and next month Node  4789
#
# add Temporal edges with node  6488  and next month Node  6489
#
# add Temporal edges with node  22886  and next month Node  22887
#
# add Temporal edges with node  25385  and next month Node  25386
#
# add Temporal edges with node  28384  and next month Node  28385
#
# add Temporal edges with node  31884  and next month Node  31885
#
# add Temporal edges with node  77873  and next month Node  77874
#
# add Temporal edges with node  3288  and next month Node  3289
#
# add Temporal edges with node  4888  and next month Node  4889
#
# add Temporal edges with node  22986  and next month Node  22987
#
# add Temporal edges with node  28484  and next month Node  28485
#
# add Temporal edges with node  31984  and next month Node  31985
#
# add Temporal edges with node  76373  and next month Node  76374
#
# add Temporal edges with node  77973  and next month Node  77974
#
# add Temporal edges with node  78971  and next month Node  78972
#
# add Temporal edges with node  82369  and next month Node  82370
#
# add Temporal edges with node  83068  and next month Node  83069
#
# add Temporal edges with node  4988  and next month Node  4989
#
# add Temporal edges with node  6688  and next month Node  6689
#
# add Temporal edges with node  10087  and next month Node  10088
#
# add Temporal edges with node  71381  and next month Node  71382
#
# add Temporal edges with node  74177  and next month Node  74178
#
# add Temporal edges with node  76473  and next month Node  76474
#
# add Temporal edges with node  79071  and next month Node  79072
#
# add Temporal edges with node  2188  and next month Node  2189
#
# add Temporal edges with node  3488  and next month Node  3489
#
# add Temporal edges with node  71481  and next month Node  71482
#
# add Temporal edges with node  74277  and next month Node  74278
#
# add Temporal edges with node  76573  and next month Node  76574
#
# add Temporal edges with node  80469  and next month Node  80470
#
# add Temporal edges with node  188  and next month Node  189
#
# add Temporal edges with node  1188  and next month Node  1189
#
# add Temporal edges with node  2288  and next month Node  2289
#
# add Temporal edges with node  13687  and next month Node  13688
#
# add Temporal edges with node  19087  and next month Node  19088
#
# add Temporal edges with node  74377  and next month Node  74378
#
# add Temporal edges with node  288  and next month Node  289
#
# add Temporal edges with node  12087  and next month Node  12088
#
# add Temporal edges with node  15487  and next month Node  15488
#
# add Temporal edges with node  17287  and next month Node  17288
#
# add Temporal edges with node  78371  and next month Node  78372
#
# add Temporal edges with node  17387  and next month Node  17388
#
# add Temporal edges with node  78471  and next month Node  78472
#
# add Temporal edges with node  3888  and next month Node  3889
#
# add Temporal edges with node  5488  and next month Node  5489
#
# add Temporal edges with node  7188  and next month Node  7189
#
# add Temporal edges with node  8888  and next month Node  8889
#
# add Temporal edges with node  23586  and next month Node  23587
#
# add Temporal edges with node  47084  and next month Node  47085
#
# add Temporal edges with node  1588  and next month Node  1589
#
# add Temporal edges with node  2688  and next month Node  2689
#
# add Temporal edges with node  26185  and next month Node  26186
#
# add Temporal edges with node  74777  and next month Node  74778
#
# add Temporal edges with node  688  and next month Node  689
#
# add Temporal edges with node  26285  and next month Node  26286
#
# add Temporal edges with node  29284  and next month Node  29285
#
# add Temporal edges with node  32784  and next month Node  32785
#
# add Temporal edges with node  54784  and next month Node  54785
#
# add Temporal edges with node  74877  and next month Node  74878
#
# add Temporal edges with node  1788  and next month Node  1789
#
# add Temporal edges with node  4188  and next month Node  4189
#
# add Temporal edges with node  5788  and next month Node  5789
#
# add Temporal edges with node  7488  and next month Node  7489
#
# add Temporal edges with node  74977  and next month Node  74978
#
# add Temporal edges with node  1888  and next month Node  1889
#
# add Temporal edges with node  2988  and next month Node  2989
#
# add Temporal edges with node  4288  and next month Node  4289
#
# add Temporal edges with node  5888  and next month Node  5889
#
# add Temporal edges with node  7588  and next month Node  7589
#
# add Temporal edges with node  58684  and next month Node  58685
#
# add Temporal edges with node  62284  and next month Node  62285
#
# add Temporal edges with node  72281  and next month Node  72282
#
# add Temporal edges with node  1988  and next month Node  1989
#
# add Temporal edges with node  5988  and next month Node  5989
#
# add Temporal edges with node  7688  and next month Node  7689
#
# add Temporal edges with node  9388  and next month Node  9389
#
# add Temporal edges with node  14487  and next month Node  14488
#
# add Temporal edges with node  16187  and next month Node  16188
#
# add Temporal edges with node  17987  and next month Node  17988
#
# add Temporal edges with node  7788  and next month Node  7789
#
# add Temporal edges with node  9488  and next month Node  9489
#
# add Temporal edges with node  11187  and next month Node  11188
#
# add Temporal edges with node  14587  and next month Node  14588
#
# add Temporal edges with node  16287  and next month Node  16288
#
# add Temporal edges with node  18087  and next month Node  18088
#
# add Temporal edges with node  19987  and next month Node  19988
#
# add Temporal edges with node  9588  and next month Node  9589
#
# add Temporal edges with node  11287  and next month Node  11288
#
# add Temporal edges with node  12987  and next month Node  12988
#
# add Temporal edges with node  14687  and next month Node  14688
#
# add Temporal edges with node  16387  and next month Node  16388
#
# add Temporal edges with node  18187  and next month Node  18188
#
# add Temporal edges with node  20087  and next month Node  20088
#
# add Temporal edges with node  11387  and next month Node  11388
#
# add Temporal edges with node  13087  and next month Node  13088
#
# add Temporal edges with node  14787  and next month Node  14788
#
# add Temporal edges with node  18287  and next month Node  18288
#
# add Temporal edges with node  20187  and next month Node  20188
#
# add Temporal edges with node  11487  and next month Node  11488
#
# add Temporal edges with node  13187  and next month Node  13188
#
# add Temporal edges with node  14887  and next month Node  14888
#
# add Temporal edges with node  20287  and next month Node  20288
#
# add Temporal edges with node  11587  and next month Node  11588
#
# add Temporal edges with node  13287  and next month Node  13288
#
# add Temporal edges with node  14987  and next month Node  14988
#
# add Temporal edges with node  20387  and next month Node  20388
#
# add Temporal edges with node  22287  and next month Node  22288
#
# add Temporal edges with node  24586  and next month Node  24587
#
# add Temporal edges with node  16787  and next month Node  16788
#
# add Temporal edges with node  18587  and next month Node  18588
#
# add Temporal edges with node  24686  and next month Node  24687
#
# nodes processed: 49304
# current month  202210  next month  202211
# 10 11
# add Temporal edges with node  79470  and next month Node  79471
#
# add Temporal edges with node  80570  and next month Node  80571
#
# add Temporal edges with node  81570  and next month Node  81571
#
# add Temporal edges with node  30385  and next month Node  30386
#
# add Temporal edges with node  79570  and next month Node  79571
#
# add Temporal edges with node  81670  and next month Node  81671
#
# add Temporal edges with node  27086  and next month Node  27087
#
# add Temporal edges with node  37685  and next month Node  37686
#
# add Temporal edges with node  41285  and next month Node  41286
#
# add Temporal edges with node  79670  and next month Node  79671
#
# add Temporal edges with node  37785  and next month Node  37786
#
# add Temporal edges with node  72682  and next month Node  72683
#
# add Temporal edges with node  82669  and next month Node  82670
#
# add Temporal edges with node  48985  and next month Node  48986
#
# add Temporal edges with node  66784  and next month Node  66785
#
# add Temporal edges with node  69982  and next month Node  69983
#
# add Temporal edges with node  72782  and next month Node  72783
#
# add Temporal edges with node  81970  and next month Node  81971
#
# add Temporal edges with node  82769  and next month Node  82770
#
# add Temporal edges with node  49085  and next month Node  49086
#
# add Temporal edges with node  70082  and next month Node  70083
#
# add Temporal edges with node  72882  and next month Node  72883
#
# add Temporal edges with node  75178  and next month Node  75179
#
# add Temporal edges with node  82070  and next month Node  82071
#
# add Temporal edges with node  45385  and next month Node  45386
#
# add Temporal edges with node  49185  and next month Node  49186
#
# add Temporal edges with node  70182  and next month Node  70183
#
# add Temporal edges with node  82969  and next month Node  82970
#
# add Temporal edges with node  30985  and next month Node  30986
#
# add Temporal edges with node  45485  and next month Node  45486
#
# add Temporal edges with node  70282  and next month Node  70283
#
# add Temporal edges with node  75378  and next month Node  75379
#
# add Temporal edges with node  34585  and next month Node  34586
#
# add Temporal edges with node  45585  and next month Node  45586
#
# add Temporal edges with node  67184  and next month Node  67185
#
# add Temporal edges with node  70382  and next month Node  70383
#
# add Temporal edges with node  73180  and next month Node  73181
#
# add Temporal edges with node  34685  and next month Node  34686
#
# add Temporal edges with node  38385  and next month Node  38386
#
# add Temporal edges with node  45685  and next month Node  45686
#
# add Temporal edges with node  53185  and next month Node  53186
#
# add Temporal edges with node  56885  and next month Node  56886
#
# add Temporal edges with node  67284  and next month Node  67285
#
# add Temporal edges with node  70482  and next month Node  70483
#
# add Temporal edges with node  73279  and next month Node  73280
#
# add Temporal edges with node  27786  and next month Node  27787
#
# add Temporal edges with node  31285  and next month Node  31286
#
# add Temporal edges with node  45785  and next month Node  45786
#
# add Temporal edges with node  49585  and next month Node  49586
#
# add Temporal edges with node  56985  and next month Node  56986
#
# add Temporal edges with node  70582  and next month Node  70583
#
# add Temporal edges with node  24886  and next month Node  24887
#
# add Temporal edges with node  27885  and next month Node  27886
#
# add Temporal edges with node  49685  and next month Node  49686
#
# add Temporal edges with node  53385  and next month Node  53386
#
# add Temporal edges with node  57085  and next month Node  57086
#
# add Temporal edges with node  60685  and next month Node  60686
#
# add Temporal edges with node  22487  and next month Node  22488
#
# add Temporal edges with node  24986  and next month Node  24987
#
# add Temporal edges with node  49785  and next month Node  49786
#
# add Temporal edges with node  53485  and next month Node  53486
#
# add Temporal edges with node  25086  and next month Node  25087
#
# add Temporal edges with node  31685  and next month Node  31686
#
# add Temporal edges with node  53685  and next month Node  53686
#
# add Temporal edges with node  57385  and next month Node  57386
#
# add Temporal edges with node  22787  and next month Node  22788
#
# add Temporal edges with node  28285  and next month Node  28286
#
# add Temporal edges with node  35285  and next month Node  35286
#
# add Temporal edges with node  46285  and next month Node  46286
#
# add Temporal edges with node  50085  and next month Node  50086
#
# add Temporal edges with node  53785  and next month Node  53786
#
# add Temporal edges with node  73878  and next month Node  73879
#
# add Temporal edges with node  76174  and next month Node  76175
#
# add Temporal edges with node  76274  and next month Node  76275
#
# add Temporal edges with node  81170  and next month Node  81171
#
# add Temporal edges with node  82270  and next month Node  82271
#
# add Temporal edges with node  6589  and next month Node  6590
#
# add Temporal edges with node  8289  and next month Node  8290
#
# add Temporal edges with node  13388  and next month Node  13389
#
# add Temporal edges with node  22987  and next month Node  22988
#
# add Temporal edges with node  74078  and next month Node  74079
#
# add Temporal edges with node  76374  and next month Node  76375
#
# add Temporal edges with node  77974  and next month Node  77975
#
# add Temporal edges with node  3389  and next month Node  3390
#
# add Temporal edges with node  4989  and next month Node  4990
#
# add Temporal edges with node  10088  and next month Node  10089
#
# add Temporal edges with node  13488  and next month Node  13489
#
# add Temporal edges with node  15188  and next month Node  15189
#
# add Temporal edges with node  39285  and next month Node  39286
#
# add Temporal edges with node  42885  and next month Node  42886
#
# add Temporal edges with node  46585  and next month Node  46586
#
# add Temporal edges with node  50385  and next month Node  50386
#
# add Temporal edges with node  71382  and next month Node  71383
#
# add Temporal edges with node  2189  and next month Node  2190
#
# add Temporal edges with node  3489  and next month Node  3490
#
# add Temporal edges with node  11888  and next month Node  11889
#
# add Temporal edges with node  32185  and next month Node  32186
#
# add Temporal edges with node  35685  and next month Node  35686
#
# add Temporal edges with node  42985  and next month Node  42986
#
# add Temporal edges with node  46685  and next month Node  46686
#
# add Temporal edges with node  79172  and next month Node  79173
#
# add Temporal edges with node  80470  and next month Node  80471
#
# add Temporal edges with node  81470  and next month Node  81471
#
# add Temporal edges with node  82570  and next month Node  82571
#
# add Temporal edges with node  5189  and next month Node  5190
#
# add Temporal edges with node  6889  and next month Node  6890
#
# add Temporal edges with node  8589  and next month Node  8590
#
# add Temporal edges with node  10288  and next month Node  10289
#
# add Temporal edges with node  11988  and next month Node  11989
#
# add Temporal edges with node  23287  and next month Node  23288
#
# add Temporal edges with node  32285  and next month Node  32286
#
# add Temporal edges with node  35785  and next month Node  35786
#
# add Temporal edges with node  39485  and next month Node  39486
#
# add Temporal edges with node  78272  and next month Node  78273
#
# add Temporal edges with node  79271  and next month Node  79272
#
# add Temporal edges with node  3689  and next month Node  3690
#
# add Temporal edges with node  6989  and next month Node  6990
#
# add Temporal edges with node  8689  and next month Node  8690
#
# add Temporal edges with node  10388  and next month Node  10389
#
# add Temporal edges with node  15488  and next month Node  15489
#
# add Temporal edges with node  17288  and next month Node  17289
#
# add Temporal edges with node  19188  and next month Node  19189
#
# add Temporal edges with node  21088  and next month Node  21089
#
# add Temporal edges with node  23387  and next month Node  23388
#
# add Temporal edges with node  35885  and next month Node  35886
#
# add Temporal edges with node  39585  and next month Node  39586
#
# add Temporal edges with node  76774  and next month Node  76775
#
# add Temporal edges with node  2489  and next month Node  2490
#
# add Temporal edges with node  3789  and next month Node  3790
#
# add Temporal edges with node  5389  and next month Node  5390
#
# add Temporal edges with node  7089  and next month Node  7090
#
# add Temporal edges with node  8789  and next month Node  8790
#
# add Temporal edges with node  10488  and next month Node  10489
#
# add Temporal edges with node  12188  and next month Node  12189
#
# add Temporal edges with node  13888  and next month Node  13889
#
# add Temporal edges with node  15588  and next month Node  15589
#
# ...
#
# add Temporal edges with node  63894  and next month Node  63895
#
# add Temporal edges with node  70391  and next month Node  70392
#
# add Temporal edges with node  73189  and next month Node  73190
#
# add Temporal edges with node  27695  and next month Node  27696
#
# add Temporal edges with node  34694  and next month Node  34695
#
# add Temporal edges with node  63994  and next month Node  63995
#
# add Temporal edges with node  67293  and next month Node  67294
#
# add Temporal edges with node  70491  and next month Node  70492
#
# add Temporal edges with node  73288  and next month Node  73289
#
# add Temporal edges with node  75587  and next month Node  75588
#
# add Temporal edges with node  27795  and next month Node  27796
#
# add Temporal edges with node  31294  and next month Node  31295
#
# add Temporal edges with node  34794  and next month Node  34795
#
# add Temporal edges with node  45794  and next month Node  45795
#
# add Temporal edges with node  73387  and next month Node  73388
#
# add Temporal edges with node  24895  and next month Node  24896
#
# add Temporal edges with node  27894  and next month Node  27895
#
# add Temporal edges with node  31394  and next month Node  31395
#
# add Temporal edges with node  53394  and next month Node  53395
#
# add Temporal edges with node  67493  and next month Node  67494
#
# add Temporal edges with node  34994  and next month Node  34995
#
# add Temporal edges with node  45994  and next month Node  45995
#
# add Temporal edges with node  49794  and next month Node  49795
#
# add Temporal edges with node  53494  and next month Node  53495
#
# add Temporal edges with node  57194  and next month Node  57195
#
# add Temporal edges with node  60794  and next month Node  60795
#
# add Temporal edges with node  64294  and next month Node  64295
#
# add Temporal edges with node  67593  and next month Node  67594
#
# add Temporal edges with node  22596  and next month Node  22597
#
# add Temporal edges with node  46094  and next month Node  46095
#
# add Temporal edges with node  64394  and next month Node  64395
#
# add Temporal edges with node  70891  and next month Node  70892
#
# add Temporal edges with node  73687  and next month Node  73688
#
# add Temporal edges with node  75984  and next month Node  75985
#
# add Temporal edges with node  77583  and next month Node  77584
#
# add Temporal edges with node  78581  and next month Node  78582
#
# add Temporal edges with node  22696  and next month Node  22697
#
# add Temporal edges with node  28194  and next month Node  28195
#
# add Temporal edges with node  38894  and next month Node  38895
#
# add Temporal edges with node  42494  and next month Node  42495
#
# add Temporal edges with node  64494  and next month Node  64495
#
# add Temporal edges with node  67793  and next month Node  67794
#
# add Temporal edges with node  70991  and next month Node  70992
#
# add Temporal edges with node  76083  and next month Node  76084
#
# add Temporal edges with node  77683  and next month Node  77684
#
# add Temporal edges with node  78681  and next month Node  78682
#
# add Temporal edges with node  79979  and next month Node  79980
#
# add Temporal edges with node  22796  and next month Node  22797
#
# add Temporal edges with node  31794  and next month Node  31795
#
# add Temporal edges with node  35294  and next month Node  35295
#
# add Temporal edges with node  38994  and next month Node  38995
#
# add Temporal edges with node  42594  and next month Node  42595
#
# add Temporal edges with node  46294  and next month Node  46295
#
# add Temporal edges with node  57494  and next month Node  57495
#
# add Temporal edges with node  61094  and next month Node  61095
#
# add Temporal edges with node  64594  and next month Node  64595
#
# add Temporal edges with node  71091  and next month Node  71092
#
# add Temporal edges with node  73887  and next month Node  73888
#
# add Temporal edges with node  76183  and next month Node  76184
#
# add Temporal edges with node  77783  and next month Node  77784
#
# add Temporal edges with node  78781  and next month Node  78782
#
# add Temporal edges with node  80079  and next month Node  80080
#
# add Temporal edges with node  81079  and next month Node  81080
#
# add Temporal edges with node  20597  and next month Node  20598
#
# add Temporal edges with node  31894  and next month Node  31895
#
# add Temporal edges with node  35394  and next month Node  35395
#
# add Temporal edges with node  39094  and next month Node  39095
#
# add Temporal edges with node  42694  and next month Node  42695
#
# add Temporal edges with node  46394  and next month Node  46395
#
# add Temporal edges with node  50194  and next month Node  50195
#
# add Temporal edges with node  53894  and next month Node  53895
#
# add Temporal edges with node  57594  and next month Node  57595
#
# add Temporal edges with node  76283  and next month Node  76284
#
# add Temporal edges with node  80179  and next month Node  80180
#
# add Temporal edges with node  81179  and next month Node  81180
#
# add Temporal edges with node  82279  and next month Node  82280
#
# add Temporal edges with node  3298  and next month Node  3299
#
# add Temporal edges with node  4898  and next month Node  4899
#
# add Temporal edges with node  15097  and next month Node  15098
#
# add Temporal edges with node  16897  and next month Node  16898
#
# add Temporal edges with node  25495  and next month Node  25496
#
# add Temporal edges with node  35494  and next month Node  35495
#
# add Temporal edges with node  39194  and next month Node  39195
#
# add Temporal edges with node  42794  and next month Node  42795
#
# add Temporal edges with node  46494  and next month Node  46495
#
# add Temporal edges with node  53994  and next month Node  53995
#
# add Temporal edges with node  80279  and next month Node  80280
#
# add Temporal edges with node  82379  and next month Node  82380
#
# add Temporal edges with node  83078  and next month Node  83079
#
# add Temporal edges with node  2098  and next month Node  2099
#
# add Temporal edges with node  3398  and next month Node  3399
#
# add Temporal edges with node  4998  and next month Node  4999
#
# add Temporal edges with node  13497  and next month Node  13498
#
# add Temporal edges with node  16997  and next month Node  16998
#
# add Temporal edges with node  32094  and next month Node  32095
#
# add Temporal edges with node  35594  and next month Node  35595
#
# add Temporal edges with node  39294  and next month Node  39295
#
# add Temporal edges with node  68193  and next month Node  68194
#
# add Temporal edges with node  71391  and next month Node  71392
#
# add Temporal edges with node  76483  and next month Node  76484
#
# add Temporal edges with node  80379  and next month Node  80380
#
# add Temporal edges with node  83178  and next month Node  83179
#
# add Temporal edges with node  2198  and next month Node  2199
#
# add Temporal edges with node  5098  and next month Node  5099
#
# add Temporal edges with node  10197  and next month Node  10198
#
# add Temporal edges with node  15297  and next month Node  15298
#
# add Temporal edges with node  17097  and next month Node  17098
#
# add Temporal edges with node  18997  and next month Node  18998
#
# add Temporal edges with node  32194  and next month Node  32195
#
# add Temporal edges with node  35694  and next month Node  35695
#
# add Temporal edges with node  39394  and next month Node  39395
#
# add Temporal edges with node  57894  and next month Node  57895
#
# add Temporal edges with node  68293  and next month Node  68294
#
# add Temporal edges with node  79181  and next month Node  79182
#
# add Temporal edges with node  80479  and next month Node  80480
#
# add Temporal edges with node  198  and next month Node  199
#
# add Temporal edges with node  1198  and next month Node  1199
#
# add Temporal edges with node  2298  and next month Node  2299
#
# add Temporal edges with node  5198  and next month Node  5199
#
# add Temporal edges with node  11997  and next month Node  11998
#
# add Temporal edges with node  13697  and next month Node  13698
#
# add Temporal edges with node  19097  and next month Node  19098
#
# add Temporal edges with node  23296  and next month Node  23297
#
# add Temporal edges with node  39494  and next month Node  39495
#
# add Temporal edges with node  76683  and next month Node  76684
#
# add Temporal edges with node  79280  and next month Node  79281
#
# add Temporal edges with node  83378  and next month Node  83379
#
# add Temporal edges with node  298  and next month Node  299
#
# add Temporal edges with node  5298  and next month Node  5299
#
# add Temporal edges with node  13797  and next month Node  13798
#
# add Temporal edges with node  15497  and next month Node  15498
#
# add Temporal edges with node  17297  and next month Node  17298
#
# add Temporal edges with node  39594  and next month Node  39595
#
# add Temporal edges with node  43194  and next month Node  43195
#
# add Temporal edges with node  46894  and next month Node  46895
#
# add Temporal edges with node  50694  and next month Node  50695
#
# add Temporal edges with node  54394  and next month Node  54395
#
# add Temporal edges with node  58094  and next month Node  58095
#
# add Temporal edges with node  68493  and next month Node  68494
#
# add Temporal edges with node  79379  and next month Node  79380
#
# add Temporal edges with node  98  and next month Node  99
#
# add Temporal edges with node  1398  and next month Node  1399
#
# add Temporal edges with node  5398  and next month Node  5399
#
# add Temporal edges with node  12197  and next month Node  12198
#
# add Temporal edges with node  23496  and next month Node  23497
#
# add Temporal edges with node  39694  and next month Node  39695
#
# add Temporal edges with node  43294  and next month Node  43295
#
# add Temporal edges with node  46994  and next month Node  46995
#
# add Temporal edges with node  50794  and next month Node  50795
#
# add Temporal edges with node  54494  and next month Node  54495
#
# add Temporal edges with node  61794  and next month Node  61795
#
# add Temporal edges with node  68593  and next month Node  68594
#
# add Temporal edges with node  5498  and next month Node  5499
#
# add Temporal edges with node  12297  and next month Node  12298
#
# add Temporal edges with node  23596  and next month Node  23597
#
# add Temporal edges with node  54594  and next month Node  54595
#
# add Temporal edges with node  74687  and next month Node  74688
#
# add Temporal edges with node  54694  and next month Node  54695
#
# add Temporal edges with node  7398  and next month Node  7399
#
# add Temporal edges with node  10797  and next month Node  10798
#
# add Temporal edges with node  17697  and next month Node  17698
#
# add Temporal edges with node  72091  and next month Node  72092
#
# add Temporal edges with node  74887  and next month Node  74888
#
# add Temporal edges with node  12597  and next month Node  12598
#
# add Temporal edges with node  14297  and next month Node  14298
#
# add Temporal edges with node  29394  and next month Node  29395
#
# add Temporal edges with node  47394  and next month Node  47395
#
# add Temporal edges with node  51194  and next month Node  51195
#
# add Temporal edges with node  54894  and next month Node  54895
#
# add Temporal edges with node  72191  and next month Node  72192
#
# add Temporal edges with node  74987  and next month Node  74988
#
# add Temporal edges with node  898  and next month Node  899
#
# add Temporal edges with node  7598  and next month Node  7599
#
# add Temporal edges with node  29494  and next month Node  29495
#
# add Temporal edges with node  32994  and next month Node  32995
#
# add Temporal edges with node  36494  and next month Node  36495
#
# add Temporal edges with node  40194  and next month Node  40195
#
# add Temporal edges with node  43794  and next month Node  43795
#
# add Temporal edges with node  47494  and next month Node  47495
#
# add Temporal edges with node  51294  and next month Node  51295
#
# add Temporal edges with node  54994  and next month Node  54995
#
# add Temporal edges with node  58694  and next month Node  58695
#
# add Temporal edges with node  62294  and next month Node  62295
#
# add Temporal edges with node  65794  and next month Node  65795
#
# add Temporal edges with node  69093  and next month Node  69094
#
# add Temporal edges with node  72291  and next month Node  72292
#
# add Temporal edges with node  7698  and next month Node  7699
#
# add Temporal edges with node  29594  and next month Node  29595
#
# add Temporal edges with node  33094  and next month Node  33095
#
# add Temporal edges with node  36594  and next month Node  36595
#
# add Temporal edges with node  40294  and next month Node  40295
#
# add Temporal edges with node  43894  and next month Node  43895
#
# add Temporal edges with node  47594  and next month Node  47595
#
# add Temporal edges with node  51394  and next month Node  51395
#
# add Temporal edges with node  55094  and next month Node  55095
#
# add Temporal edges with node  58794  and next month Node  58795
#
# add Temporal edges with node  62394  and next month Node  62395
#
# add Temporal edges with node  65894  and next month Node  65895
#
# add Temporal edges with node  69193  and next month Node  69194
#
# add Temporal edges with node  72391  and next month Node  72392
#
# add Temporal edges with node  998  and next month Node  999
#
# add Temporal edges with node  7798  and next month Node  7799
#
# add Temporal edges with node  29694  and next month Node  29695
#
# add Temporal edges with node  33194  and next month Node  33195
#
# add Temporal edges with node  36694  and next month Node  36695
#
# add Temporal edges with node  40394  and next month Node  40395
#
# add Temporal edges with node  47694  and next month Node  47695
#
# add Temporal edges with node  51494  and next month Node  51495
#
# add Temporal edges with node  55194  and next month Node  55195
#
# add Temporal edges with node  58894  and next month Node  58895
#
# add Temporal edges with node  62494  and next month Node  62495
#
# add Temporal edges with node  65994  and next month Node  65995
#
# add Temporal edges with node  69293  and next month Node  69294
#
# add Temporal edges with node  72491  and next month Node  72492
#
# add Temporal edges with node  20097  and next month Node  20098
#
# add Temporal edges with node  33294  and next month Node  33295
#
# add Temporal edges with node  36794  and next month Node  36795
#
# add Temporal edges with node  40494  and next month Node  40495
#
# add Temporal edges with node  47794  and next month Node  47795
#
# add Temporal edges with node  51594  and next month Node  51595
#
# add Temporal edges with node  55294  and next month Node  55295
#
# add Temporal edges with node  58994  and next month Node  58995
#
# add Temporal edges with node  62594  and next month Node  62595
#
# add Temporal edges with node  66094  and next month Node  66095
#
# add Temporal edges with node  69393  and next month Node  69394
#
# add Temporal edges with node  72591  and next month Node  72592
#
# add Temporal edges with node  20197  and next month Node  20198
#
# add Temporal edges with node  44194  and next month Node  44195
#
# add Temporal edges with node  47894  and next month Node  47895
#
# add Temporal edges with node  51694  and next month Node  51695
#
# add Temporal edges with node  55394  and next month Node  55395
#
# add Temporal edges with node  59094  and next month Node  59095
#
# add Temporal edges with node  62694  and next month Node  62695
#
# add Temporal edges with node  66194  and next month Node  66195
#
# add Temporal edges with node  69493  and next month Node  69494
#
# add Temporal edges with node  9798  and next month Node  9799
#
# add Temporal edges with node  16597  and next month Node  16598
#
# add Temporal edges with node  18397  and next month Node  18398
#
# add Temporal edges with node  20297  and next month Node  20298
#
# add Temporal edges with node  47994  and next month Node  47995
#
# add Temporal edges with node  8198  and next month Node  8199
#
# add Temporal edges with node  14997  and next month Node  14998
#
# add Temporal edges with node  16697  and next month Node  16698
#
# add Temporal edges with node  18497  and next month Node  18498
#
# add Temporal edges with node  16797  and next month Node  16798
#
# add Temporal edges with node  18597  and next month Node  18598
#
# nodes processed: 55156

# %%
row1 = sort_processed_dataset[sort_processed_dataset["row_index"] == 4715]
display(row1)
# Out:
#       Unnamed: 0   Month    Lat    Lon   Lat_nom   Lon_nom  temperature_2m  \
# 4715        4715  201608  4.492 -8.085  0.538469  0.131577        0.619261
#
#       temperature_2m_min  temperature_2m_max  dewpoint_temperature_2m  ...  \
# 4715            0.837604            0.480337                  0.91382  ...
#
#       next_month_tempreature  next_month_precipitation    spei01    spei03  \
# 4715                0.599712                  0.233928  0.584923  0.565931
#
#        year    month2  next_month_soil_moisture_am  next_month_spei01  \
# 4715  0.125  0.636364                     0.511022           0.578787
#
#         datetime  row_index
# 4715  2016-08-01       4715
#
# [1 rows x 31 columns]

# %%
row2 = sort_processed_dataset[sort_processed_dataset["row_index"] == 4799]
display(row2)
# Out:
#       Unnamed: 0   Month    Lat    Lon   Lat_nom   Lon_nom  temperature_2m  \
# 4799        4799  202308  4.492 -8.085  0.538469  0.131577        0.629123
#
#       temperature_2m_min  temperature_2m_max  dewpoint_temperature_2m  ...  \
# 4799             0.84246            0.483874                 0.927895  ...
#
#       next_month_tempreature  next_month_precipitation    spei01    spei03  \
# 4799                0.610467                  0.117995  0.659666  0.665221
#
#       year    month2  next_month_soil_moisture_am  next_month_spei01  \
# 4799   1.0  0.636364                     0.580663           0.582456
#
#         datetime  row_index
# 4799  2023-08-01       4799
#
# [1 rows x 31 columns]

# %%
display_a_to_b_nodes(Spatial_temporal_graph, 836, 846, "row_index")

# %%
display_a_to_b_nodes(Spatial_temporal_graph, 0, 10, "row_index")

# %% [markdown]
# # Create Yearly Temporal edge with same month

# %%
list_of_months = ["01","02","03","04","05","06","07","08","09","10","11","12"]
list_of_years=["2015","2016","2017","2018","2019","2020","2021","2022","2023"]
diffy=1
for m, month in enumerate(list_of_months):
    for y, year in enumerate(list_of_years[:-1]):
    # Get the dataset for the current year of the month and the next year
      currentYearMonth = float(year+month)
      nextYearMonth = float(list_of_years[y+1]+month)
      dataset_subset_1 = sort_processed_dataset[sort_processed_dataset["Month"] == currentYearMonth]
      dataset_subset_2 = sort_processed_dataset[sort_processed_dataset["Month"] == nextYearMonth]
      print("current year month ", currentYearMonth, " next year month ",nextYearMonth)


  	# Create dictionaries for the coordinates
      coords_dict_1 = {(row["Lon"], row["Lat"]): idx for idx, row in dataset_subset_1.iterrows()}
      coords_dict_2 = {(row["Lon"], row["Lat"]): idx for idx, row in dataset_subset_2.iterrows()}


    # Iterate through the first dictionary and check if the coordinates exist in the second dictionary
      if coords_dict_1  is not None:
        for coord, idx1 in coords_dict_1.items():
          idx1_Spei=dataset_subset_1[dataset_subset_1["row_index"] == idx1].iloc[0]['spei01']
          #print("idx1", idx1, " SPEI01 ", idx1_Spei);
          if coords_dict_2 is not None:
            idx2 = coords_dict_2.get(coord)
            if idx2 is not None:
               idx2_Spei=dataset_subset_2[dataset_subset_2["row_index"] == idx2].iloc[0]['spei01']
               #print("idx2", idx2, " SPEI01 ", idx2_Spei);
               speiDiff= abs(idx1_Spei-idx2_Spei)
               if speiDiff<diffy :
                  Spatial_temporal_graph.add_edge(idx1, idx2)
                  print("add Temporal edges with node ", idx1 ," and next year Node ", idx2)
                  print("")
      # Update and print the processed count
      total_index += len(dataset_subset_1)
      print("nodes processed: " + str(total_index))
# Out:
# Streaming output truncated to the last 5000 lines.
#
# add Temporal edges with node  59151  and next year Node  59163
#
# add Temporal edges with node  33451  and next year Node  33463
#
# add Temporal edges with node  37151  and next year Node  37163
#
# add Temporal edges with node  40751  and next year Node  40763
#
# add Temporal edges with node  44451  and next year Node  44463
#
# add Temporal edges with node  48251  and next year Node  48263
#
# add Temporal edges with node  51951  and next year Node  51963
#
# add Temporal edges with node  55651  and next year Node  55663
#
# add Temporal edges with node  59251  and next year Node  59263
#
# add Temporal edges with node  62751  and next year Node  62763
#
# add Temporal edges with node  30051  and next year Node  30063
#
# add Temporal edges with node  33551  and next year Node  33563
#
# add Temporal edges with node  37251  and next year Node  37263
#
# add Temporal edges with node  40851  and next year Node  40863
#
# add Temporal edges with node  44551  and next year Node  44563
#
# add Temporal edges with node  48351  and next year Node  48363
#
# add Temporal edges with node  52051  and next year Node  52063
#
# add Temporal edges with node  55751  and next year Node  55763
#
# add Temporal edges with node  59351  and next year Node  59363
#
# add Temporal edges with node  62851  and next year Node  62863
#
# add Temporal edges with node  30151  and next year Node  30163
#
# add Temporal edges with node  33651  and next year Node  33663
#
# add Temporal edges with node  37351  and next year Node  37363
#
# add Temporal edges with node  40951  and next year Node  40963
#
# add Temporal edges with node  44651  and next year Node  44663
#
# add Temporal edges with node  48451  and next year Node  48463
#
# add Temporal edges with node  52151  and next year Node  52163
#
# add Temporal edges with node  55851  and next year Node  55863
#
# add Temporal edges with node  59451  and next year Node  59463
#
# add Temporal edges with node  62951  and next year Node  62963
#
# add Temporal edges with node  66251  and next year Node  66263
#
# add Temporal edges with node  30251  and next year Node  30263
#
# add Temporal edges with node  33751  and next year Node  33763
#
# add Temporal edges with node  37451  and next year Node  37463
#
# add Temporal edges with node  41051  and next year Node  41063
#
# add Temporal edges with node  44751  and next year Node  44763
#
# add Temporal edges with node  48551  and next year Node  48563
#
# add Temporal edges with node  52251  and next year Node  52263
#
# add Temporal edges with node  55951  and next year Node  55963
#
# add Temporal edges with node  59551  and next year Node  59563
#
# add Temporal edges with node  63051  and next year Node  63063
#
# add Temporal edges with node  66350  and next year Node  66362
#
# add Temporal edges with node  69550  and next year Node  69562
#
# add Temporal edges with node  79436  and next year Node  79448
#
# add Temporal edges with node  80536  and next year Node  80548
#
# add Temporal edges with node  81536  and next year Node  81548
#
# add Temporal edges with node  30351  and next year Node  30363
#
# add Temporal edges with node  33851  and next year Node  33863
#
# add Temporal edges with node  37551  and next year Node  37563
#
# add Temporal edges with node  41151  and next year Node  41163
#
# add Temporal edges with node  44851  and next year Node  44863
#
# add Temporal edges with node  48651  and next year Node  48663
#
# add Temporal edges with node  52351  and next year Node  52363
#
# add Temporal edges with node  56051  and next year Node  56063
#
# add Temporal edges with node  59651  and next year Node  59663
#
# add Temporal edges with node  63151  and next year Node  63163
#
# add Temporal edges with node  66450  and next year Node  66462
#
# add Temporal edges with node  69650  and next year Node  69662
#
# add Temporal edges with node  79536  and next year Node  79548
#
# add Temporal edges with node  80636  and next year Node  80648
#
# add Temporal edges with node  81636  and next year Node  81648
#
# add Temporal edges with node  27052  and next year Node  27064
#
# add Temporal edges with node  30451  and next year Node  30463
#
# add Temporal edges with node  33951  and next year Node  33963
#
# add Temporal edges with node  37651  and next year Node  37663
#
# add Temporal edges with node  41251  and next year Node  41263
#
# add Temporal edges with node  44951  and next year Node  44963
#
# add Temporal edges with node  48751  and next year Node  48763
#
# add Temporal edges with node  52451  and next year Node  52463
#
# add Temporal edges with node  56151  and next year Node  56163
#
# add Temporal edges with node  59751  and next year Node  59763
#
# add Temporal edges with node  63251  and next year Node  63263
#
# add Temporal edges with node  66550  and next year Node  66562
#
# add Temporal edges with node  69750  and next year Node  69762
#
# add Temporal edges with node  79636  and next year Node  79648
#
# add Temporal edges with node  80736  and next year Node  80748
#
# add Temporal edges with node  81736  and next year Node  81748
#
# add Temporal edges with node  27152  and next year Node  27164
#
# add Temporal edges with node  30551  and next year Node  30563
#
# add Temporal edges with node  34051  and next year Node  34063
#
# add Temporal edges with node  37751  and next year Node  37763
#
# add Temporal edges with node  41351  and next year Node  41363
#
# add Temporal edges with node  45051  and next year Node  45063
#
# add Temporal edges with node  48851  and next year Node  48863
#
# add Temporal edges with node  52551  and next year Node  52563
#
# add Temporal edges with node  56251  and next year Node  56263
#
# add Temporal edges with node  59851  and next year Node  59863
#
# add Temporal edges with node  63351  and next year Node  63363
#
# add Temporal edges with node  66650  and next year Node  66662
#
# add Temporal edges with node  69849  and next year Node  69861
#
# add Temporal edges with node  72648  and next year Node  72660
#
# add Temporal edges with node  79736  and next year Node  79748
#
# add Temporal edges with node  80836  and next year Node  80848
#
# add Temporal edges with node  81836  and next year Node  81848
#
# add Temporal edges with node  82636  and next year Node  82648
#
# add Temporal edges with node  24753  and next year Node  24765
#
# add Temporal edges with node  27252  and next year Node  27264
#
# add Temporal edges with node  30651  and next year Node  30663
#
# add Temporal edges with node  34151  and next year Node  34163
#
# add Temporal edges with node  37851  and next year Node  37863
#
# add Temporal edges with node  41451  and next year Node  41463
#
# add Temporal edges with node  45151  and next year Node  45163
#
# add Temporal edges with node  48951  and next year Node  48963
#
# add Temporal edges with node  52651  and next year Node  52663
#
# add Temporal edges with node  56351  and next year Node  56363
#
# add Temporal edges with node  59951  and next year Node  59963
#
# add Temporal edges with node  63451  and next year Node  63463
#
# add Temporal edges with node  66750  and next year Node  66762
#
# add Temporal edges with node  69948  and next year Node  69960
#
# add Temporal edges with node  72748  and next year Node  72760
#
# add Temporal edges with node  75044  and next year Node  75056
#
# add Temporal edges with node  79836  and next year Node  79848
#
# add Temporal edges with node  80936  and next year Node  80948
#
# add Temporal edges with node  81936  and next year Node  81948
#
# add Temporal edges with node  82735  and next year Node  82747
#
# add Temporal edges with node  27352  and next year Node  27364
#
# add Temporal edges with node  30751  and next year Node  30763
#
# add Temporal edges with node  34251  and next year Node  34263
#
# add Temporal edges with node  37951  and next year Node  37963
#
# add Temporal edges with node  41551  and next year Node  41563
#
# add Temporal edges with node  45251  and next year Node  45263
#
# add Temporal edges with node  49051  and next year Node  49063
#
# add Temporal edges with node  52751  and next year Node  52763
#
# add Temporal edges with node  56451  and next year Node  56463
#
# add Temporal edges with node  60051  and next year Node  60063
#
# add Temporal edges with node  63551  and next year Node  63563
#
# add Temporal edges with node  66850  and next year Node  66862
#
# add Temporal edges with node  70048  and next year Node  70060
#
# add Temporal edges with node  72848  and next year Node  72860
#
# add Temporal edges with node  75144  and next year Node  75156
#
# add Temporal edges with node  77040  and next year Node  77052
#
# add Temporal edges with node  82036  and next year Node  82048
#
# add Temporal edges with node  82835  and next year Node  82847
#
# add Temporal edges with node  27452  and next year Node  27464
#
# add Temporal edges with node  30851  and next year Node  30863
#
# add Temporal edges with node  34351  and next year Node  34363
#
# add Temporal edges with node  38051  and next year Node  38063
#
# add Temporal edges with node  41651  and next year Node  41663
#
# add Temporal edges with node  45351  and next year Node  45363
#
# add Temporal edges with node  49151  and next year Node  49163
#
# add Temporal edges with node  52851  and next year Node  52863
#
# add Temporal edges with node  56551  and next year Node  56563
#
# add Temporal edges with node  60151  and next year Node  60163
#
# add Temporal edges with node  63651  and next year Node  63663
#
# add Temporal edges with node  66950  and next year Node  66962
#
# add Temporal edges with node  70148  and next year Node  70160
#
# add Temporal edges with node  72948  and next year Node  72960
#
# add Temporal edges with node  75244  and next year Node  75256
#
# add Temporal edges with node  77140  and next year Node  77152
#
# add Temporal edges with node  82136  and next year Node  82148
#
# add Temporal edges with node  82935  and next year Node  82947
#
# add Temporal edges with node  30951  and next year Node  30963
#
# add Temporal edges with node  34451  and next year Node  34463
#
# add Temporal edges with node  38151  and next year Node  38163
#
# add Temporal edges with node  41751  and next year Node  41763
#
# add Temporal edges with node  45451  and next year Node  45463
#
# add Temporal edges with node  49251  and next year Node  49263
#
# add Temporal edges with node  52951  and next year Node  52963
#
# add Temporal edges with node  56651  and next year Node  56663
#
# add Temporal edges with node  60251  and next year Node  60263
#
# add Temporal edges with node  63751  and next year Node  63763
#
# add Temporal edges with node  67050  and next year Node  67062
#
# add Temporal edges with node  70248  and next year Node  70260
#
# add Temporal edges with node  73048  and next year Node  73060
#
# add Temporal edges with node  75344  and next year Node  75356
#
# add Temporal edges with node  77240  and next year Node  77252
#
# add Temporal edges with node  27552  and next year Node  27564
#
# add Temporal edges with node  31051  and next year Node  31063
#
# add Temporal edges with node  34551  and next year Node  34563
#
# add Temporal edges with node  38251  and next year Node  38263
#
# add Temporal edges with node  41851  and next year Node  41863
#
# add Temporal edges with node  45551  and next year Node  45563
#
# add Temporal edges with node  49351  and next year Node  49363
#
# add Temporal edges with node  53051  and next year Node  53063
#
# add Temporal edges with node  56751  and next year Node  56763
#
# add Temporal edges with node  60351  and next year Node  60363
#
# add Temporal edges with node  63851  and next year Node  63863
#
# add Temporal edges with node  67150  and next year Node  67162
#
# add Temporal edges with node  70348  and next year Node  70360
#
# add Temporal edges with node  73147  and next year Node  73159
#
# add Temporal edges with node  75444  and next year Node  75456
#
# add Temporal edges with node  77340  and next year Node  77352
#
# add Temporal edges with node  27652  and next year Node  27664
#
# add Temporal edges with node  31151  and next year Node  31163
#
# add Temporal edges with node  34651  and next year Node  34663
#
# add Temporal edges with node  38351  and next year Node  38363
#
# add Temporal edges with node  41951  and next year Node  41963
#
# add Temporal edges with node  45651  and next year Node  45663
#
# add Temporal edges with node  49451  and next year Node  49463
#
# add Temporal edges with node  53151  and next year Node  53163
#
# add Temporal edges with node  56851  and next year Node  56863
#
# add Temporal edges with node  60451  and next year Node  60463
#
# add Temporal edges with node  63951  and next year Node  63963
#
# add Temporal edges with node  67250  and next year Node  67262
#
# add Temporal edges with node  70448  and next year Node  70460
#
# add Temporal edges with node  73246  and next year Node  73258
#
# add Temporal edges with node  75544  and next year Node  75556
#
# add Temporal edges with node  27752  and next year Node  27764
#
# add Temporal edges with node  31251  and next year Node  31263
#
# add Temporal edges with node  34751  and next year Node  34763
#
# add Temporal edges with node  38451  and next year Node  38463
#
# add Temporal edges with node  42051  and next year Node  42063
#
# add Temporal edges with node  45751  and next year Node  45763
#
# add Temporal edges with node  49551  and next year Node  49563
#
# add Temporal edges with node  53251  and next year Node  53263
#
# add Temporal edges with node  56951  and next year Node  56963
#
# add Temporal edges with node  60551  and next year Node  60563
#
# add Temporal edges with node  64051  and next year Node  64063
#
# add Temporal edges with node  67350  and next year Node  67362
#
# add Temporal edges with node  70548  and next year Node  70560
#
# add Temporal edges with node  73345  and next year Node  73357
#
# add Temporal edges with node  75644  and next year Node  75656
#
# add Temporal edges with node  24853  and next year Node  24865
#
# add Temporal edges with node  27852  and next year Node  27864
#
# add Temporal edges with node  31351  and next year Node  31363
#
# add Temporal edges with node  34851  and next year Node  34863
#
# add Temporal edges with node  38551  and next year Node  38563
#
# add Temporal edges with node  42151  and next year Node  42163
#
# add Temporal edges with node  45851  and next year Node  45863
#
# add Temporal edges with node  49651  and next year Node  49663
#
# add Temporal edges with node  53351  and next year Node  53363
#
# add Temporal edges with node  57051  and next year Node  57063
#
# add Temporal edges with node  60651  and next year Node  60663
#
# add Temporal edges with node  64151  and next year Node  64163
#
# add Temporal edges with node  67450  and next year Node  67462
#
# add Temporal edges with node  70648  and next year Node  70660
#
# add Temporal edges with node  73444  and next year Node  73456
#
# add Temporal edges with node  75744  and next year Node  75756
#
# add Temporal edges with node  22454  and next year Node  22466
#
# add Temporal edges with node  24952  and next year Node  24964
#
# add Temporal edges with node  27951  and next year Node  27963
#
# add Temporal edges with node  31451  and next year Node  31463
#
# add Temporal edges with node  34951  and next year Node  34963
#
# add Temporal edges with node  38651  and next year Node  38663
#
# add Temporal edges with node  42251  and next year Node  42263
#
# add Temporal edges with node  45951  and next year Node  45963
#
# add Temporal edges with node  49751  and next year Node  49763
#
# add Temporal edges with node  53451  and next year Node  53463
#
# add Temporal edges with node  57151  and next year Node  57163
#
# add Temporal edges with node  60751  and next year Node  60763
#
# add Temporal edges with node  64251  and next year Node  64263
#
# add Temporal edges with node  67550  and next year Node  67562
#
# add Temporal edges with node  70748  and next year Node  70760
#
# add Temporal edges with node  73544  and next year Node  73556
#
# add Temporal edges with node  75843  and next year Node  75855
#
# add Temporal edges with node  77440  and next year Node  77452
#
# add Temporal edges with node  22553  and next year Node  22565
#
# add Temporal edges with node  25052  and next year Node  25064
#
# add Temporal edges with node  28051  and next year Node  28063
#
# add Temporal edges with node  31551  and next year Node  31563
#
# add Temporal edges with node  35051  and next year Node  35063
#
# add Temporal edges with node  38751  and next year Node  38763
#
# add Temporal edges with node  42351  and next year Node  42363
#
# add Temporal edges with node  46051  and next year Node  46063
#
# add Temporal edges with node  49851  and next year Node  49863
#
# add Temporal edges with node  53551  and next year Node  53563
#
# add Temporal edges with node  57251  and next year Node  57263
#
# add Temporal edges with node  60851  and next year Node  60863
#
# add Temporal edges with node  64351  and next year Node  64363
#
# add Temporal edges with node  67650  and next year Node  67662
#
# add Temporal edges with node  70848  and next year Node  70860
#
# add Temporal edges with node  73644  and next year Node  73656
#
# add Temporal edges with node  75942  and next year Node  75954
#
# add Temporal edges with node  77540  and next year Node  77552
#
# add Temporal edges with node  78538  and next year Node  78550
#
# add Temporal edges with node  22653  and next year Node  22665
#
# add Temporal edges with node  25152  and next year Node  25164
#
# add Temporal edges with node  28151  and next year Node  28163
#
# add Temporal edges with node  31651  and next year Node  31663
#
# add Temporal edges with node  35151  and next year Node  35163
#
# add Temporal edges with node  38851  and next year Node  38863
#
# add Temporal edges with node  42451  and next year Node  42463
#
# add Temporal edges with node  46151  and next year Node  46163
#
# add Temporal edges with node  49951  and next year Node  49963
#
# add Temporal edges with node  53651  and next year Node  53663
#
# add Temporal edges with node  57351  and next year Node  57363
#
# add Temporal edges with node  60951  and next year Node  60963
#
# add Temporal edges with node  64451  and next year Node  64463
#
# add Temporal edges with node  67750  and next year Node  67762
#
# add Temporal edges with node  70948  and next year Node  70960
#
# add Temporal edges with node  73744  and next year Node  73756
#
# add Temporal edges with node  76041  and next year Node  76053
#
# add Temporal edges with node  77640  and next year Node  77652
#
# add Temporal edges with node  78638  and next year Node  78650
#
# add Temporal edges with node  79936  and next year Node  79948
#
# add Temporal edges with node  22753  and next year Node  22765
#
# add Temporal edges with node  25252  and next year Node  25264
#
# add Temporal edges with node  28251  and next year Node  28263
#
# add Temporal edges with node  31751  and next year Node  31763
#
# add Temporal edges with node  35251  and next year Node  35263
#
# add Temporal edges with node  38951  and next year Node  38963
#
# add Temporal edges with node  42551  and next year Node  42563
#
# add Temporal edges with node  46251  and next year Node  46263
#
# add Temporal edges with node  50051  and next year Node  50063
#
# add Temporal edges with node  53751  and next year Node  53763
#
# add Temporal edges with node  57451  and next year Node  57463
#
# add Temporal edges with node  61051  and next year Node  61063
#
# add Temporal edges with node  64551  and next year Node  64563
#
# add Temporal edges with node  67850  and next year Node  67862
#
# add Temporal edges with node  71048  and next year Node  71060
#
# add Temporal edges with node  73844  and next year Node  73856
#
# add Temporal edges with node  76140  and next year Node  76152
#
# add Temporal edges with node  77740  and next year Node  77752
#
# add Temporal edges with node  78738  and next year Node  78750
#
# add Temporal edges with node  80036  and next year Node  80048
#
# add Temporal edges with node  81036  and next year Node  81048
#
# add Temporal edges with node  4755  and next year Node  4767
#
# add Temporal edges with node  6455  and next year Node  6467
#
# add Temporal edges with node  18654  and next year Node  18666
#
# add Temporal edges with node  20554  and next year Node  20566
#
# add Temporal edges with node  22853  and next year Node  22865
#
# add Temporal edges with node  25352  and next year Node  25364
#
# add Temporal edges with node  28351  and next year Node  28363
#
# add Temporal edges with node  31851  and next year Node  31863
#
# add Temporal edges with node  35351  and next year Node  35363
#
# add Temporal edges with node  39051  and next year Node  39063
#
# add Temporal edges with node  42651  and next year Node  42663
#
# add Temporal edges with node  46351  and next year Node  46363
#
# add Temporal edges with node  50151  and next year Node  50163
#
# add Temporal edges with node  53851  and next year Node  53863
#
# add Temporal edges with node  57551  and next year Node  57563
#
# add Temporal edges with node  61151  and next year Node  61163
#
# add Temporal edges with node  64651  and next year Node  64663
#
# add Temporal edges with node  67950  and next year Node  67962
#
# add Temporal edges with node  71148  and next year Node  71160
#
# add Temporal edges with node  73944  and next year Node  73956
#
# add Temporal edges with node  76240  and next year Node  76252
#
# add Temporal edges with node  77840  and next year Node  77852
#
# add Temporal edges with node  78838  and next year Node  78850
#
# add Temporal edges with node  80136  and next year Node  80148
#
# add Temporal edges with node  81136  and next year Node  81148
#
# add Temporal edges with node  82236  and next year Node  82248
#
# add Temporal edges with node  3255  and next year Node  3267
#
# add Temporal edges with node  4855  and next year Node  4867
#
# add Temporal edges with node  6555  and next year Node  6567
#
# add Temporal edges with node  8255  and next year Node  8267
#
# add Temporal edges with node  9955  and next year Node  9967
#
# add Temporal edges with node  11654  and next year Node  11666
#
# add Temporal edges with node  13354  and next year Node  13366
#
# add Temporal edges with node  15054  and next year Node  15066
#
# add Temporal edges with node  16854  and next year Node  16866
#
# add Temporal edges with node  18754  and next year Node  18766
#
# add Temporal edges with node  20654  and next year Node  20666
#
# add Temporal edges with node  22953  and next year Node  22965
#
# add Temporal edges with node  25452  and next year Node  25464
#
# add Temporal edges with node  28451  and next year Node  28463
#
# add Temporal edges with node  31951  and next year Node  31963
#
# add Temporal edges with node  35451  and next year Node  35463
#
# add Temporal edges with node  39151  and next year Node  39163
#
# add Temporal edges with node  42751  and next year Node  42763
#
# add Temporal edges with node  46451  and next year Node  46463
#
# add Temporal edges with node  50251  and next year Node  50263
#
# add Temporal edges with node  53951  and next year Node  53963
#
# add Temporal edges with node  57651  and next year Node  57663
#
# add Temporal edges with node  61251  and next year Node  61263
#
# add Temporal edges with node  64751  and next year Node  64763
#
# add Temporal edges with node  68050  and next year Node  68062
#
# add Temporal edges with node  71248  and next year Node  71260
#
# add Temporal edges with node  74044  and next year Node  74056
#
# add Temporal edges with node  76340  and next year Node  76352
#
# add Temporal edges with node  77940  and next year Node  77952
#
# add Temporal edges with node  78938  and next year Node  78950
#
# add Temporal edges with node  80236  and next year Node  80248
#
# add Temporal edges with node  81236  and next year Node  81248
#
# add Temporal edges with node  82336  and next year Node  82348
#
# add Temporal edges with node  83035  and next year Node  83047
#
# add Temporal edges with node  2055  and next year Node  2067
#
# add Temporal edges with node  3355  and next year Node  3367
#
# add Temporal edges with node  4955  and next year Node  4967
#
# add Temporal edges with node  6655  and next year Node  6667
#
# add Temporal edges with node  8355  and next year Node  8367
#
# add Temporal edges with node  10054  and next year Node  10066
#
# add Temporal edges with node  11754  and next year Node  11766
#
# add Temporal edges with node  13454  and next year Node  13466
#
# add Temporal edges with node  15154  and next year Node  15166
#
# add Temporal edges with node  16954  and next year Node  16966
#
# add Temporal edges with node  18854  and next year Node  18866
#
# add Temporal edges with node  20754  and next year Node  20766
#
# add Temporal edges with node  23053  and next year Node  23065
#
# add Temporal edges with node  25552  and next year Node  25564
#
# add Temporal edges with node  28551  and next year Node  28563
#
# add Temporal edges with node  32051  and next year Node  32063
#
# add Temporal edges with node  35551  and next year Node  35563
#
# add Temporal edges with node  39251  and next year Node  39263
#
# add Temporal edges with node  42851  and next year Node  42863
#
# add Temporal edges with node  46551  and next year Node  46563
#
# add Temporal edges with node  50351  and next year Node  50363
#
# add Temporal edges with node  54051  and next year Node  54063
#
# add Temporal edges with node  57751  and next year Node  57763
#
# add Temporal edges with node  61351  and next year Node  61363
#
# add Temporal edges with node  64851  and next year Node  64863
#
# add Temporal edges with node  68150  and next year Node  68162
#
# add Temporal edges with node  71348  and next year Node  71360
#
# add Temporal edges with node  74144  and next year Node  74156
#
# add Temporal edges with node  76440  and next year Node  76452
#
# add Temporal edges with node  78040  and next year Node  78052
#
# add Temporal edges with node  79038  and next year Node  79050
#
# add Temporal edges with node  80336  and next year Node  80348
#
# add Temporal edges with node  81336  and next year Node  81348
#
# add Temporal edges with node  82436  and next year Node  82448
#
# add Temporal edges with node  83135  and next year Node  83147
#
# add Temporal edges with node  1055  and next year Node  1067
#
# add Temporal edges with node  2155  and next year Node  2167
#
# add Temporal edges with node  3455  and next year Node  3467
#
# add Temporal edges with node  5055  and next year Node  5067
#
# add Temporal edges with node  6755  and next year Node  6767
#
# add Temporal edges with node  8455  and next year Node  8467
#
# add Temporal edges with node  10154  and next year Node  10166
#
# add Temporal edges with node  11854  and next year Node  11866
#
# add Temporal edges with node  13554  and next year Node  13566
#
# add Temporal edges with node  15254  and next year Node  15266
#
# add Temporal edges with node  17054  and next year Node  17066
#
# add Temporal edges with node  18954  and next year Node  18966
#
# add Temporal edges with node  20854  and next year Node  20866
#
# add Temporal edges with node  23153  and next year Node  23165
#
# add Temporal edges with node  25652  and next year Node  25664
#
# add Temporal edges with node  28651  and next year Node  28663
#
# add Temporal edges with node  32151  and next year Node  32163
#
# add Temporal edges with node  35651  and next year Node  35663
#
# add Temporal edges with node  39351  and next year Node  39363
#
# add Temporal edges with node  42951  and next year Node  42963
#
# add Temporal edges with node  46651  and next year Node  46663
#
# add Temporal edges with node  50451  and next year Node  50463
#
# add Temporal edges with node  54151  and next year Node  54163
#
# add Temporal edges with node  57851  and next year Node  57863
#
# add Temporal edges with node  61451  and next year Node  61463
#
# add Temporal edges with node  64951  and next year Node  64963
#
# add Temporal edges with node  68250  and next year Node  68262
#
# add Temporal edges with node  71448  and next year Node  71460
#
# add Temporal edges with node  74244  and next year Node  74256
#
# add Temporal edges with node  76540  and next year Node  76552
#
# add Temporal edges with node  78139  and next year Node  78151
#
# add Temporal edges with node  79138  and next year Node  79150
#
# add Temporal edges with node  80436  and next year Node  80448
#
# add Temporal edges with node  81436  and next year Node  81448
#
# add Temporal edges with node  82536  and next year Node  82548
#
# add Temporal edges with node  83235  and next year Node  83247
#
# add Temporal edges with node  83435  and next year Node  83447
#
# add Temporal edges with node  155  and next year Node  167
#
# add Temporal edges with node  1155  and next year Node  1167
#
# add Temporal edges with node  2255  and next year Node  2267
#
# add Temporal edges with node  3555  and next year Node  3567
#
# add Temporal edges with node  5155  and next year Node  5167
#
# add Temporal edges with node  6855  and next year Node  6867
#
# add Temporal edges with node  8555  and next year Node  8567
#
# add Temporal edges with node  10254  and next year Node  10266
#
# add Temporal edges with node  11954  and next year Node  11966
#
# add Temporal edges with node  13654  and next year Node  13666
#
# add Temporal edges with node  15354  and next year Node  15366
#
# add Temporal edges with node  17154  and next year Node  17166
#
# add Temporal edges with node  19054  and next year Node  19066
#
# add Temporal edges with node  20954  and next year Node  20966
#
# add Temporal edges with node  23253  and next year Node  23265
#
# add Temporal edges with node  25752  and next year Node  25764
#
# add Temporal edges with node  28751  and next year Node  28763
#
# add Temporal edges with node  32251  and next year Node  32263
#
# add Temporal edges with node  35751  and next year Node  35763
#
# add Temporal edges with node  39451  and next year Node  39463
#
# add Temporal edges with node  43051  and next year Node  43063
#
# add Temporal edges with node  46751  and next year Node  46763
#
# add Temporal edges with node  50551  and next year Node  50563
#
# add Temporal edges with node  54251  and next year Node  54263
#
# add Temporal edges with node  57951  and next year Node  57963
#
# add Temporal edges with node  61551  and next year Node  61563
#
# add Temporal edges with node  65051  and next year Node  65063
#
# add Temporal edges with node  68350  and next year Node  68362
#
# add Temporal edges with node  71548  and next year Node  71560
#
# add Temporal edges with node  74344  and next year Node  74356
#
# add Temporal edges with node  76640  and next year Node  76652
#
# add Temporal edges with node  78238  and next year Node  78250
#
# add Temporal edges with node  79238  and next year Node  79250
#
# add Temporal edges with node  83335  and next year Node  83347
#
# add Temporal edges with node  83535  and next year Node  83547
#
# add Temporal edges with node  255  and next year Node  267
#
# add Temporal edges with node  1255  and next year Node  1267
#
# add Temporal edges with node  2355  and next year Node  2367
#
# add Temporal edges with node  3655  and next year Node  3667
#
# add Temporal edges with node  5255  and next year Node  5267
#
# add Temporal edges with node  6955  and next year Node  6967
#
# add Temporal edges with node  8655  and next year Node  8667
#
# add Temporal edges with node  10354  and next year Node  10366
#
# add Temporal edges with node  12054  and next year Node  12066
#
# add Temporal edges with node  13754  and next year Node  13766
#
# add Temporal edges with node  15454  and next year Node  15466
#
# add Temporal edges with node  17254  and next year Node  17266
#
# add Temporal edges with node  19154  and next year Node  19166
#
# add Temporal edges with node  21054  and next year Node  21066
#
# add Temporal edges with node  23353  and next year Node  23365
#
# add Temporal edges with node  25852  and next year Node  25864
#
# add Temporal edges with node  28851  and next year Node  28863
#
# add Temporal edges with node  32351  and next year Node  32363
#
# add Temporal edges with node  35851  and next year Node  35863
#
# add Temporal edges with node  39551  and next year Node  39563
#
# add Temporal edges with node  43151  and next year Node  43163
#
# add Temporal edges with node  46851  and next year Node  46863
#
# add Temporal edges with node  50651  and next year Node  50663
#
# add Temporal edges with node  54351  and next year Node  54363
#
# add Temporal edges with node  58051  and next year Node  58063
#
# add Temporal edges with node  61651  and next year Node  61663
#
# add Temporal edges with node  65151  and next year Node  65163
#
# add Temporal edges with node  68450  and next year Node  68462
#
# add Temporal edges with node  71648  and next year Node  71660
#
# add Temporal edges with node  74444  and next year Node  74456
#
# add Temporal edges with node  76740  and next year Node  76752
#
# add Temporal edges with node  78338  and next year Node  78350
#
# add Temporal edges with node  79337  and next year Node  79349
#
# add Temporal edges with node  55  and next year Node  67
#
# add Temporal edges with node  355  and next year Node  367
#
# add Temporal edges with node  1355  and next year Node  1367
#
# add Temporal edges with node  2455  and next year Node  2467
#
# add Temporal edges with node  3755  and next year Node  3767
#
# add Temporal edges with node  5355  and next year Node  5367
#
# add Temporal edges with node  7055  and next year Node  7067
#
# add Temporal edges with node  8755  and next year Node  8767
#
# add Temporal edges with node  10454  and next year Node  10466
#
# add Temporal edges with node  12154  and next year Node  12166
#
# add Temporal edges with node  13854  and next year Node  13866
#
# add Temporal edges with node  15554  and next year Node  15566
#
# add Temporal edges with node  17354  and next year Node  17366
#
# add Temporal edges with node  19254  and next year Node  19266
#
# add Temporal edges with node  21154  and next year Node  21166
#
# add Temporal edges with node  23453  and next year Node  23465
#
# add Temporal edges with node  25952  and next year Node  25964
#
# add Temporal edges with node  28951  and next year Node  28963
#
# add Temporal edges with node  32451  and next year Node  32463
#
# add Temporal edges with node  35951  and next year Node  35963
#
# add Temporal edges with node  39651  and next year Node  39663
#
# add Temporal edges with node  43251  and next year Node  43263
#
# add Temporal edges with node  46951  and next year Node  46963
#
# add Temporal edges with node  50751  and next year Node  50763
#
# add Temporal edges with node  54451  and next year Node  54463
#
# add Temporal edges with node  58151  and next year Node  58163
#
# add Temporal edges with node  61751  and next year Node  61763
#
# add Temporal edges with node  65251  and next year Node  65263
#
# add Temporal edges with node  68550  and next year Node  68562
#
# add Temporal edges with node  71748  and next year Node  71760
#
# add Temporal edges with node  74544  and next year Node  74556
#
# add Temporal edges with node  76840  and next year Node  76852
#
# add Temporal edges with node  78438  and next year Node  78450
#
# add Temporal edges with node  455  and next year Node  467
#
# add Temporal edges with node  1455  and next year Node  1467
#
# add Temporal edges with node  2555  and next year Node  2567
#
# add Temporal edges with node  3855  and next year Node  3867
#
# add Temporal edges with node  5455  and next year Node  5467
#
# add Temporal edges with node  7155  and next year Node  7167
#
# add Temporal edges with node  8855  and next year Node  8867
#
# add Temporal edges with node  10554  and next year Node  10566
#
# add Temporal edges with node  12254  and next year Node  12266
#
# add Temporal edges with node  13954  and next year Node  13966
#
# add Temporal edges with node  15654  and next year Node  15666
#
# add Temporal edges with node  17454  and next year Node  17466
#
# add Temporal edges with node  19354  and next year Node  19366
#
# add Temporal edges with node  21254  and next year Node  21266
#
# add Temporal edges with node  23553  and next year Node  23565
#
# add Temporal edges with node  26052  and next year Node  26064
#
# add Temporal edges with node  29051  and next year Node  29063
#
# add Temporal edges with node  32551  and next year Node  32563
#
# add Temporal edges with node  36051  and next year Node  36063
#
# add Temporal edges with node  39751  and next year Node  39763
#
# add Temporal edges with node  43351  and next year Node  43363
#
# add Temporal edges with node  47051  and next year Node  47063
#
# add Temporal edges with node  50851  and next year Node  50863
#
# add Temporal edges with node  54551  and next year Node  54563
#
# add Temporal edges with node  58251  and next year Node  58263
#
# add Temporal edges with node  61851  and next year Node  61863
#
# add Temporal edges with node  65351  and next year Node  65363
#
# add Temporal edges with node  68650  and next year Node  68662
#
# add Temporal edges with node  71848  and next year Node  71860
#
# add Temporal edges with node  74644  and next year Node  74656
#
# add Temporal edges with node  76940  and next year Node  76952
#
# add Temporal edges with node  555  and next year Node  567
#
# add Temporal edges with node  1555  and next year Node  1567
#
# add Temporal edges with node  2655  and next year Node  2667
#
# add Temporal edges with node  3955  and next year Node  3967
#
# add Temporal edges with node  5555  and next year Node  5567
#
# add Temporal edges with node  7255  and next year Node  7267
#
# add Temporal edges with node  8955  and next year Node  8967
#
# add Temporal edges with node  10654  and next year Node  10666
#
# add Temporal edges with node  12354  and next year Node  12366
#
# add Temporal edges with node  14054  and next year Node  14066
#
# add Temporal edges with node  15754  and next year Node  15766
#
# add Temporal edges with node  17554  and next year Node  17566
#
# add Temporal edges with node  19454  and next year Node  19466
#
# add Temporal edges with node  21354  and next year Node  21366
#
# add Temporal edges with node  23653  and next year Node  23665
#
# add Temporal edges with node  26152  and next year Node  26164
#
# add Temporal edges with node  29151  and next year Node  29163
#
# add Temporal edges with node  32651  and next year Node  32663
#
# add Temporal edges with node  36151  and next year Node  36163
#
# add Temporal edges with node  39851  and next year Node  39863
#
# add Temporal edges with node  43451  and next year Node  43463
#
# add Temporal edges with node  47151  and next year Node  47163
#
# add Temporal edges with node  50951  and next year Node  50963
#
# add Temporal edges with node  54651  and next year Node  54663
#
# add Temporal edges with node  58351  and next year Node  58363
#
# add Temporal edges with node  61951  and next year Node  61963
#
# add Temporal edges with node  65451  and next year Node  65463
#
# add Temporal edges with node  68750  and next year Node  68762
#
# add Temporal edges with node  71948  and next year Node  71960
#
# add Temporal edges with node  74744  and next year Node  74756
#
# add Temporal edges with node  655  and next year Node  667
#
# add Temporal edges with node  1655  and next year Node  1667
#
# add Temporal edges with node  2755  and next year Node  2767
#
# add Temporal edges with node  4055  and next year Node  4067
#
# add Temporal edges with node  5655  and next year Node  5667
#
# add Temporal edges with node  7355  and next year Node  7367
#
# add Temporal edges with node  9055  and next year Node  9067
#
# add Temporal edges with node  10754  and next year Node  10766
#
# add Temporal edges with node  12454  and next year Node  12466
#
# add Temporal edges with node  14154  and next year Node  14166
#
# add Temporal edges with node  15854  and next year Node  15866
#
# add Temporal edges with node  17654  and next year Node  17666
#
# add Temporal edges with node  19554  and next year Node  19566
#
# add Temporal edges with node  21454  and next year Node  21466
#
# add Temporal edges with node  23753  and next year Node  23765
#
# add Temporal edges with node  26252  and next year Node  26264
#
# add Temporal edges with node  29251  and next year Node  29263
#
# add Temporal edges with node  32751  and next year Node  32763
#
# add Temporal edges with node  36251  and next year Node  36263
#
# add Temporal edges with node  39951  and next year Node  39963
#
# add Temporal edges with node  43551  and next year Node  43563
#
# add Temporal edges with node  47251  and next year Node  47263
#
# add Temporal edges with node  51051  and next year Node  51063
#
# add Temporal edges with node  54751  and next year Node  54763
#
# add Temporal edges with node  58451  and next year Node  58463
#
# add Temporal edges with node  62051  and next year Node  62063
#
# add Temporal edges with node  65551  and next year Node  65563
#
# add Temporal edges with node  68850  and next year Node  68862
#
# add Temporal edges with node  72048  and next year Node  72060
#
# add Temporal edges with node  74844  and next year Node  74856
#
# add Temporal edges with node  755  and next year Node  767
#
# add Temporal edges with node  1755  and next year Node  1767
#
# add Temporal edges with node  2855  and next year Node  2867
#
# add Temporal edges with node  4155  and next year Node  4167
#
# add Temporal edges with node  5755  and next year Node  5767
#
# add Temporal edges with node  7455  and next year Node  7467
#
# add Temporal edges with node  9155  and next year Node  9167
#
# add Temporal edges with node  10854  and next year Node  10866
#
# add Temporal edges with node  12554  and next year Node  12566
#
# add Temporal edges with node  14254  and next year Node  14266
#
# add Temporal edges with node  15954  and next year Node  15966
#
# add Temporal edges with node  17754  and next year Node  17766
#
# add Temporal edges with node  19654  and next year Node  19666
#
# add Temporal edges with node  21554  and next year Node  21566
#
# add Temporal edges with node  23853  and next year Node  23865
#
# add Temporal edges with node  26352  and next year Node  26364
#
# add Temporal edges with node  29351  and next year Node  29363
#
# add Temporal edges with node  32851  and next year Node  32863
#
# add Temporal edges with node  36351  and next year Node  36363
#
# add Temporal edges with node  40051  and next year Node  40063
#
# add Temporal edges with node  43651  and next year Node  43663
#
# add Temporal edges with node  47351  and next year Node  47363
#
# add Temporal edges with node  51151  and next year Node  51163
#
# add Temporal edges with node  54851  and next year Node  54863
#
# add Temporal edges with node  58551  and next year Node  58563
#
# add Temporal edges with node  62151  and next year Node  62163
#
# add Temporal edges with node  65651  and next year Node  65663
#
# add Temporal edges with node  68950  and next year Node  68962
#
# add Temporal edges with node  72148  and next year Node  72160
#
# add Temporal edges with node  74944  and next year Node  74956
#
# add Temporal edges with node  855  and next year Node  867
#
# add Temporal edges with node  1855  and next year Node  1867
#
# add Temporal edges with node  2955  and next year Node  2967
#
# add Temporal edges with node  4255  and next year Node  4267
#
# add Temporal edges with node  5855  and next year Node  5867
#
# add Temporal edges with node  7555  and next year Node  7567
#
# add Temporal edges with node  9255  and next year Node  9267
#
# add Temporal edges with node  10954  and next year Node  10966
#
# add Temporal edges with node  12654  and next year Node  12666
#
# add Temporal edges with node  14354  and next year Node  14366
#
# add Temporal edges with node  16054  and next year Node  16066
#
# add Temporal edges with node  17854  and next year Node  17866
#
# add Temporal edges with node  19754  and next year Node  19766
#
# add Temporal edges with node  21654  and next year Node  21666
#
# add Temporal edges with node  23953  and next year Node  23965
#
# add Temporal edges with node  26452  and next year Node  26464
#
# add Temporal edges with node  29451  and next year Node  29463
#
# add Temporal edges with node  32951  and next year Node  32963
#
# add Temporal edges with node  36451  and next year Node  36463
#
# add Temporal edges with node  40151  and next year Node  40163
#
# add Temporal edges with node  43751  and next year Node  43763
#
# add Temporal edges with node  47451  and next year Node  47463
#
# add Temporal edges with node  51251  and next year Node  51263
#
# add Temporal edges with node  54951  and next year Node  54963
#
# add Temporal edges with node  58651  and next year Node  58663
#
# add Temporal edges with node  62251  and next year Node  62263
#
# add Temporal edges with node  65751  and next year Node  65763
#
# add Temporal edges with node  69050  and next year Node  69062
#
# add Temporal edges with node  72248  and next year Node  72260
#
# add Temporal edges with node  1955  and next year Node  1967
#
# add Temporal edges with node  3055  and next year Node  3067
#
# add Temporal edges with node  4355  and next year Node  4367
#
# add Temporal edges with node  5955  and next year Node  5967
#
# add Temporal edges with node  7655  and next year Node  7667
#
# add Temporal edges with node  9355  and next year Node  9367
#
# add Temporal edges with node  11054  and next year Node  11066
#
# add Temporal edges with node  12754  and next year Node  12766
#
# add Temporal edges with node  14454  and next year Node  14466
#
# add Temporal edges with node  16154  and next year Node  16166
#
# add Temporal edges with node  17954  and next year Node  17966
#
# add Temporal edges with node  19854  and next year Node  19866
#
# add Temporal edges with node  21754  and next year Node  21766
#
# add Temporal edges with node  24053  and next year Node  24065
#
# add Temporal edges with node  26552  and next year Node  26564
#
# add Temporal edges with node  29551  and next year Node  29563
#
# add Temporal edges with node  33051  and next year Node  33063
#
# add Temporal edges with node  36551  and next year Node  36563
#
# add Temporal edges with node  40251  and next year Node  40263
#
# add Temporal edges with node  43851  and next year Node  43863
#
# add Temporal edges with node  47551  and next year Node  47563
#
# add Temporal edges with node  51351  and next year Node  51363
#
# add Temporal edges with node  55051  and next year Node  55063
#
# add Temporal edges with node  58751  and next year Node  58763
#
# add Temporal edges with node  62351  and next year Node  62363
#
# add Temporal edges with node  65851  and next year Node  65863
#
# add Temporal edges with node  69150  and next year Node  69162
#
# add Temporal edges with node  72348  and next year Node  72360
#
# add Temporal edges with node  955  and next year Node  967
#
# add Temporal edges with node  3155  and next year Node  3167
#
# add Temporal edges with node  4455  and next year Node  4467
#
# add Temporal edges with node  6055  and next year Node  6067
#
# add Temporal edges with node  7755  and next year Node  7767
#
# add Temporal edges with node  9455  and next year Node  9467
#
# add Temporal edges with node  11154  and next year Node  11166
#
# add Temporal edges with node  12854  and next year Node  12866
#
# add Temporal edges with node  14554  and next year Node  14566
#
# add Temporal edges with node  16254  and next year Node  16266
#
# add Temporal edges with node  18054  and next year Node  18066
#
# add Temporal edges with node  19954  and next year Node  19966
#
# add Temporal edges with node  21854  and next year Node  21866
#
# add Temporal edges with node  24153  and next year Node  24165
#
# add Temporal edges with node  26652  and next year Node  26664
#
# add Temporal edges with node  29651  and next year Node  29663
#
# add Temporal edges with node  33151  and next year Node  33163
#
# add Temporal edges with node  36651  and next year Node  36663
#
# add Temporal edges with node  40351  and next year Node  40363
#
# add Temporal edges with node  43951  and next year Node  43963
#
# add Temporal edges with node  47651  and next year Node  47663
#
# add Temporal edges with node  51451  and next year Node  51463
#
# add Temporal edges with node  55151  and next year Node  55163
#
# add Temporal edges with node  58851  and next year Node  58863
#
# add Temporal edges with node  62451  and next year Node  62463
#
# add Temporal edges with node  65951  and next year Node  65963
#
# add Temporal edges with node  69250  and next year Node  69262
#
# add Temporal edges with node  72448  and next year Node  72460
#
# add Temporal edges with node  4555  and next year Node  4567
#
# add Temporal edges with node  6155  and next year Node  6167
#
# add Temporal edges with node  7855  and next year Node  7867
#
# add Temporal edges with node  9555  and next year Node  9567
#
# add Temporal edges with node  11254  and next year Node  11266
#
# add Temporal edges with node  12954  and next year Node  12966
#
# add Temporal edges with node  14654  and next year Node  14666
#
# ...
#
# add Temporal edges with node  5579  and next year Node  5591
#
# add Temporal edges with node  7279  and next year Node  7291
#
# add Temporal edges with node  8979  and next year Node  8991
#
# add Temporal edges with node  10678  and next year Node  10690
#
# add Temporal edges with node  12378  and next year Node  12390
#
# add Temporal edges with node  14078  and next year Node  14090
#
# add Temporal edges with node  15778  and next year Node  15790
#
# add Temporal edges with node  17578  and next year Node  17590
#
# add Temporal edges with node  19478  and next year Node  19490
#
# add Temporal edges with node  21378  and next year Node  21390
#
# add Temporal edges with node  23677  and next year Node  23689
#
# add Temporal edges with node  26176  and next year Node  26188
#
# add Temporal edges with node  29175  and next year Node  29187
#
# add Temporal edges with node  32675  and next year Node  32687
#
# add Temporal edges with node  36175  and next year Node  36187
#
# add Temporal edges with node  39875  and next year Node  39887
#
# add Temporal edges with node  43475  and next year Node  43487
#
# add Temporal edges with node  47175  and next year Node  47187
#
# add Temporal edges with node  50975  and next year Node  50987
#
# add Temporal edges with node  54675  and next year Node  54687
#
# add Temporal edges with node  58375  and next year Node  58387
#
# add Temporal edges with node  61975  and next year Node  61987
#
# add Temporal edges with node  65475  and next year Node  65487
#
# add Temporal edges with node  68774  and next year Node  68786
#
# add Temporal edges with node  71972  and next year Node  71984
#
# add Temporal edges with node  74768  and next year Node  74780
#
# add Temporal edges with node  679  and next year Node  691
#
# add Temporal edges with node  1679  and next year Node  1691
#
# add Temporal edges with node  2779  and next year Node  2791
#
# add Temporal edges with node  4079  and next year Node  4091
#
# add Temporal edges with node  5679  and next year Node  5691
#
# add Temporal edges with node  7379  and next year Node  7391
#
# add Temporal edges with node  9079  and next year Node  9091
#
# add Temporal edges with node  10778  and next year Node  10790
#
# add Temporal edges with node  12478  and next year Node  12490
#
# add Temporal edges with node  14178  and next year Node  14190
#
# add Temporal edges with node  15878  and next year Node  15890
#
# add Temporal edges with node  17678  and next year Node  17690
#
# add Temporal edges with node  19578  and next year Node  19590
#
# add Temporal edges with node  21478  and next year Node  21490
#
# add Temporal edges with node  23777  and next year Node  23789
#
# add Temporal edges with node  26276  and next year Node  26288
#
# add Temporal edges with node  29275  and next year Node  29287
#
# add Temporal edges with node  32775  and next year Node  32787
#
# add Temporal edges with node  36275  and next year Node  36287
#
# add Temporal edges with node  39975  and next year Node  39987
#
# add Temporal edges with node  43575  and next year Node  43587
#
# add Temporal edges with node  47275  and next year Node  47287
#
# add Temporal edges with node  51075  and next year Node  51087
#
# add Temporal edges with node  54775  and next year Node  54787
#
# add Temporal edges with node  58475  and next year Node  58487
#
# add Temporal edges with node  62075  and next year Node  62087
#
# add Temporal edges with node  65575  and next year Node  65587
#
# add Temporal edges with node  68874  and next year Node  68886
#
# add Temporal edges with node  72072  and next year Node  72084
#
# add Temporal edges with node  74868  and next year Node  74880
#
# add Temporal edges with node  779  and next year Node  791
#
# add Temporal edges with node  1779  and next year Node  1791
#
# add Temporal edges with node  2879  and next year Node  2891
#
# add Temporal edges with node  4179  and next year Node  4191
#
# add Temporal edges with node  5779  and next year Node  5791
#
# add Temporal edges with node  7479  and next year Node  7491
#
# add Temporal edges with node  9179  and next year Node  9191
#
# add Temporal edges with node  10878  and next year Node  10890
#
# add Temporal edges with node  12578  and next year Node  12590
#
# add Temporal edges with node  14278  and next year Node  14290
#
# add Temporal edges with node  15978  and next year Node  15990
#
# add Temporal edges with node  17778  and next year Node  17790
#
# add Temporal edges with node  19678  and next year Node  19690
#
# add Temporal edges with node  21578  and next year Node  21590
#
# add Temporal edges with node  23877  and next year Node  23889
#
# add Temporal edges with node  26376  and next year Node  26388
#
# add Temporal edges with node  29375  and next year Node  29387
#
# add Temporal edges with node  32875  and next year Node  32887
#
# add Temporal edges with node  36375  and next year Node  36387
#
# add Temporal edges with node  40075  and next year Node  40087
#
# add Temporal edges with node  43675  and next year Node  43687
#
# add Temporal edges with node  47375  and next year Node  47387
#
# add Temporal edges with node  51175  and next year Node  51187
#
# add Temporal edges with node  54875  and next year Node  54887
#
# add Temporal edges with node  58575  and next year Node  58587
#
# add Temporal edges with node  62175  and next year Node  62187
#
# add Temporal edges with node  65675  and next year Node  65687
#
# add Temporal edges with node  68974  and next year Node  68986
#
# add Temporal edges with node  72172  and next year Node  72184
#
# add Temporal edges with node  74968  and next year Node  74980
#
# add Temporal edges with node  879  and next year Node  891
#
# add Temporal edges with node  1879  and next year Node  1891
#
# add Temporal edges with node  2979  and next year Node  2991
#
# add Temporal edges with node  4279  and next year Node  4291
#
# add Temporal edges with node  5879  and next year Node  5891
#
# add Temporal edges with node  7579  and next year Node  7591
#
# add Temporal edges with node  9279  and next year Node  9291
#
# add Temporal edges with node  10978  and next year Node  10990
#
# add Temporal edges with node  12678  and next year Node  12690
#
# add Temporal edges with node  14378  and next year Node  14390
#
# add Temporal edges with node  16078  and next year Node  16090
#
# add Temporal edges with node  17878  and next year Node  17890
#
# add Temporal edges with node  19778  and next year Node  19790
#
# add Temporal edges with node  21678  and next year Node  21690
#
# add Temporal edges with node  23977  and next year Node  23989
#
# add Temporal edges with node  26476  and next year Node  26488
#
# add Temporal edges with node  29475  and next year Node  29487
#
# add Temporal edges with node  32975  and next year Node  32987
#
# add Temporal edges with node  36475  and next year Node  36487
#
# add Temporal edges with node  40175  and next year Node  40187
#
# add Temporal edges with node  43775  and next year Node  43787
#
# add Temporal edges with node  47475  and next year Node  47487
#
# add Temporal edges with node  51275  and next year Node  51287
#
# add Temporal edges with node  54975  and next year Node  54987
#
# add Temporal edges with node  58675  and next year Node  58687
#
# add Temporal edges with node  62275  and next year Node  62287
#
# add Temporal edges with node  65775  and next year Node  65787
#
# add Temporal edges with node  69074  and next year Node  69086
#
# add Temporal edges with node  72272  and next year Node  72284
#
# add Temporal edges with node  1979  and next year Node  1991
#
# add Temporal edges with node  3079  and next year Node  3091
#
# add Temporal edges with node  4379  and next year Node  4391
#
# add Temporal edges with node  5979  and next year Node  5991
#
# add Temporal edges with node  7679  and next year Node  7691
#
# add Temporal edges with node  9379  and next year Node  9391
#
# add Temporal edges with node  11078  and next year Node  11090
#
# add Temporal edges with node  12778  and next year Node  12790
#
# add Temporal edges with node  14478  and next year Node  14490
#
# add Temporal edges with node  16178  and next year Node  16190
#
# add Temporal edges with node  17978  and next year Node  17990
#
# add Temporal edges with node  19878  and next year Node  19890
#
# add Temporal edges with node  21778  and next year Node  21790
#
# add Temporal edges with node  24077  and next year Node  24089
#
# add Temporal edges with node  26576  and next year Node  26588
#
# add Temporal edges with node  29575  and next year Node  29587
#
# add Temporal edges with node  33075  and next year Node  33087
#
# add Temporal edges with node  36575  and next year Node  36587
#
# add Temporal edges with node  40275  and next year Node  40287
#
# add Temporal edges with node  43875  and next year Node  43887
#
# add Temporal edges with node  47575  and next year Node  47587
#
# add Temporal edges with node  51375  and next year Node  51387
#
# add Temporal edges with node  55075  and next year Node  55087
#
# add Temporal edges with node  58775  and next year Node  58787
#
# add Temporal edges with node  62375  and next year Node  62387
#
# add Temporal edges with node  65875  and next year Node  65887
#
# add Temporal edges with node  69174  and next year Node  69186
#
# add Temporal edges with node  72372  and next year Node  72384
#
# add Temporal edges with node  979  and next year Node  991
#
# add Temporal edges with node  3179  and next year Node  3191
#
# add Temporal edges with node  4479  and next year Node  4491
#
# add Temporal edges with node  6079  and next year Node  6091
#
# add Temporal edges with node  7779  and next year Node  7791
#
# add Temporal edges with node  9479  and next year Node  9491
#
# add Temporal edges with node  11178  and next year Node  11190
#
# add Temporal edges with node  12878  and next year Node  12890
#
# add Temporal edges with node  14578  and next year Node  14590
#
# add Temporal edges with node  16278  and next year Node  16290
#
# add Temporal edges with node  18078  and next year Node  18090
#
# add Temporal edges with node  19978  and next year Node  19990
#
# add Temporal edges with node  21878  and next year Node  21890
#
# add Temporal edges with node  24177  and next year Node  24189
#
# add Temporal edges with node  26676  and next year Node  26688
#
# add Temporal edges with node  29675  and next year Node  29687
#
# add Temporal edges with node  33175  and next year Node  33187
#
# add Temporal edges with node  36675  and next year Node  36687
#
# add Temporal edges with node  40375  and next year Node  40387
#
# add Temporal edges with node  43975  and next year Node  43987
#
# add Temporal edges with node  47675  and next year Node  47687
#
# add Temporal edges with node  51475  and next year Node  51487
#
# add Temporal edges with node  55175  and next year Node  55187
#
# add Temporal edges with node  58875  and next year Node  58887
#
# add Temporal edges with node  62475  and next year Node  62487
#
# add Temporal edges with node  65975  and next year Node  65987
#
# add Temporal edges with node  69274  and next year Node  69286
#
# add Temporal edges with node  72472  and next year Node  72484
#
# add Temporal edges with node  4579  and next year Node  4591
#
# add Temporal edges with node  6179  and next year Node  6191
#
# add Temporal edges with node  7879  and next year Node  7891
#
# add Temporal edges with node  9579  and next year Node  9591
#
# add Temporal edges with node  11278  and next year Node  11290
#
# add Temporal edges with node  12978  and next year Node  12990
#
# add Temporal edges with node  14678  and next year Node  14690
#
# add Temporal edges with node  16378  and next year Node  16390
#
# add Temporal edges with node  18178  and next year Node  18190
#
# add Temporal edges with node  20078  and next year Node  20090
#
# add Temporal edges with node  21978  and next year Node  21990
#
# add Temporal edges with node  24277  and next year Node  24289
#
# add Temporal edges with node  26776  and next year Node  26788
#
# add Temporal edges with node  29775  and next year Node  29787
#
# add Temporal edges with node  33275  and next year Node  33287
#
# add Temporal edges with node  36775  and next year Node  36787
#
# add Temporal edges with node  40475  and next year Node  40487
#
# add Temporal edges with node  44075  and next year Node  44087
#
# add Temporal edges with node  47775  and next year Node  47787
#
# add Temporal edges with node  51575  and next year Node  51587
#
# add Temporal edges with node  55275  and next year Node  55287
#
# add Temporal edges with node  58975  and next year Node  58987
#
# add Temporal edges with node  62575  and next year Node  62587
#
# add Temporal edges with node  66075  and next year Node  66087
#
# add Temporal edges with node  69374  and next year Node  69386
#
# add Temporal edges with node  72572  and next year Node  72584
#
# add Temporal edges with node  4679  and next year Node  4691
#
# add Temporal edges with node  6279  and next year Node  6291
#
# add Temporal edges with node  7979  and next year Node  7991
#
# add Temporal edges with node  9679  and next year Node  9691
#
# add Temporal edges with node  11378  and next year Node  11390
#
# add Temporal edges with node  13078  and next year Node  13090
#
# add Temporal edges with node  14778  and next year Node  14790
#
# add Temporal edges with node  16478  and next year Node  16490
#
# add Temporal edges with node  18278  and next year Node  18290
#
# add Temporal edges with node  20178  and next year Node  20190
#
# add Temporal edges with node  22078  and next year Node  22090
#
# add Temporal edges with node  24377  and next year Node  24389
#
# add Temporal edges with node  26876  and next year Node  26888
#
# add Temporal edges with node  29875  and next year Node  29887
#
# add Temporal edges with node  33375  and next year Node  33387
#
# add Temporal edges with node  36875  and next year Node  36887
#
# add Temporal edges with node  44175  and next year Node  44187
#
# add Temporal edges with node  47875  and next year Node  47887
#
# add Temporal edges with node  51675  and next year Node  51687
#
# add Temporal edges with node  55375  and next year Node  55387
#
# add Temporal edges with node  59075  and next year Node  59087
#
# add Temporal edges with node  62675  and next year Node  62687
#
# add Temporal edges with node  66175  and next year Node  66187
#
# add Temporal edges with node  69474  and next year Node  69486
#
# add Temporal edges with node  6379  and next year Node  6391
#
# add Temporal edges with node  8079  and next year Node  8091
#
# add Temporal edges with node  9779  and next year Node  9791
#
# add Temporal edges with node  11478  and next year Node  11490
#
# add Temporal edges with node  13178  and next year Node  13190
#
# add Temporal edges with node  14878  and next year Node  14890
#
# add Temporal edges with node  16578  and next year Node  16590
#
# add Temporal edges with node  18378  and next year Node  18390
#
# add Temporal edges with node  20278  and next year Node  20290
#
# add Temporal edges with node  22178  and next year Node  22190
#
# add Temporal edges with node  24477  and next year Node  24489
#
# add Temporal edges with node  26976  and next year Node  26988
#
# add Temporal edges with node  29975  and next year Node  29987
#
# add Temporal edges with node  47975  and next year Node  47987
#
# add Temporal edges with node  8179  and next year Node  8191
#
# add Temporal edges with node  9879  and next year Node  9891
#
# add Temporal edges with node  11578  and next year Node  11590
#
# add Temporal edges with node  13278  and next year Node  13290
#
# add Temporal edges with node  14978  and next year Node  14990
#
# add Temporal edges with node  16678  and next year Node  16690
#
# add Temporal edges with node  18478  and next year Node  18490
#
# add Temporal edges with node  20378  and next year Node  20390
#
# add Temporal edges with node  22278  and next year Node  22290
#
# add Temporal edges with node  24577  and next year Node  24589
#
# add Temporal edges with node  16778  and next year Node  16790
#
# add Temporal edges with node  18578  and next year Node  18590
#
# add Temporal edges with node  20478  and next year Node  20490
#
# add Temporal edges with node  22378  and next year Node  22390
#
# add Temporal edges with node  24677  and next year Node  24689
#
# nodes processed: 131212
# current year month  202212.0  next year month  202312.0
# nodes processed: 132048

# %%
row1 = sort_processed_dataset[sort_processed_dataset["row_index"] == 58975  ]
display(row1)
# Out:
#        Unnamed: 0   Month     Lat     Lon  Lat_nom   Lon_nom  temperature_2m  \
# 58975       58975  202112  29.644  27.848  0.89743  0.657898        0.355758
#
#        temperature_2m_min  temperature_2m_max  dewpoint_temperature_2m  ...  \
# 58975            0.428959            0.332534                 0.519827  ...
#
#        next_month_tempreature  next_month_precipitation    spei01    spei03  \
# 58975                0.265482                  0.000467  0.585803  0.435282
#
#        year  month2  next_month_soil_moisture_am  next_month_spei01  \
# 58975  0.75     1.0                     0.152478           0.622285
#
#          datetime  row_index
# 58975  2021-12-01      58975
#
# [1 rows x 31 columns]

# %%
row2 = sort_processed_dataset[sort_processed_dataset["row_index"] == 58987  ]
display(row2)
# Out:
#        Unnamed: 0   Month     Lat     Lon  Lat_nom   Lon_nom  temperature_2m  \
# 58987       58987  202212  29.644  27.848  0.89743  0.657898        0.423274
#
#        temperature_2m_min  temperature_2m_max  dewpoint_temperature_2m  ...  \
# 58987            0.494939            0.395182                 0.571392  ...
#
#        next_month_tempreature  next_month_precipitation    spei01    spei03  \
# 58987                0.252426                  0.000244  0.283917  0.408811
#
#         year  month2  next_month_soil_moisture_am  next_month_spei01  \
# 58987  0.875     1.0                     0.086983           0.341775
#
#          datetime  row_index
# 58987  2022-12-01      58987
#
# [1 rows x 31 columns]

# %% [markdown]
# **Create 3 month temporal edges**

# %%
total_index = 0

for i, month in enumerate(unique_list_of_months[:-2]):
    # Get the dataset for the current month and the next month
    dataset_subset_1 = sort_processed_dataset[sort_processed_dataset["Month"] == month]
    dataset_subset_3 = sort_processed_dataset[sort_processed_dataset["Month"] == unique_list_of_months[i+2]]

    # Create dictionaries for the coordinates
    coords_dict_1 = {(row["Lon"], row["Lat"]): idx for idx, row in dataset_subset_1.iterrows()}
    coords_dict_3 = {(row["Lon"], row["Lat"]): idx for idx, row in dataset_subset_3.iterrows()}

    # Iterate through the first dictionary and check if the coordinates exist in the second dictionary
    for coord, idx1 in coords_dict_1.items():
        idx2 = coords_dict_3.get(coord)
        if idx2 is not None:
            Spatial_temporal_graph.add_edge(idx1, idx2)

    # Update and print the processed count
    total_index += len(dataset_subset_1)
    print("nodes processed: " + str(total_index))
# Out:
# nodes processed: 836
# nodes processed: 1672
# nodes processed: 2508
# nodes processed: 3344
# nodes processed: 4180
# nodes processed: 5016
# nodes processed: 5852
# nodes processed: 6688
# nodes processed: 7524
# nodes processed: 8360
# nodes processed: 9196
# nodes processed: 10032
# nodes processed: 10868
# nodes processed: 11704
# nodes processed: 12540
# nodes processed: 13376
# nodes processed: 14212
# nodes processed: 15048
# nodes processed: 15884
# nodes processed: 16720
# nodes processed: 17556
# nodes processed: 18392
# nodes processed: 19228
# nodes processed: 20064
# nodes processed: 20900
# nodes processed: 21736
# nodes processed: 22572
# nodes processed: 23408
# nodes processed: 24244
# nodes processed: 25080
# nodes processed: 25916
# nodes processed: 26752
# nodes processed: 27588
# nodes processed: 28424
# nodes processed: 29260
# nodes processed: 30096
# nodes processed: 30932
# nodes processed: 31768
# nodes processed: 32604
# nodes processed: 33440
# nodes processed: 34276
# nodes processed: 35112
# nodes processed: 35948
# nodes processed: 36784
# nodes processed: 37620
# nodes processed: 38456
# nodes processed: 39292
# nodes processed: 40128
# nodes processed: 40964
# nodes processed: 41800
# nodes processed: 42636
# nodes processed: 43472
# nodes processed: 44308
# nodes processed: 45144
# nodes processed: 45980
# nodes processed: 46816
# nodes processed: 47652
# nodes processed: 48488
# nodes processed: 49324
# nodes processed: 50160
# nodes processed: 50996
# nodes processed: 51832
# nodes processed: 52668
# nodes processed: 53504
# nodes processed: 54340
# nodes processed: 55176
# nodes processed: 56012
# nodes processed: 56848
# nodes processed: 57684
# nodes processed: 58520
# nodes processed: 59356
# nodes processed: 60192
# nodes processed: 61028
# nodes processed: 61864
# nodes processed: 62700
# nodes processed: 63536
# nodes processed: 64372
# nodes processed: 65208
# nodes processed: 66044
# nodes processed: 66880
# nodes processed: 67716
# nodes processed: 68552
# nodes processed: 69388
# nodes processed: 70224
# nodes processed: 71060
# nodes processed: 71896
# nodes processed: 72732
# nodes processed: 73568
# nodes processed: 74384
# nodes processed: 75220
# nodes processed: 76056
# nodes processed: 76892
# nodes processed: 77728
# nodes processed: 78564
# nodes processed: 79400
# nodes processed: 80236
# nodes processed: 81072
# nodes processed: 81908

# %%
list(Spatial_temporal_graph.edges())[0:3000]
# Out:
# [(36896, 36996),
#  (36896, 40496),
#  (36896, 40596),
#  (36896, 36897),
#  (36896, 36898),
#  (40496, 36996),
#  (40496, 44196),
#  (40496, 44296),
#  (40496, 40596),
#  (40496, 40497),
#  (40496, 40498),
#  (44196, 48096),
#  (44196, 44296),
#  (44196, 47996),
#  (44196, 40596),
#  (44196, 44197),
#  (44196, 44198),
#  (47996, 48096),
#  (47996, 44296),
#  (47996, 51796),
#  (47996, 51696),
#  (47996, 47997),
#  (47996, 47998),
#  (51696, 48096),
#  (51696, 55496),
#  (51696, 55396),
#  (51696, 51796),
#  (51696, 51697),
#  (51696, 51698),
#  (55396, 55496),
#  (55396, 59096),
#  (55396, 51796),
#  (55396, 55397),
#  (55396, 55398),
#  (36996, 37096),
#  (36996, 33396),
#  (36996, 40596),
#  (36996, 40696),
#  (36996, 36997),
#  (36996, 36998),
#  (40596, 37096),
#  (40596, 44296),
#  (40596, 40696),
#  (40596, 44396),
#  (40596, 40597),
#  (40596, 40598),
#  (44296, 48096),
#  (44296, 40696),
#  (44296, 48196),
#  (44296, 44396),
#  (44296, 44297),
#  (44296, 44298),
#  (48096, 48196),
#  (48096, 44396),
#  (48096, 51796),
#  (48096, 51896),
#  (48096, 48097),
#  (48096, 48098),
#  (51796, 48196),
#  (51796, 55496),
#  (51796, 51896),
#  (51796, 55596),
#  (51796, 51797),
#  (51796, 51798),
#  (55496, 59196),
#  (55496, 59096),
#  (55496, 51896),
#  (55496, 55596),
#  (55496, 55497),
#  (55496, 55498),
#  (59096, 62696),
#  (59096, 59196),
#  (59096, 55596),
#  (59096, 59097),
#  (59096, 59098),
#  (33396, 29996),
#  (33396, 37096),
#  (33396, 33496),
#  (33396, 37196),
#  (33396, 33397),
#  (33396, 33398),
#  (37096, 33496),
#  (37096, 37196),
#  (37096, 40696),
#  (37096, 40796),
#  (37096, 37097),
#  (37096, 37098),
#  (40696, 37196),
#  (40696, 44396),
#  (40696, 44496),
#  (40696, 40796),
#  (40696, 40697),
#  (40696, 40698),
#  (44396, 48196),
#  (44396, 48296),
#  (44396, 44496),
#  (44396, 40796),
#  (44396, 44397),
#  (44396, 44398),
#  (48196, 48296),
#  (48196, 44496),
#  (48196, 51896),
#  (48196, 51996),
#  (48196, 48197),
#  (48196, 48198),
#  (51896, 48296),
#  (51896, 55596),
#  (51896, 51996),
#  (51896, 55696),
#  (51896, 51897),
#  (51896, 51898),
#  (55596, 59196),
#  (55596, 51996),
#  (55596, 55696),
#  (55596, 59296),
#  (55596, 55597),
#  (55596, 55598),
#  (59196, 62696),
#  (59196, 55696),
#  (59196, 62796),
#  (59196, 59296),
#  (59196, 59197),
#  (59196, 59198),
#  (62696, 62796),
#  (62696, 59296),
#  (62696, 62697),
#  (62696, 62698),
#  (29996, 33496),
#  (29996, 33596),
#  (29996, 30096),
#  (29996, 29997),
#  (29996, 29998),
#  (33496, 37196),
#  (33496, 33596),
#  (33496, 30096),
#  (33496, 37296),
#  (33496, 33497),
#  (33496, 33498),
#  (37196, 40796),
#  (37196, 33596),
#  (37196, 37296),
#  (37196, 40896),
#  (37196, 37197),
#  (37196, 37198),
#  (40796, 44496),
#  (40796, 37296),
#  (40796, 40896),
#  (40796, 44596),
#  (40796, 40797),
#  (40796, 40798),
#  (44496, 48296),
#  (44496, 40896),
#  (44496, 44596),
#  (44496, 48396),
#  (44496, 44497),
#  (44496, 44498),
#  (48296, 44596),
#  (48296, 48396),
#  (48296, 51996),
#  (48296, 52096),
#  (48296, 48297),
#  (48296, 48298),
#  (51996, 48396),
#  (51996, 55796),
#  (51996, 52096),
#  (51996, 55696),
#  (51996, 51997),
#  (51996, 51998),
#  (55696, 55796),
#  (55696, 52096),
#  (55696, 59396),
#  (55696, 59296),
#  (55696, 55697),
#  (55696, 55698),
#  (59296, 55796),
#  (59296, 59396),
#  (59296, 62796),
#  (59296, 62896),
#  (59296, 59297),
#  (59296, 59298),
#  (62796, 59396),
#  (62796, 62896),
#  (62796, 66196),
#  (62796, 62797),
#  (62796, 62798),
#  (30096, 30196),
#  (30096, 33596),
#  (30096, 33696),
#  (30096, 30097),
#  (30096, 30098),
#  (33596, 30196),
#  (33596, 33696),
#  (33596, 37296),
#  (33596, 37396),
#  (33596, 33597),
#  (33596, 33598),
#  (37296, 33696),
#  (37296, 37396),
#  (37296, 40896),
#  (37296, 40996),
#  (37296, 37297),
#  (37296, 37298),
#  (40896, 37396),
#  (40896, 40996),
#  (40896, 44596),
#  (40896, 44696),
#  (40896, 40897),
#  (40896, 40898),
#  (44596, 40996),
#  (44596, 44696),
#  (44596, 48496),
#  (44596, 48396),
#  (44596, 44597),
#  (44596, 44598),
#  (48396, 44696),
#  (48396, 48496),
#  (48396, 52196),
#  (48396, 52096),
#  (48396, 48397),
#  (48396, 48398),
#  (52096, 48496),
#  (52096, 55796),
#  (52096, 52196),
#  (52096, 55896),
#  (52096, 52097),
#  (52096, 52098),
#  (55796, 52196),
#  (55796, 55896),
#  (55796, 59396),
#  (55796, 59496),
#  (55796, 55797),
#  (55796, 55798),
#  (59396, 55896),
#  (59396, 59496),
#  (59396, 62996),
#  (59396, 62896),
#  (59396, 59397),
#  (59396, 59398),
#  (62896, 59496),
#  (62896, 62996),
#  (62896, 66196),
#  (62896, 66295),
#  (62896, 62897),
#  (62896, 62898),
#  (66196, 62996),
#  (66196, 69495),
#  (66196, 66295),
#  (66196, 66197),
#  (66196, 66198),
#  (30196, 30296),
#  (30196, 33696),
#  (30196, 33796),
#  (30196, 30197),
#  (30196, 30198),
#  (33696, 30296),
#  (33696, 33796),
#  (33696, 37396),
#  (33696, 37496),
#  (33696, 33697),
#  (33696, 33698),
#  (37396, 33796),
#  (37396, 41096),
#  (37396, 37496),
#  (37396, 40996),
#  (37396, 37397),
#  (37396, 37398),
#  (40996, 41096),
#  (40996, 37496),
#  (40996, 44696),
#  (40996, 44796),
#  (40996, 40997),
#  (40996, 40998),
#  (44696, 41096),
#  (44696, 48496),
#  (44696, 44796),
#  (44696, 48596),
#  (44696, 44697),
#  (44696, 44698),
#  (48496, 44796),
#  (48496, 48596),
#  (48496, 52196),
#  (48496, 52296),
#  (48496, 48497),
#  (48496, 48498),
#  (52196, 48596),
#  (52196, 55896),
#  (52196, 55996),
#  (52196, 52296),
#  (52196, 52197),
#  (52196, 52198),
#  (55896, 59496),
#  (55896, 55996),
#  (55896, 52296),
#  (55896, 59596),
#  (55896, 55897),
#  (55896, 55898),
#  (59496, 62996),
#  (59496, 55996),
#  (59496, 59596),
#  (59496, 63096),
#  (59496, 59497),
#  (59496, 59498),
#  (62996, 59596),
#  (62996, 63096),
#  (62996, 66395),
#  (62996, 66295),
#  (62996, 62997),
#  (62996, 62998),
#  (66295, 63096),
#  (66295, 66395),
#  (66295, 69495),
#  (66295, 69595),
#  (66295, 66296),
#  (66295, 66297),
#  (69495, 66395),
#  (69495, 69595),
#  (69495, 69496),
#  (69495, 69497),
#  (79381, 80581),
#  (79381, 79481),
#  (79381, 80481),
#  (79381, 79382),
#  (79381, 79383),
#  (80481, 80581),
#  (80481, 79481),
#  (80481, 81481),
#  (80481, 81581),
#  (80481, 80482),
#  (80481, 80483),
#  (81481, 80581),
#  (81481, 81581),
#  (81481, 81482),
#  (81481, 81483),
#  (30296, 26997),
#  (30296, 30396),
#  (30296, 33896),
#  (30296, 33796),
#  (30296, 30297),
#  (30296, 30298),
#  (33796, 30396),
#  (33796, 33896),
#  (33796, 37596),
#  (33796, 37496),
#  (33796, 33797),
#  (33796, 33798),
#  (37496, 33896),
#  (37496, 41096),
#  (37496, 37596),
#  (37496, 41196),
#  (37496, 37497),
#  (37496, 37498),
#  (41096, 37596),
#  (41096, 41196),
#  (41096, 44896),
#  (41096, 44796),
#  (41096, 41097),
#  (41096, 41098),
#  (44796, 41196),
#  (44796, 44896),
#  (44796, 48696),
#  (44796, 48596),
#  (44796, 44797),
#  (44796, 44798),
#  (48596, 44896),
#  (48596, 48696),
#  (48596, 52296),
#  (48596, 52396),
#  (48596, 48597),
#  (48596, 48598),
#  (52296, 48696),
#  (52296, 55996),
#  (52296, 52396),
#  (52296, 56096),
#  (52296, 52297),
#  (52296, 52298),
#  (55996, 52396),
#  (55996, 56096),
#  (55996, 59696),
#  (55996, 59596),
#  (55996, 55997),
#  (55996, 55998),
#  (59596, 56096),
#  (59596, 59696),
#  (59596, 63096),
#  (59596, 63196),
#  (59596, 59597),
#  (59596, 59598),
#  (63096, 59696),
#  (63096, 63196),
#  (63096, 66495),
#  (63096, 66395),
#  (63096, 63097),
#  (63096, 63098),
#  (66395, 63196),
#  (66395, 66495),
#  (66395, 69695),
#  (66395, 69595),
#  (66395, 66396),
#  (66395, 66397),
#  (69595, 66495),
#  (69595, 69695),
#  (69595, 69596),
#  (69595, 69597),
#  (79481, 80581),
#  (79481, 79581),
#  (79481, 80681),
#  (79481, 79482),
#  (79481, 79483),
#  (80581, 81581),
#  (80581, 79581),
#  (80581, 81681),
#  (80581, 80681),
#  (80581, 80582),
#  (80581, 80583),
#  (81581, 81681),
#  (81581, 80681),
#  (81581, 81582),
#  (81581, 81583),
#  (26997, 30396),
#  (26997, 27097),
#  (26997, 30496),
#  (26997, 26998),
#  (26997, 26999),
#  (30396, 33896),
#  (30396, 33996),
#  (30396, 27097),
#  (30396, 30496),
#  (30396, 30397),
#  (30396, 30398),
#  (33896, 37596),
#  (33896, 33996),
#  (33896, 30496),
#  (33896, 37696),
#  (33896, 33897),
#  (33896, 33898),
#  (37596, 41196),
#  (37596, 33996),
#  (37596, 37696),
#  (37596, 41296),
#  (37596, 37597),
#  (37596, 37598),
#  (41196, 44896),
#  (41196, 37696),
#  (41196, 41296),
#  (41196, 44996),
#  (41196, 41197),
#  (41196, 41198),
#  (44896, 48696),
#  (44896, 41296),
#  (44896, 48796),
#  (44896, 44996),
#  (44896, 44897),
#  (44896, 44898),
#  (48696, 48796),
#  (48696, 44996),
#  (48696, 52496),
#  (48696, 52396),
#  (48696, 48697),
#  (48696, 48698),
#  (52396, 48796),
#  (52396, 56196),
#  (52396, 52496),
#  (52396, 56096),
#  (52396, 52397),
#  (52396, 52398),
#  (56096, 56196),
#  (56096, 52496),
#  (56096, 59796),
#  (56096, 59696),
#  (56096, 56097),
#  (56096, 56098),
#  (59696, 56196),
#  (59696, 59796),
#  (59696, 63296),
#  (59696, 63196),
#  (59696, 59697),
#  (59696, 59698),
#  (63196, 59796),
#  (63196, 63296),
#  (63196, 66495),
#  (63196, 66595),
#  (63196, 63197),
#  (63196, 63198),
#  (66495, 63296),
#  (66495, 69794),
#  (66495, 69695),
#  (66495, 66595),
#  (66495, 66496),
#  (66495, 66497),
#  (69695, 69794),
#  (69695, 72593),
#  (69695, 66595),
#  (69695, 69696),
#  (69695, 69697),
#  (79581, 80681),
#  (79581, 79681),
#  (79581, 80781),
#  (79581, 79582),
#  (79581, 79583),
#  (80681, 81681),
#  (80681, 81781),
#  (80681, 79681),
#  (80681, 80781),
#  (80681, 80682),
#  (80681, 80683),
#  (81681, 81781),
#  (81681, 82581),
#  (81681, 80781),
#  (81681, 81682),
#  (81681, 81683),
#  (27097, 30496),
#  (27097, 24698),
#  (27097, 30596),
#  (27097, 27197),
#  (27097, 27098),
#  (27097, 27099),
#  (30496, 33996),
#  (30496, 34096),
#  (30496, 30596),
#  (30496, 27197),
#  (30496, 30497),
#  (30496, 30498),
#  (33996, 34096),
#  (33996, 30596),
#  (33996, 37696),
#  (33996, 37796),
#  (33996, 33997),
#  (33996, 33998),
#  (37696, 34096),
#  (37696, 37796),
#  (37696, 41396),
#  (37696, 41296),
#  (37696, 37697),
#  (37696, 37698),
#  (41296, 37796),
#  (41296, 41396),
#  (41296, 45096),
#  (41296, 44996),
#  (41296, 41297),
#  (41296, 41298),
#  (44996, 41396),
#  (44996, 48896),
#  (44996, 48796),
#  (44996, 45096),
#  (44996, 44997),
#  (44996, 44998),
#  (48796, 48896),
#  (48796, 45096),
#  (48796, 52496),
#  (48796, 52596),
#  (48796, 48797),
#  (48796, 48798),
#  (52496, 48896),
#  (52496, 56196),
#  (52496, 56296),
#  (52496, 52596),
#  (52496, 52497),
#  (52496, 52498),
#  (56196, 59796),
#  (56196, 56296),
#  (56196, 52596),
#  (56196, 59896),
#  (56196, 56197),
#  (56196, 56198),
#  (59796, 63296),
#  (59796, 56296),
#  (59796, 63396),
#  (59796, 59896),
#  (59796, 59797),
#  (59796, 59798),
#  (63296, 63396),
#  (63296, 59896),
#  (63296, 66595),
#  (63296, 66695),
#  (63296, 63297),
#  (63296, 63298),
#  (66595, 63396),
#  (66595, 69794),
#  (66595, 66695),
#  (66595, 69893),
#  (66595, 66596),
#  (66595, 66597),
#  (69794, 72593),
#  (69794, 66695),
#  (69794, 72693),
#  (69794, 69893),
#  (69794, 69795),
#  (69794, 69796),
#  (72593, 72693),
#  (72593, 69893),
#  (72593, 74989),
#  (72593, 72594),
#  (72593, 72595),
#  (79681, 80781),
#  (79681, 79781),
#  (79681, 80881),
#  (79681, 79682),
#  (79681, 79683),
#  (80781, 81781),
#  (80781, 79781),
#  (80781, 80881),
#  (80781, 81881),
#  (80781, 80782),
#  (80781, 80783),
#  (81781, 82581),
#  (81781, 80881),
#  (81781, 81881),
#  (81781, 82680),
#  (81781, 81782),
#  (81781, 81783),
#  (82581, 81881),
#  (82581, 82680),
#  (82581, 82582),
#  (82581, 82583),
#  (24698, 27197),
#  (24698, 27297),
#  (24698, 24699),
#  (24698, 24700),
#  (27197, 30596),
#  (27197, 30696),
#  (27197, 27297),
#  (27197, 27198),
#  (27197, 27199),
#  (30596, 34096),
#  (30596, 34196),
#  (30596, 30696),
#  (30596, 27297),
#  (30596, 30597),
#  (30596, 30598),
#  (34096, 34196),
#  (34096, 30696),
#  (34096, 37896),
#  (34096, 37796),
#  (34096, 34097),
#  (34096, 34098),
#  (37796, 34196),
#  (37796, 41496),
#  (37796, 37896),
#  (37796, 41396),
#  (37796, 37797),
#  (37796, 37798),
#  (41396, 41496),
#  (41396, 37896),
#  (41396, 45196),
#  (41396, 45096),
#  (41396, 41397),
#  (41396, 41398),
#  (45096, 41496),
#  (45096, 45196),
#  (45096, 48896),
#  (45096, 48996),
#  (45096, 45097),
#  (45096, 45098),
#  (48896, 45196),
#  (48896, 48996),
#  (48896, 52696),
#  (48896, 52596),
#  (48896, 48897),
#  (48896, 48898),
#  (52596, 48996),
#  (52596, 52696),
#  (52596, 56296),
#  (52596, 56396),
#  (52596, 52597),
#  (52596, 52598),
#  (56296, 52696),
#  (56296, 59896),
#  (56296, 56396),
#  (56296, 59996),
#  (56296, 56297),
#  (56296, 56298),
#  (59896, 63396),
#  (59896, 63496),
#  (59896, 56396),
#  (59896, 59996),
#  (59896, 59897),
#  (59896, 59898),
#  (63396, 63496),
#  (63396, 59996),
#  (63396, 66695),
#  (63396, 66795),
#  (63396, 63397),
#  (63396, 63398),
#  (66695, 63496),
#  (66695, 69893),
#  (66695, 66795),
#  (66695, 69993),
#  (66695, 66696),
#  (66695, 66697),
#  (69893, 72693),
#  (69893, 72793),
#  (69893, 66795),
#  (69893, 69993),
#  (69893, 69894),
#  (69893, 69895),
#  (72693, 72793),
#  (72693, 69993),
#  (72693, 75089),
#  (72693, 74989),
#  (72693, 72694),
#  (72693, 72695),
#  (74989, 72793),
#  (74989, 75089),
#  (74989, 76985),
#  (74989, 74990),
#  (74989, 74991),
#  (79781, 80881),
#  (79781, 79782),
#  (79781, 79783),
#  (80881, 81981),
#  (80881, 81881),
#  (80881, 80882),
#  (80881, 80883),
#  (81881, 82780),
#  (81881, 81981),
#  (81881, 82680),
#  (81881, 81882),
#  (81881, 81883),
#  (82680, 82780),
#  (82680, 81981),
#  (82680, 82681),
#  (82680, 82682),
#  (27297, 30696),
#  (27297, 30796),
#  (27297, 27397),
#  (27297, 27298),
#  (27297, 27299),
#  (30696, 34196),
#  (30696, 30796),
#  (30696, 27397),
#  (30696, 34296),
#  (30696, 30697),
#  (30696, 30698),
#  (34196, 30796),
#  (34196, 34296),
#  (34196, 37896),
#  (34196, 37996),
#  (34196, 34197),
#  (34196, 34198),
#  (37896, 34296),
#  (37896, 41496),
#  (37896, 37996),
#  (37896, 41596),
#  (37896, 37897),
#  (37896, 37898),
#  (41496, 45196),
#  (41496, 37996),
#  (41496, 41596),
#  (41496, 45296),
#  (41496, 41497),
#  (41496, 41498),
#  (45196, 48996),
#  (45196, 41596),
#  (45196, 45296),
#  (45196, 49096),
#  (45196, 45197),
#  (45196, 45198),
#  (48996, 45296),
#  (48996, 49096),
#  (48996, 52696),
#  (48996, 52796),
#  (48996, 48997),
#  (48996, 48998),
#  (52696, 49096),
#  (52696, 56396),
#  (52696, 56496),
#  (52696, 52796),
#  (52696, 52697),
#  (52696, 52698),
#  (56396, 59996),
#  (56396, 60096),
#  (56396, 56496),
#  (56396, 52796),
#  (56396, 56397),
#  (56396, 56398),
#  (59996, 63496),
#  (59996, 63596),
#  (59996, 60096),
#  (59996, 56496),
#  (59996, 59997),
#  (59996, 59998),
#  (63496, 63596),
#  (63496, 60096),
#  (63496, 66795),
#  (63496, 66895),
#  (63496, 63497),
#  (63496, 63498),
#  (66795, 63596),
#  (66795, 69993),
#  (66795, 66895),
#  (66795, 70093),
#  (66795, 66796),
#  (66795, 66797),
#  (69993, 72793),
#  (69993, 66895),
#  (69993, 70093),
#  (69993, 72893),
#  (69993, 69994),
#  (69993, 69995),
#  (72793, 70093),
#  (72793, 72893),
#  (72793, 75089),
#  (72793, 75189),
#  (72793, 72794),
#  (72793, 72795),
#  (75089, 72893),
#  (75089, 76985),
#  (75089, 75189),
#  (75089, 77085),
#  (75089, 75090),
#  (75089, 75091),
#  (76985, 75189),
#  (76985, 77085),
#  (76985, 76986),
#  (76985, 76987),
#  (81981, 82880),
#  (81981, 82081),
#  (81981, 82780),
#  (81981, 81982),
#  (81981, 81983),
#  (82780, 82880),
#  (82780, 82081),
#  (82780, 82781),
#  (82780, 82782),
#  (27397, 30896),
#  (27397, 30796),
#  (27397, 27398),
#  (27397, 27399),
#  (30796, 30896),
#  (30796, 34296),
#  (30796, 34396),
#  (30796, 30797),
#  (30796, 30798),
#  (34296, 30896),
#  (34296, 34396),
#  (34296, 37996),
#  (34296, 38096),
#  (34296, 34297),
#  (34296, 34298),
#  (37996, 34396),
#  (37996, 38096),
#  (37996, 41596),
#  (37996, 41696),
#  (37996, 37997),
#  (37996, 37998),
#  (41596, 38096),
#  (41596, 41696),
#  (41596, 45396),
#  (41596, 45296),
#  (41596, 41597),
#  (41596, 41598),
#  (45296, 41696),
#  (45296, 45396),
#  (45296, 49096),
#  (45296, 49196),
#  (45296, 45297),
#  (45296, 45298),
#  (49096, 45396),
#  (49096, 49196),
#  (49096, 52896),
#  (49096, 52796),
#  (49096, 49097),
#  (49096, 49098),
#  (52796, 49196),
#  (52796, 56496),
#  (52796, 52896),
#  (52796, 56596),
#  (52796, 52797),
#  (52796, 52798),
#  (56496, 60096),
#  (56496, 52896),
#  (56496, 56596),
#  (56496, 60196),
#  (56496, 56497),
#  (56496, 56498),
#  (60096, 63596),
#  (60096, 56596),
#  (60096, 60196),
#  (60096, 63696),
#  (60096, 60097),
#  (60096, 60098),
#  (63596, 60196),
#  (63596, 63696),
#  (63596, 66895),
#  (63596, 66995),
#  (63596, 63597),
#  (63596, 63598),
#  (66895, 63696),
#  (66895, 70093),
#  (66895, 70193),
#  (66895, 66995),
#  (66895, 66896),
#  (66895, 66897),
#  (70093, 72893),
#  (70093, 70193),
#  (70093, 72993),
#  (70093, 66995),
#  (70093, 70094),
#  (70093, 70095),
#  (72893, 70193),
#  (72893, 72993),
#  (72893, 75289),
#  (72893, 75189),
#  (72893, 72894),
#  (72893, 72895),
#  (75189, 72993),
#  (75189, 77185),
#  (75189, 75289),
#  (75189, 77085),
#  (75189, 75190),
#  (75189, 75191),
#  (77085, 77185),
#  (77085, 75289),
#  (77085, 77086),
#  (77085, 77087),
#  (82081, 82880),
#  (82081, 82082),
#  (82081, 82083),
#  (82880, 82881),
#  (82880, 82882),
#  (30896, 34396),
#  (30896, 34496),
#  (30896, 27497),
#  (30896, 30996),
#  (30896, 30897),
#  (30896, 30898),
#  (34396, 34496),
#  (34396, 30996),
#  (34396, 38196),
#  (34396, 38096),
#  (34396, 34397),
#  (34396, 34398),
#  (38096, 34496),
#  (38096, 38196),
#  (38096, 41796),
#  (38096, 41696),
#  (38096, 38097),
#  (38096, 38098),
#  (41696, 38196),
#  (41696, 41796),
#  (41696, 45496),
#  (41696, 45396),
#  (41696, 41697),
#  (41696, 41698),
#  (45396, 41796),
#  (45396, 45496),
#  (45396, 49296),
#  (45396, 49196),
#  (45396, 45397),
#  (45396, 45398),
#  (49196, 45496),
#  (49196, 49296),
#  (49196, 52896),
#  (49196, 52996),
#  (49196, 49197),
#  (49196, 49198),
#  (52896, 49296),
#  (52896, 56596),
#  (52896, 52996),
#  (52896, 56696),
#  (52896, 52897),
#  (52896, 52898),
#  (56596, 60196),
#  (56596, 52996),
#  (56596, 56696),
#  (56596, 60296),
#  (56596, 56597),
#  (56596, 56598),
#  (60196, 63696),
#  (60196, 56696),
#  (60196, 60296),
#  (60196, 63796),
#  (60196, 60197),
#  (60196, 60198),
#  (63696, 66995),
#  (63696, 67095),
#  (63696, 60296),
#  (63696, 63796),
#  (63696, 63697),
#  (63696, 63698),
#  (66995, 70193),
#  (66995, 67095),
#  (66995, 63796),
#  (66995, 70293),
#  (66995, 66996),
#  (66995, 66997),
#  (70193, 72993),
#  (70193, 67095),
#  (70193, 70293),
#  (70193, 73092),
#  (70193, 70194),
#  (70193, 70195),
#  (72993, 75289),
#  (72993, 70293),
#  (72993, 73092),
#  (72993, 75389),
#  (72993, 72994),
#  (72993, 72995),
#  (75289, 77185),
#  (75289, 73092),
#  ...]

# %%
display_a_to_b_nodes(Spatial_temporal_graph, 1672, 1682, "row_index")

# %%
display_a_to_b_nodes(Spatial_temporal_graph, 0, 10, "row_index")

# %% [markdown]
# **Save Graph**

# %%
import pickle

# save graph object to file
pickle.dump(Spatial_temporal_graph, open('/content/drive/MyDrive/DroughtCastAI/Dataset/Spatial_temporal_grpah_version_2_normalized_1month_selectedV7.pickle', 'wb'))

# %%
# load graph object from file
Graph = pickle.load(open('/content/drive/MyDrive/DroughtCastAI/Dataset/Spatial_temporal_grpah_version_2_normalized_1month_selectedV7.pickle', 'rb'))

# %% [markdown]
# **Graph Display and Test**

# %%
def display_a_to_b_nodes(graph, a, b, attribute_name):
    # Extract nodes from index a to b
    nodes_subset = list(graph.nodes())[a:b]

    # Create a subgraph with these nodes
    subgraph = graph.subgraph(nodes_subset)

    # Create a dictionary for node labels based on the specified attribute
    node_labels = {node: subgraph.nodes[node].get(attribute_name, '') for node in subgraph.nodes()}

    # Draw the subgraph with the linear layout
    plt.figure(figsize=(15, 5))
    nx.draw(subgraph, with_labels=True, node_color="cyan", node_size=500, edge_color='black', linewidths=1, font_size=10, labels=node_labels)
    plt.show()

# %%
display_a_to_b_nodes(Spatial_temporal_graph, 90, 103, "Lat")

# %%
#Access node attibutes for the 80th node
Spatial_temporal_graph.nodes[list(Spatial_temporal_graph.nodes())[80]]
# Out:
# {'row_index': 52396,
#  'Month': 201505,
#  'Lat': -20.661,
#  'Lon': 26.051,
#  'Lat_nom': 0.1794944982802665,
#  'Lon_nom': 0.6315766346379188,
#  'temperature_2m': 0.5362895447530871,
#  'temperature_2m_min': 0.6666134695180341,
#  'temperature_2m_max': 0.4709635931935096,
#  'dewpoint_temperature_2m': 0.6398065665563752,
#  'total_precipitation_sum': 4.197888979301165e-05,
#  'total_precipitation_min': 0.0,
#  'total_precipitation_max': 0.0001239348777246,
#  'u_component_of_wind_10m': 0.3156139509781005,
#  'v_component_of_wind_10m': 0.4649815711718297,
#  'surface_net_solar_radiation_sum': 0.5658021482706602,
#  'total_evaporation_sum': 0.6078474348178262,
#  'soil_moisture_am': 0.1251060285930198,
#  'soil_moisture_pm': 0.1347255041185762,
#  'NDVI': 0.4128594883103823,
#  'EVI': 0.3085730909622223,
#  'next_month_tempreature': 0.3147141985917843,
#  'next_month_precipitation': 0.0088728425501937,
#  'year': 0.0,
#  'month2': 0.3636363636363636,
#  'spei01': 0.2454369999999999,
#  'next_month_soil_moisture_am': 0.1093923597723662,
#  'next_month_spei01': 0.4273866}
